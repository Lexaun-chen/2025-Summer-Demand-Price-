# %%
import connectorx as cx
import pandas as pd
import numpy as np
import os
import duckdb
from datetime import datetime
import glob
import multiprocessing as mp
from functools import partial
import time

# %%
def calculate_daily_factor(trading_date):
    order_pth = f"/data/cephfs/order/{pd.to_datetime(trading_date).strftime('%Y%m%d')}.parquet"

    if not os.path.exists(order_pth):
        raise FileNotFoundError(f"订单数据文件不存在: {order_pth}")

    conn = duckdb.connect(database=':memory:')

    query_order = f"""
        WITH buy_orders_with_time AS(
            SELECT 
                security_code,
                order_side, 
                order_type,
                order_details,
                order_price,
                order_price_adj,
                order_volume,
                order_time
            FROM '{order_pth}'
            WHERE order_side = 1
                AND order_type = 'A'
                AND order_details = 'L'
                AND order_price > 0
                AND order_volume > 0
                AND order_time >= 93000000
                AND order_time < 145700000
        )
        SELECT
            security_code,
            order_price,
            order_volume,
            order_time
        FROM buy_orders_with_time
        """

    # 将数据加载到临时表中
    conn.execute(f"CREATE TEMPORARY TABLE minute_order AS {query_order}")

                
    # 计算买方价格分位数
    bid_percentile_query = """
    CREATE TEMPORARY TABLE bid_percentiles AS
    SELECT 
        security_code,
        PERCENTILE_CONT(0.01) WITHIN GROUP (ORDER BY order_price) AS p01,
        PERCENTILE_CONT(0.99) WITHIN GROUP (ORDER BY order_price) AS p99,
        PERCENTILE_CONT(0.05) WITHIN GROUP (ORDER BY order_price) AS p05,
        PERCENTILE_CONT(0.95) WITHIN GROUP (ORDER BY order_price) AS p95
    FROM minute_order
    GROUP BY security_code
    """
    conn.execute(bid_percentile_query)
    
    # 创建买方P01-P99缩尾表
    bid_winsorized_query_p01_p99 = f"""
    CREATE TEMPORARY TABLE minute_order_p01_p99 AS
    SELECT 
        b.security_code,
        CASE 
            WHEN b.order_price < p.p01 THEN p.p01
            WHEN b.order_price > p.p99 THEN p.p99
            ELSE b.order_price
        END AS order_price,
        b.order_volume,
        b.order_time
    FROM minute_order b
    JOIN bid_percentiles p ON b.security_code = p.security_code
    """
    conn.execute(bid_winsorized_query_p01_p99)
    # created_tables.append(f'minute_order_p01_p99')
    

    bid_winsorized_query_p05_p95 = f"""
    CREATE TEMPORARY TABLE minute_order_p05_p95 AS
    SELECT 
        b.security_code,
        CASE 
            WHEN b.order_price < p.p05 THEN p.p05
            WHEN b.order_price > p.p95 THEN p.p95
            ELSE b.order_price
        END AS order_price,
        b.order_volume,
        b.order_time
    FROM minute_order b
    JOIN bid_percentiles p ON b.security_code = p.security_code
    """
    conn.execute(bid_winsorized_query_p05_p95)
    # created_tables.append(f'minute_order_p05_p95')


    P01_P99_APB_query = """
    SELECT 
        security_code,
        AVG(order_price) AS twap,
        SUM(order_volume * order_price)/SUM(order_volume) AS vwap
    FROM minute_order_p01_p99
    GROUP BY security_code
    """

    conn.execute(f"CREATE TEMPORARY TABLE order_value_p01_p99 AS {P01_P99_APB_query}")

    # 计算因子
    P01_P99_APB_Factors = conn.execute("""
    SELECT 
        security_code,
        CASE 
            WHEN twap > 0 AND vwap > 0 THEN LN(twap / vwap)
            ELSE NULL
        END AS daily_APB_p01_p99
    FROM order_value_p01_p99
    """).fetchdf()

    P05_P95_APB_query = """
    SELECT 
        security_code,
        AVG(order_price) AS twap,
        SUM(order_volume * order_price)/SUM(order_volume) AS vwap
    FROM minute_order_p05_p95
    GROUP BY security_code
    """

    conn.execute(f"CREATE TEMPORARY TABLE order_value_p05_p95 AS {P05_P95_APB_query}")

    # 计算因子
    P05_P95_APB_Factors = conn.execute("""
    SELECT 
        security_code,
        CASE 
            WHEN twap > 0 AND vwap > 0 THEN LN(twap / vwap)
            ELSE NULL
        END AS daily_APB_p05_p95
    FROM order_value_p05_p95
    """).fetchdf()

    Factor_df = pd.merge(
        P01_P99_APB_Factors,
        P05_P95_APB_Factors,
        on='security_code',
        how='inner'
    )


    return Factor_df

# %%
def derive_daily_factor (start_date, end_date, factor_name):
    
    #交易日列表
    trading_dates = pd.date_range(start=start_date, end=end_date, freq='B') 
    output_dir = f"./factors/{factor_name}"
    os.makedirs(output_dir, exist_ok=True)
    # 记录处理结果
    processed_dates = []
    skipped_dates = []
    
    for trading_date in trading_dates:
        date_str = trading_date.strftime('%Y%m%d')
        file_path = f"{output_dir}/{date_str}.parquet"
        
        # 如果文件已存在，跳过处理
        if os.path.exists(file_path):
            print(f"文件已存在，跳过: {file_path}")
            processed_dates.append(date_str)
            continue
        
        # 检查原始数据文件是否存在
        order_pth = f"/data/cephfs/order/{date_str}.parquet"

        if not os.path.exists(order_pth):
            print(f"跳过日期 {date_str}: 订单数据文件不存在")
            skipped_dates.append(date_str)
            continue
        
        try:
            # 计算因子
            daily_factor_df = calculate_daily_factor(trading_date)
            
            # 添加日期列
            daily_factor_df['date'] = date_str
            
            # 保存结果
            daily_factor_df.to_parquet(file_path, index=False)
            print(f"已生成因子文件: {file_path}")
            processed_dates.append(date_str)
            
        except Exception as e:
            print(f"处理日期 {date_str} 时出错: {str(e)}")
            skipped_dates.append(date_str)
    
    # 打印处理结果摘要
    print(f"\n处理完成:")
    print(f"成功处理 {len(processed_dates)} 个日期")
    print(f"跳过 {len(skipped_dates)} 个日期")
    
    return output_dir

# %%
def calculate_rolling_20d_avg(factor_names, factor_dir, start_date=None, end_date=None, min_window=5):
    
    if not isinstance(factor_names, list):
        factor_names = [factor_names]
    
    parquet_pattern = os.path.join(factor_dir, "*.parquet")
    parquet_files = glob.glob(parquet_pattern)
    print(f"在目录 {factor_dir} 中找到 {len(parquet_files)} 个Parquet文件")
    

    conn = duckdb.connect(database=':memory:')
    all_factor_data = conn.execute(f"""
        SELECT * FROM read_parquet('{parquet_pattern}')
    """).fetchdf()
    conn.close()

    all_factor_data.rename(columns={'daily_APB_p01_p99_x':'daily_APB_p01_p99','daily_APB_p01_p99_y':'daily_APB_p05_p95'},inplace=True)
    

    missing_factors = [f for f in factor_names if f not in all_factor_data.columns]
    if missing_factors:
        raise ValueError(f"在Parquet文件中未找到以下因子列: {', '.join(missing_factors)}")
    
    all_factor_data['date'] = pd.to_datetime(all_factor_data['date'])

    all_factor_data = all_factor_data.sort_values(['date', 'security_code'])
    
    # 筛选日期范围
    if start_date:
        start_date = pd.to_datetime(start_date)
        all_factor_data = all_factor_data[all_factor_data['date'] >= start_date]
    if end_date:
        end_date = pd.to_datetime(end_date)
        all_factor_data = all_factor_data[all_factor_data['date'] <= end_date]

    # 获取所有个股代码
    all_securities = all_factor_data['security_code'].unique()

    result_df = all_factor_data[['date', 'security_code']].copy()

    # 为每个因子计算滚动平均
    for factor_name in factor_names:
        print(f"\n处理因子: {factor_name}")
        
        #转置成宽表
        pivot_data = all_factor_data.pivot(index='date', columns='security_code', values=factor_name)

        # 对宽表直接应用rolling
        rolling_avg = pivot_data.rolling(window=20, min_periods=min_window).mean()

        # 将结果转换回长格式
        factor_df = rolling_avg.stack().reset_index()
        factor_df.columns = ['date', 'security_code', factor_name]

        factor_df.to_csv(f"/data/home/lexuanchen/Factors/Order/Signal/Alltime_Improved_APB_2/D_D_Order_Bid_20d_{factor_name}.csv")

        # 计算每日因子覆盖率
        # 计算每个日期非NaN的因子值数量
        non_nan_counts = factor_df.dropna(subset=[factor_name]).groupby('date').size()

        # 计算覆盖率
        coverage = non_nan_counts / len(all_securities)
        print(f"\n{factor_name}因子覆盖率统计: 平均={coverage.mean():.2f}, 最小={coverage.min():.2f}")

        result_df = pd.merge(
            result_df, 
            factor_df,
            on=['date', 'security_code'],
            how='left'
        )
    
    return result_df

# %%
def process_single_date(trading_date, factor_name):
    
    """处理单个交易日的函数"""
   
    date_str = trading_date.strftime('%Y%m%d')
    output_dir = f"./factors/{factor_name}"
    file_path = f"{output_dir}/{date_str}.parquet"
    
    # 如果文件已存在，跳过处理
    if os.path.exists(file_path):
        print(f"文件已存在，跳过: {file_path}")
        return date_str, True, "已存在"
    
    # 检查原始数据文件是否存在
    data_file = f"/data/cephfs/order/{date_str}.parquet"
    if not os.path.exists(data_file):
        print(f"跳过日期 {date_str}: 原始数据文件不存在")
        return date_str, False, "数据文件不存在"
    
    try:
        daily_factor_df = calculate_daily_factor(trading_date)
        
        daily_factor_df['date'] = date_str

        daily_factor_df.to_parquet(file_path, index=False)
        print(f"已生成因子文件: {file_path}")
        return date_str, True, "成功"
        
    except Exception as e:
        error_msg = str(e)
        print(f"处理日期 {date_str} 时出错: {error_msg}")
        return date_str, False, error_msg


def derive_daily_factor(start_date, end_date, factor_name, num_processes=30):
    start_time = time.time()
    
    trading_dates = pd.date_range(start=start_date, end=end_date, freq='B')
    
    # 创建输出目录
    output_dir = f"./factors/{factor_name}"
    os.makedirs(output_dir, exist_ok=True)
    
    # 创建进程池
    pool = mp.Pool(processes=num_processes)
    
    # 创建带有固定参数的处理函数
    process_date_with_args = partial(process_single_date, factor_name=factor_name)
    
    # 提交所有任务到进程池并获取结果
    print(f"开始使用 {num_processes} 个进程并行处理 {len(trading_dates)} 个交易日...")
    results = pool.map(process_date_with_args, trading_dates)
    
    # 关闭进程池
    pool.close()
    pool.join()
    
    # 分析处理结果
    processed_dates = [date_str for date_str, success, _ in results if success]
    skipped_dates = [date_str for date_str, success, _ in results if not success]
    
    # 打印处理结果摘要
    print(f"\n处理完成:")
    print(f"成功处理 {len(processed_dates)} 个日期")
    print(f"跳过 {len(skipped_dates)} 个日期")

    return output_dir

# %%
def main():

    start_date = '2016-06-20'
    end_date = '2025-06-30'

    factor_name = "Percent_D_D_Bid_daily_APB"
    
    factor_dir = derive_daily_factor (start_date, end_date, factor_name)

    factor_dir = "/data/home/lexuanchen/.conda/envs/Order_Improvement/factors/Percent_D_D_Bid_daily_APB"
    
    print(f"所有因子文件已生成在目录: {factor_dir}")


    factor_names = ['daily_APB_p01_p99', 'daily_APB_p05_p95']

    result_df = calculate_rolling_20d_avg(factor_names, factor_dir, start_date, end_date, min_window=5)
    
    #保存结果为CSV
    output_path = "/data/home/lexuanchen/Factors/Order/Signal/Alltime_Improved_APB_2"
    os.makedirs(output_path, exist_ok=True)

    result_df.to_csv(f'{output_path}/D_D_Order_Bid_Percent_20d_APB.csv')

    print(f"共计 {len(result_df)} 条记录")

    print("\n数据预览:")
    print(result_df.head())

# 执行主函数
if __name__ == "__main__":
    main()
# Out:
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160620.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160718.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160815.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160912.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161010.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161107.parquet
# 跳过日期 20170102: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170227.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161205.parquet跳过日期 20170130: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170424.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170327.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160621.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170619.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170717.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160719.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170522.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170911.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171009.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160913.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170814.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171106.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171204.parquet
#
# 跳过日期 20180101: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180129.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180226.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160816.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161108.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161011.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170228.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170103.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180326.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160622.parquet跳过日期 20180618: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180716.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180910.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161206.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180813.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170328.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170425.parquet
#
#
#
# 跳过日期 20170131: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160720.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170620.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170718.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170523.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160914.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171010.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170912.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171107.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170815.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171205.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160817.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161109.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180130.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180102.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161012.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180227.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170301.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170104.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180327.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160623.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161207.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180619.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180911.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180717.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170329.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170426.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180814.parquet
#
#
#
# 跳过日期 20170201: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160721.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170621.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170719.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170524.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171011.parquet跳过日期 20160915: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170913.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171108.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170816.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171206.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161110.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160818.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180103.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180131.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161013.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180228.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170302.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170105.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180328.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160624.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161208.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180620.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180912.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170330.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180718.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170427.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180815.parquet
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160722.parquet跳过日期 20170202: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170622.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170720.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170525.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171012.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170914.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171109.parquet
# 跳过日期 20160916: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170817.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171207.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160819.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161111.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180104.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180201.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161014.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180301.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170303.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170106.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180329.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160627.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180621.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161209.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180913.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170331.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180719.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170428.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180816.parquet
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160725.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170203.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170721.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170623.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170526.parquet
#
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171013.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170915.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171110.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160919.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160822.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170818.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171208.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161114.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180105.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161017.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180202.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180302.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170306.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170109.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180330.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160628.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161212.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180521.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180914.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180622.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180720.parquet跳过日期 20170403: 原始数据文件不存在
# 跳过日期 20170501: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180817.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180423.parquet
#
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160726.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170206.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170724.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170626.parquet跳过日期 20170529: 原始数据文件不存在
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171016.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170918.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171113.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160920.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160823.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171211.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170821.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161115.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180108.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161018.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180205.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180305.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170307.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170110.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180402.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160629.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161213.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180917.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180625.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180723.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180522.parquet
# 跳过日期 20170404: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170502.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180820.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180424.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160727.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170207.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170725.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170627.parquet
# 跳过日期 20170530: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171017.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170919.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171114.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160921.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160824.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171212.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161116.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170822.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180109.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161019.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180206.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180306.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170308.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170111.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180403.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160630.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161214.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180918.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180626.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180724.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180523.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170503.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170405.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180821.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180425.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160728.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170208.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170726.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170628.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170531.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171018.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170920.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171115.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160922.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160825.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171213.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161117.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180110.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170823.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161020.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180207.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180307.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170112.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170309.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180404.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161215.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160701.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180919.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180627.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180725.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180524.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170504.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170406.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180822.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180426.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160729.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170209.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170727.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170601.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170629.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171019.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170921.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171116.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160923.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160826.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171214.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161118.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180111.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170824.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161021.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180208.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180308.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170113.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170310.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161216.parquet跳过日期 20180405: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160704.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180920.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180628.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180525.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180726.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170505.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170407.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180823.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180427.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160801.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170210.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170728.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170602.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170630.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171020.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170922.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171117.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160926.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160829.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171215.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161121.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180112.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170825.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161024.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180209.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180309.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170116.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170313.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161219.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160705.parquet跳过日期 20180406: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180921.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180629.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180528.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170508.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180727.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170410.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180824.parquet
#
#
# 跳过日期 20180430: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160802.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170213.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170731.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170605.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170703.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171023.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170925.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171120.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160927.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171218.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160830.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161122.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180115.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170828.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161025.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180212.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180312.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170117.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170314.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161220.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160706.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180409.parquet
#
# 跳过日期 20180924: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180702.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180529.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170509.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180730.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170411.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180827.parquet
#
#
# 跳过日期 20180501: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160803.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170214.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170801.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170606.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170704.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171024.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170926.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171121.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160928.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171219.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160831.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161123.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180116.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170829.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161026.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180213.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180313.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170118.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170315.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161221.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160707.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180410.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180925.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180703.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180530.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170510.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180731.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170412.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180828.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180502.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160804.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170215.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170802.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170607.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170705.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171025.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170927.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171122.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160929.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171220.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160901.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161124.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180117.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170830.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161027.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180214.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180314.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170119.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170316.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161222.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160708.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180411.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180926.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180704.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180531.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170511.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180801.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170413.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180829.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170216.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180503.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160805.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170803.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170608.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170706.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171026.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170928.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171123.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160930.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171221.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160902.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161125.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180118.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170831.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161028.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180315.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170120.parquet
# 跳过日期 20180215: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170317.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161223.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160711.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180412.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180927.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180705.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180601.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170512.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180802.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170414.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180830.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170217.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180504.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160808.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170804.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170609.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170707.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171027.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170929.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171124.parquet
#
#
# 跳过日期 20161003: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160905.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171222.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161128.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180119.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170901.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161031.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170123.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180316.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170320.parquet跳过日期 20180216: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161226.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160712.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180413.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180928.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180706.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180604.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170515.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180803.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170417.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180831.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170220.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160809.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180507.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170807.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170612.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170710.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171030.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171127.parquet
# 跳过日期 20171002: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160906.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171225.parquet跳过日期 20161004: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161129.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180122.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170904.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161101.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170124.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180319.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170321.parquet
# 跳过日期 20180219: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161227.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160713.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180416.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180709.parquet跳过日期 20181001: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180605.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170516.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180806.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170418.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180903.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170221.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160810.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180508.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170808.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170613.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170711.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171031.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171128.parquet
#
# 跳过日期 20171003: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171226.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160907.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161130.parquet跳过日期 20161005: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180123.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170905.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161102.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170125.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180320.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170322.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161228.parquet
#
# 跳过日期 20180220: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180417.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160714.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180710.parquet
# 跳过日期 20181002: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170517.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180606.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180807.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170419.parquet
#
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180904.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170222.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180509.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160811.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170809.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170614.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170712.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171101.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171129.parquet
#
#
# 跳过日期 20171004: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160908.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171227.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161201.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180124.parquet跳过日期 20161006: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170906.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161103.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180321.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170126.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170323.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161229.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180418.parquet跳过日期 20180221: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160715.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180711.parquet跳过日期 20181003: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170518.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180607.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180808.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170420.parquet
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180905.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170223.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180510.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160812.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170615.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170810.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170713.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171102.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171130.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20160909.parquet跳过日期 20171005: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171228.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161202.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180125.parquet
# 跳过日期 20161007: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170907.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161104.parquet
# 跳过日期 20170127: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180322.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170324.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20161230.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180419.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180222.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180712.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181008.parquet
# 跳过日期 20181004: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170519.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180608.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180809.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170421.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180906.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170224.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180511.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181105.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170616.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170811.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170714.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171103.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171201.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181203.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20171229.parquet跳过日期 20171006: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180126.parquet跳过日期 20181231: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20170908.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190128.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190225.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180323.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190325.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190422.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190520.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180420.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180223.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180713.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181009.parquet跳过日期 20181005: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190617.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180611.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180810.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190715.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180907.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190812.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181106.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180514.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190909.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191104.parquet
#
# 跳过日期 20191007: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191202.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191230.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181204.parquet
#
# 跳过日期 20200127: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200224.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200323.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190129.parquet跳过日期 20190101: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190226.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200420.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190326.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190423.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200518.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190521.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200615.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200713.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181010.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190618.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200810.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200907.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180612.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190716.parquet跳过日期 20201005: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20201102.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190813.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180515.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181107.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190910.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191105.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191008.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191203.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191231.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181205.parquet
#
# 跳过日期 20200128: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200324.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200225.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190130.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190102.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190227.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200421.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190327.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190424.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200519.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190522.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200616.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200714.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190619.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181011.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200811.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180613.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200908.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190717.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20201103.parquet跳过日期 20201006: 原始数据文件不存在
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190814.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180516.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181108.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190911.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191106.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191009.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191204.parquet
#
# 跳过日期 20200101: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181206.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200325.parquet跳过日期 20200129: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200226.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190131.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190228.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190103.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200422.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190328.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190425.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200520.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190523.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200617.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190620.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200715.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181012.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200812.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180614.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200909.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190718.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20201104.parquet
#
# 跳过日期 20201007: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190815.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180517.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181109.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190912.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191107.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191010.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191205.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200102.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181207.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200326.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200227.parquet跳过日期 20200130: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190201.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190104.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190301.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200423.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190329.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190426.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190524.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200521.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200618.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190621.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200716.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181015.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200813.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180615.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200910.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190719.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20201105.parquet
#
#
# 跳过日期 20201008: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190816.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20180518.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181112.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191108.parquet
# 跳过日期 20190913: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191011.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200103.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191206.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181210.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200327.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200228.parquet
# 跳过日期 20200131: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190107.parquet跳过日期 20190204: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190304.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200424.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190401.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190429.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190527.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200522.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200619.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190624.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200717.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181016.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200814.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20201130.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200911.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190722.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20201106.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20201009.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190819.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20201228.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181113.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191111.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190916.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191014.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200106.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191209.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181211.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200330.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200302.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200203.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190108.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190305.parquet
# 跳过日期 20190205: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200427.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190402.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190430.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190528.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200525.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200622.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190625.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200720.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181017.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200817.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20201201.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200914.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190723.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20201109.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20201012.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190820.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20201229.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181114.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191112.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191015.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20190917.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20200107.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20191210.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20181212.parquet
#
#
# ...
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20231019.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20231218.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241112.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250520.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250109.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230601.parquet
#
# 跳过日期 20250404: 原始数据文件不存在跳过日期 20240503: 原始数据文件不存在
#
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230921.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250425.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250306.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240626.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230824.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241213.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240725.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230802.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240919.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20231120.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240531.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241016.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240308.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230602.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20231219.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241113.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240506.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240111.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230704.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250407.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240603.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240627.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241114.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20231220.parquet
# 跳过日期 20240405: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240726.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240206.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250521.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230705.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250307.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230803.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230825.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250408.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250207.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240507.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240628.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240604.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230922.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250310.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250409.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230828.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241017.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250210.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240311.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241115.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250311.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250110.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250410.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250428.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240821.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240508.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240920.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240408.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230829.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20231121.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241018.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230605.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250211.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240729.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240509.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250522.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230804.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20231221.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240112.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240312.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20231020.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250312.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250411.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230830.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230706.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20231122.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250212.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250113.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241118.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241216.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240510.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240207.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20231222.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240313.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250429.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250609.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240701.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230925.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250313.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250114.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20231023.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240730.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230831.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240923.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240314.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20231123.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230606.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240605.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241021.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230707.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240822.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240315.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250610.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240409.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241119.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240208.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250523.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240115.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241217.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240731.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250115.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250430.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250213.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240702.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230926.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230901.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250314.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241022.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250611.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240606.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230607.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240703.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20231024.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250116.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20231124.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230927.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240801.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240116.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240924.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240410.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250214.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241120.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250526.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241023.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240607.parquet
#
# 跳过日期 20240209: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250612.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250117.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230608.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240704.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230928.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240117.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20231025.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240925.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240411.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240802.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241024.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250527.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241121.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250613.parquet
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20230609.parquet跳过日期 20230929: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240705.parquet跳过日期 20250501: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240118.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240926.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240823.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240412.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241122.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241025.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250528.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250616.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20231026.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240119.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240927.parquet
# 跳过日期 20240212: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241218.parquet
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250529.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20231027.parquet跳过日期 20250502: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240826.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250617.parquet
#
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250530.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241219.parquet跳过日期 20240213: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240827.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250618.parquet跳过日期 20250505: 原始数据文件不存在
#
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240828.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250506.parquet跳过日期 20250602: 原始数据文件不存在跳过日期 20240214: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250619.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240829.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250620.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250507.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250603.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20241220.parquet
# 跳过日期 20240215: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20240830.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250508.parquet跳过日期 20240216: 原始数据文件不存在文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250623.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250604.parquet
#
#
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250509.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250624.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250605.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250625.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250606.parquet文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250626.parquet
#
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250627.parquet
# 文件已存在，跳过: ./factors/Percent_D_D_Bid_daily_APB/20250630.parquet
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 已生成因子文件: ./factors/Percent_D_D_Bid_daily_APB/20210316.parquet
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 已生成因子文件: ./factors/Percent_D_D_Bid_daily_APB/20220118.parquet
# 已生成因子文件: ./factors/Percent_D_D_Bid_daily_APB/20220824.parquet
# 已生成因子文件: ./factors/Percent_D_D_Bid_daily_APB/20210317.parquet
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 已生成因子文件: ./factors/Percent_D_D_Bid_daily_APB/20210318.parquet
# 已生成因子文件: ./factors/Percent_D_D_Bid_daily_APB/20220119.parquet
# 已生成因子文件: ./factors/Percent_D_D_Bid_daily_APB/20220825.parquet
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 已生成因子文件: ./factors/Percent_D_D_Bid_daily_APB/20210319.parquet
# 已生成因子文件: ./factors/Percent_D_D_Bid_daily_APB/20220826.parquet
# 已生成因子文件: ./factors/Percent_D_D_Bid_daily_APB/20220120.parquet
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 已生成因子文件: ./factors/Percent_D_D_Bid_daily_APB/20220829.parquet
# 已生成因子文件: ./factors/Percent_D_D_Bid_daily_APB/20220121.parquet
# 已生成因子文件: ./factors/Percent_D_D_Bid_daily_APB/20220830.parquet
# 已生成因子文件: ./factors/Percent_D_D_Bid_daily_APB/20220831.parquet
# 已生成因子文件: ./factors/Percent_D_D_Bid_daily_APB/20220901.parquet
# 已生成因子文件: ./factors/Percent_D_D_Bid_daily_APB/20220902.parquet
#
# 处理完成:
# 成功处理 2193 个日期
# 跳过 163 个日期
# 所有因子文件已生成在目录: /data/home/lexuanchen/.conda/envs/Order_Improvement/factors/Percent_D_D_Bid_daily_APB
# 在目录 /data/home/lexuanchen/.conda/envs/Order_Improvement/factors/Percent_D_D_Bid_daily_APB 中找到 2193 个Parquet文件
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 处理因子: daily_APB_p01_p99
#
# daily_APB_p01_p99因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: daily_APB_p05_p95
#
# daily_APB_p05_p95因子覆盖率统计: 平均=0.77, 最小=0.47
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 32
#      30 # 执行主函数
#      31 if __name__ == "__main__":
# ---> 32     main()
#
# Cell In[5], line 19, in main()
#      15 factor_names = ['daily_APB_p01_p99', 'daily_APB_p05_p95']
#      17 result_df = calculate_rolling_20d_avg(factor_names, factor_dir, start_date, end_date, min_window=5)
# ---> 19 保存结果为CSV
#      20 output_path = "/data/home/lexuanchen/Factors/Order/Signal/Alltime_Improved_APB_2"
#      21 os.makedirs(output_path, exist_ok=True)
#
# NameError: name '保存结果为CSV' is not defined

# %%
output_path = "/data/home/lexuanchen/Factors/Order/Signal/Alltime_Improved_APB"
df = pd.read_csv(f'{output_path}/D_D_Ask_daily_APB.csv')
df.rename(columns={'daily_APB':'D_D_Ask_daily_APB'},inplace=True)
df.to_csv(f'{output_path}/D_D_Ask_daily_APB.csv')


# stats = df['daily_APB'].describe()
# print(stats)
