# %%
import connectorx as cx
import pandas as pd
import numpy as np
import os
import duckdb
from datetime import datetime
import glob
import multiprocessing as mp
from functools import partial
import time

# %%
def calculate_daily_factor(trading_date):
    order_pth = f"/data/HighFreqData/Order/l2order/{pd.to_datetime(trading_date).strftime('%Y%m%d')}.parquet"

    if not os.path.exists(order_pth):
        raise FileNotFoundError(f"订单数据文件不存在: {order_pth}")

    conn = duckdb.connect(database=':memory:')

    query_order = f"""
        WITH buy_orders_with_time AS(
            SELECT 
                security_code,
                order_side, 
                order_type,
                order_details,
                order_price,
                order_price_adj,
                order_volume,
                order_time,
                ('{trading_date}'::DATE + MAKE_TIME(
                    FLOOR(order_time / 10000000)::int,
                    (FLOOR(order_time / 100000) % 100)::int,
                    (FLOOR(order_time / 1000) % 100)::numeric + 
                    (order_time % 1000)::numeric / 1000)
                )::TIMESTAMP AS formatted_time    -- 拼接成TIME格式

            FROM '{order_pth}'
            WHERE order_side = 1
                AND order_type = 'A'
                AND order_details = 'L'
                AND order_price > 0
                AND order_volume > 0
                AND order_time >= 93000000
                AND order_time < 145700000
        )
        SELECT
            security_code,
            order_price,
            order_price_adj,
            order_volume,
            DATE_TRUNC('minute', formatted_time) AS order_minute
        FROM buy_orders_with_time
        """

    # 将数据加载到临时表中
    conn.execute(f"CREATE TEMPORARY TABLE minute_order AS {query_order}")

    APB_query = """
        WITH buy_orders_with_time AS(
            SELECT 
                security_code,
                order_minute,
                SUM(order_volume * order_price) AS minute_turnover_value,
                SUM(order_volume) AS minute_turnover_volume,
                SUM(order_volume * order_price)/SUM(order_volume) AS minute_vwap
            FROM minute_order
            GROUP BY security_code, order_minute
        )
        SELECT
            security_code,
            SUM(minute_turnover_value)/SUM(minute_turnover_volume) AS vwap,
            AVG(minute_vwap) AS twap
        FROM buy_orders_with_time
        GROUP BY security_code
    """

    conn.execute(f"CREATE TEMPORARY TABLE order_value AS {APB_query}")

    # 计算因子
    APB_Factors = conn.execute("""
    SELECT 
        security_code,
        CASE 
            WHEN twap > 0 AND vwap > 0 THEN LN(twap / vwap)
            ELSE NULL
        END AS new_APB
    FROM order_value
    """).fetchdf()

    return APB_Factors

# %%
def derive_daily_factor (start_date, end_date, factor_name):
    
    #交易日列表
    trading_dates = pd.date_range(start=start_date, end=end_date, freq='B') 
    output_dir = f"./factors/{factor_name}"
    os.makedirs(output_dir, exist_ok=True)
    # 记录处理结果
    processed_dates = []
    skipped_dates = []
    
    for trading_date in trading_dates:
        date_str = trading_date.strftime('%Y%m%d')
        file_path = f"{output_dir}/{date_str}.parquet"
        
        # 如果文件已存在，跳过处理
        if os.path.exists(file_path):
            print(f"文件已存在，跳过: {file_path}")
            processed_dates.append(date_str)
            continue
        
        # 检查原始数据文件是否存在
        order_pth = f"/data/HighFreqData/Order/l2order/{date_str}.parquet"

        if not os.path.exists(order_pth):
            print(f"跳过日期 {date_str}: 订单数据文件不存在")
            skipped_dates.append(date_str)
            continue
        
        try:
            # 计算因子
            daily_factor_df = calculate_daily_factor(trading_date)
            
            # 添加日期列
            daily_factor_df['date'] = date_str
            
            # 保存结果
            daily_factor_df.to_parquet(file_path, index=False)
            print(f"已生成因子文件: {file_path}")
            processed_dates.append(date_str)
            
        except Exception as e:
            print(f"处理日期 {date_str} 时出错: {str(e)}")
            skipped_dates.append(date_str)
    
    # 打印处理结果摘要
    print(f"\n处理完成:")
    print(f"成功处理 {len(processed_dates)} 个日期")
    print(f"跳过 {len(skipped_dates)} 个日期")
    
    return output_dir

# %%
def calculate_rolling_20d_avg(factor_names, factor_dir, start_date=None, end_date=None, min_window=5):
    
    if not isinstance(factor_names, list):
        factor_names = [factor_names]
    
    parquet_pattern = os.path.join(factor_dir, "*.parquet")
    parquet_files = glob.glob(parquet_pattern)
    print(f"在目录 {factor_dir} 中找到 {len(parquet_files)} 个Parquet文件")
    

    conn = duckdb.connect(database=':memory:')
    all_factor_data = conn.execute(f"""
        SELECT * FROM read_parquet('{parquet_pattern}')
    """).fetchdf()
    conn.close()
    

    missing_factors = [f for f in factor_names if f not in all_factor_data.columns]
    if missing_factors:
        raise ValueError(f"在Parquet文件中未找到以下因子列: {', '.join(missing_factors)}")
    
    all_factor_data['date'] = pd.to_datetime(all_factor_data['date'])

    all_factor_data = all_factor_data.sort_values(['date', 'security_code'])
    
    # 筛选日期范围
    if start_date:
        start_date = pd.to_datetime(start_date)
        all_factor_data = all_factor_data[all_factor_data['date'] >= start_date]
    if end_date:
        end_date = pd.to_datetime(end_date)
        all_factor_data = all_factor_data[all_factor_data['date'] <= end_date]

    # 获取所有个股代码
    all_securities = all_factor_data['security_code'].unique()

    result_df = all_factor_data[['date', 'security_code']].copy()

    # 为每个因子计算滚动平均
    for factor_name in factor_names:
        print(f"\n处理因子: {factor_name}")
        
        #转置成宽表
        pivot_data = all_factor_data.pivot(index='date', columns='security_code', values=factor_name)

        # 对宽表直接应用rolling
        rolling_avg = pivot_data.rolling(window=20, min_periods=min_window).mean()

        # 将结果转换回长格式
        factor_df = rolling_avg.stack().reset_index()
        factor_df.columns = ['date', 'security_code', factor_name]
        # factor_df[factor_name] = - factor_df[factor_name]

        # 计算每日因子覆盖率
        # 计算每个日期非NaN的因子值数量
        non_nan_counts = factor_df.dropna(subset=[factor_name]).groupby('date').size()

        # 计算覆盖率
        coverage = non_nan_counts / len(all_securities)
        print(f"\n{factor_name}因子覆盖率统计: 平均={coverage.mean():.2f}, 最小={coverage.min():.2f}")

        result_df = pd.merge(
            result_df, 
            factor_df,
            on=['date', 'security_code'],
            how='left'
        )
    
    return result_df

# %%
def process_single_date(trading_date, factor_name):
    
    """处理单个交易日的函数"""
   
    date_str = trading_date.strftime('%Y%m%d')
    output_dir = f"./factors/{factor_name}"
    file_path = f"{output_dir}/{date_str}.parquet"
    
    # 如果文件已存在，跳过处理
    if os.path.exists(file_path):
        print(f"文件已存在，跳过: {file_path}")
        return date_str, True, "已存在"
    
    # 检查原始数据文件是否存在
    data_file = f"/data/HighFreqData/Order/l2order/{date_str}.parquet"
    if not os.path.exists(data_file):
        print(f"跳过日期 {date_str}: 原始数据文件不存在")
        return date_str, False, "数据文件不存在"
    
    try:
        daily_factor_df = calculate_daily_factor(trading_date)
        
        daily_factor_df['date'] = date_str

        daily_factor_df.to_parquet(file_path, index=False)
        print(f"已生成因子文件: {file_path}")
        return date_str, True, "成功"
        
    except Exception as e:
        error_msg = str(e)
        print(f"处理日期 {date_str} 时出错: {error_msg}")
        return date_str, False, error_msg


def derive_daily_factor(start_date, end_date, factor_name, num_processes=30):
    start_time = time.time()
    
    trading_dates = pd.date_range(start=start_date, end=end_date, freq='B')
    
    # 创建输出目录
    output_dir = f"./factors/{factor_name}"
    os.makedirs(output_dir, exist_ok=True)
    
    # 创建进程池
    pool = mp.Pool(processes=num_processes)
    
    # 创建带有固定参数的处理函数
    process_date_with_args = partial(process_single_date, factor_name=factor_name)
    
    # 提交所有任务到进程池并获取结果
    print(f"开始使用 {num_processes} 个进程并行处理 {len(trading_dates)} 个交易日...")
    results = pool.map(process_date_with_args, trading_dates)
    
    # 关闭进程池
    pool.close()
    pool.join()
    
    # 分析处理结果
    processed_dates = [date_str for date_str, success, _ in results if success]
    skipped_dates = [date_str for date_str, success, _ in results if not success]
    
    # 打印处理结果摘要
    print(f"\n处理完成:")
    print(f"成功处理 {len(processed_dates)} 个日期")
    print(f"跳过 {len(skipped_dates)} 个日期")

    return output_dir

# %%
def main():

    start_date = '2021-05-18'
    end_date = '2024-12-31'

    factor_name = "raw_order_APB"
    
    factor_dir = derive_daily_factor (start_date, end_date, factor_name)
    print(f"所有因子文件已生成在目录: {factor_dir}")

    factor_name = ['new_APB']

    result_df = calculate_rolling_20d_avg(factor_name, factor_dir, start_date, end_date, min_window=5)
    
    # 保存结果为CSV
    output_path = "/data/home/lexuanchen/Factors/Order/Signal/Improved_APB"
    os.makedirs(output_path, exist_ok=True)

    result_df.to_csv(f'{output_path}/raw_order_APB.csv')

    print(f"共计 {len(result_df)} 条记录")

    print("\n数据预览:")
    print(result_df.head())

# 执行主函数
if __name__ == "__main__":
    main()
# Out:
# 文件已存在，跳过: ./factors/raw_order_APB/20210518.parquet文件已存在，跳过: ./factors/raw_order_APB/20210528.parquet文件已存在，跳过: ./factors/raw_order_APB/20210609.parquet文件已存在，跳过: ./factors/raw_order_APB/20210713.parquet文件已存在，跳过: ./factors/raw_order_APB/20210621.parquet文件已存在，跳过: ./factors/raw_order_APB/20210701.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20210723.parquet文件已存在，跳过: ./factors/raw_order_APB/20210804.parquet文件已存在，跳过: ./factors/raw_order_APB/20210826.parquet文件已存在，跳过: ./factors/raw_order_APB/20210816.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210929.parquet文件已存在，跳过: ./factors/raw_order_APB/20210907.parquet文件已存在，跳过: ./factors/raw_order_APB/20211011.parquet文件已存在，跳过: ./factors/raw_order_APB/20211102.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20211112.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20210519.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20211124.parquet文件已存在，跳过: ./factors/raw_order_APB/20211216.parquet文件已存在，跳过: ./factors/raw_order_APB/20220107.parquet
# 跳过日期 20211228: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20220119.parquet跳过日期 20211206: 原始数据文件不存在
#
# 跳过日期 20210917: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20210531.parquet文件已存在，跳过: ./factors/raw_order_APB/20210610.parquet跳过日期 20211021: 原始数据文件不存在
# 文件已存在，跳过: ./factors/raw_order_APB/20220222.parquet文件已存在，跳过: ./factors/raw_order_APB/20220316.parquet文件已存在，跳过: ./factors/raw_order_APB/20210702.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220328.parquet文件已存在，跳过: ./factors/raw_order_APB/20220407.parquet文件已存在，跳过: ./factors/raw_order_APB/20220304.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210622.parquet
# 跳过日期 20210714: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20210805.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210827.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20210726.parquet
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210817.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210930.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210908.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211012.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20211103.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210520.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211115.parquet文件已存在，跳过: ./factors/raw_order_APB/20211125.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211217.parquet文件已存在，跳过: ./factors/raw_order_APB/20220110.parquet文件已存在，跳过: ./factors/raw_order_APB/20211229.parquet文件已存在，跳过: ./factors/raw_order_APB/20210601.parquet文件已存在，跳过: ./factors/raw_order_APB/20210611.parquet文件已存在，跳过: ./factors/raw_order_APB/20220120.parquet跳过日期 20211207: 原始数据文件不存在
# 跳过日期 20210920: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20210705.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20211022.parquet文件已存在，跳过: ./factors/raw_order_APB/20220223.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220329.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220317.parquet文件已存在，跳过: ./factors/raw_order_APB/20220408.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20210623.parquet文件已存在，跳过: ./factors/raw_order_APB/20220307.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20210715.parquet文件已存在，跳过: ./factors/raw_order_APB/20210806.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210830.parquet文件已存在，跳过: ./factors/raw_order_APB/20210727.parquet
#
#
#
#
#
#
#
# 跳过日期 20210818: 原始数据文件不存在
# 跳过日期 20211001: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211013.parquet文件已存在，跳过: ./factors/raw_order_APB/20210909.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211104.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210521.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211116.parquet文件已存在，跳过: ./factors/raw_order_APB/20211126.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211220.parquet文件已存在，跳过: ./factors/raw_order_APB/20220111.parquet文件已存在，跳过: ./factors/raw_order_APB/20211230.parquet文件已存在，跳过: ./factors/raw_order_APB/20210602.parquet跳过日期 20210614: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20220121.parquet文件已存在，跳过: ./factors/raw_order_APB/20211208.parquet跳过日期 20210921: 原始数据文件不存在
# 文件已存在，跳过: ./factors/raw_order_APB/20210706.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20211025.parquet文件已存在，跳过: ./factors/raw_order_APB/20220224.parquet文件已存在，跳过: ./factors/raw_order_APB/20220330.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220318.parquet文件已存在，跳过: ./factors/raw_order_APB/20220411.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20210624.parquet文件已存在，跳过: ./factors/raw_order_APB/20220308.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20210716.parquet文件已存在，跳过: ./factors/raw_order_APB/20210809.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210831.parquet文件已存在，跳过: ./factors/raw_order_APB/20210728.parquet
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210819.parquet跳过日期 20211004: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211014.parquet文件已存在，跳过: ./factors/raw_order_APB/20210910.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211105.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210524.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211117.parquet文件已存在，跳过: ./factors/raw_order_APB/20211129.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211221.parquet文件已存在，跳过: ./factors/raw_order_APB/20220112.parquet文件已存在，跳过: ./factors/raw_order_APB/20211231.parquet文件已存在，跳过: ./factors/raw_order_APB/20210603.parquet文件已存在，跳过: ./factors/raw_order_APB/20210615.parquet文件已存在，跳过: ./factors/raw_order_APB/20220124.parquet文件已存在，跳过: ./factors/raw_order_APB/20211209.parquet文件已存在，跳过: ./factors/raw_order_APB/20210922.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210707.parquet文件已存在，跳过: ./factors/raw_order_APB/20211026.parquet文件已存在，跳过: ./factors/raw_order_APB/20220225.parquet文件已存在，跳过: ./factors/raw_order_APB/20220331.parquet跳过日期 20220131: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220321.parquet文件已存在，跳过: ./factors/raw_order_APB/20220412.parquet文件已存在，跳过: ./factors/raw_order_APB/20220210.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20210625.parquet文件已存在，跳过: ./factors/raw_order_APB/20220309.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20210719.parquet文件已存在，跳过: ./factors/raw_order_APB/20210810.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210901.parquet文件已存在，跳过: ./factors/raw_order_APB/20210729.parquet
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210820.parquet跳过日期 20211005: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211015.parquet文件已存在，跳过: ./factors/raw_order_APB/20210913.parquet
#
#
# 跳过日期 20211108: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210525.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211118.parquet跳过日期 20211130: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211222.parquet文件已存在，跳过: ./factors/raw_order_APB/20220113.parquet跳过日期 20220103: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20210604.parquet文件已存在，跳过: ./factors/raw_order_APB/20210616.parquet文件已存在，跳过: ./factors/raw_order_APB/20220125.parquet文件已存在，跳过: ./factors/raw_order_APB/20211210.parquet文件已存在，跳过: ./factors/raw_order_APB/20210923.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210708.parquet文件已存在，跳过: ./factors/raw_order_APB/20211027.parquet文件已存在，跳过: ./factors/raw_order_APB/20220228.parquet文件已存在，跳过: ./factors/raw_order_APB/20220401.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220413.parquet文件已存在，跳过: ./factors/raw_order_APB/20220322.parquet跳过日期 20220201: 原始数据文件不存在
# 文件已存在，跳过: ./factors/raw_order_APB/20210628.parquet文件已存在，跳过: ./factors/raw_order_APB/20220310.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20210720.parquet文件已存在，跳过: ./factors/raw_order_APB/20220211.parquet文件已存在，跳过: ./factors/raw_order_APB/20210811.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210730.parquet文件已存在，跳过: ./factors/raw_order_APB/20210902.parquet
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210823.parquet跳过日期 20211006: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211018.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20210914.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211109.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210526.parquet
#
#
# 跳过日期 20211119: 原始数据文件不存在
# 文件已存在，跳过: ./factors/raw_order_APB/20211201.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20211223.parquet文件已存在，跳过: ./factors/raw_order_APB/20220114.parquet文件已存在，跳过: ./factors/raw_order_APB/20220104.parquet文件已存在，跳过: ./factors/raw_order_APB/20210617.parquet文件已存在，跳过: ./factors/raw_order_APB/20210607.parquet文件已存在，跳过: ./factors/raw_order_APB/20220126.parquet文件已存在，跳过: ./factors/raw_order_APB/20211213.parquet文件已存在，跳过: ./factors/raw_order_APB/20210924.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210709.parquet文件已存在，跳过: ./factors/raw_order_APB/20211028.parquet文件已存在，跳过: ./factors/raw_order_APB/20220301.parquet
# 跳过日期 20220404: 原始数据文件不存在
# 文件已存在，跳过: ./factors/raw_order_APB/20220323.parquet文件已存在，跳过: ./factors/raw_order_APB/20220414.parquet跳过日期 20220202: 原始数据文件不存在
# 文件已存在，跳过: ./factors/raw_order_APB/20210629.parquet文件已存在，跳过: ./factors/raw_order_APB/20220311.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20210721.parquet文件已存在，跳过: ./factors/raw_order_APB/20220214.parquet文件已存在，跳过: ./factors/raw_order_APB/20210812.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20210802.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20210903.parquet
#
#
#
#
#
#
#
#
# 跳过日期 20211007: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20210824.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211019.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210915.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211110.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210527.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211122.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20211202.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20211224.parquet文件已存在，跳过: ./factors/raw_order_APB/20220117.parquet文件已存在，跳过: ./factors/raw_order_APB/20220105.parquet文件已存在，跳过: ./factors/raw_order_APB/20210618.parquet文件已存在，跳过: ./factors/raw_order_APB/20210608.parquet文件已存在，跳过: ./factors/raw_order_APB/20220127.parquet文件已存在，跳过: ./factors/raw_order_APB/20210927.parquet文件已存在，跳过: ./factors/raw_order_APB/20211214.parquet文件已存在，跳过: ./factors/raw_order_APB/20210712.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211029.parquet文件已存在，跳过: ./factors/raw_order_APB/20220302.parquet
# 跳过日期 20220405: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20220324.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220415.parquet跳过日期 20220203: 原始数据文件不存在
# 文件已存在，跳过: ./factors/raw_order_APB/20210630.parquet文件已存在，跳过: ./factors/raw_order_APB/20220314.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20210722.parquet文件已存在，跳过: ./factors/raw_order_APB/20210813.parquet文件已存在，跳过: ./factors/raw_order_APB/20220215.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20210803.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20210906.parquet
#
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211008.parquet文件已存在，跳过: ./factors/raw_order_APB/20210825.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211020.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20210916.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211111.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220419.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20211203.parquet文件已存在，跳过: ./factors/raw_order_APB/20211123.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20211227.parquet文件已存在，跳过: ./factors/raw_order_APB/20220118.parquet文件已存在，跳过: ./factors/raw_order_APB/20220106.parquet文件已存在，跳过: ./factors/raw_order_APB/20220429.parquet文件已存在，跳过: ./factors/raw_order_APB/20220128.parquet文件已存在，跳过: ./factors/raw_order_APB/20220511.parquet文件已存在，跳过: ./factors/raw_order_APB/20210928.parquet文件已存在，跳过: ./factors/raw_order_APB/20211215.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220523.parquet文件已存在，跳过: ./factors/raw_order_APB/20211101.parquet文件已存在，跳过: ./factors/raw_order_APB/20220303.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220406.parquet文件已存在，跳过: ./factors/raw_order_APB/20220325.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220418.parquet跳过日期 20220204: 原始数据文件不存在
# 文件已存在，跳过: ./factors/raw_order_APB/20220602.parquet文件已存在，跳过: ./factors/raw_order_APB/20220315.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220614.parquet文件已存在，跳过: ./factors/raw_order_APB/20220216.parquet文件已存在，跳过: ./factors/raw_order_APB/20220624.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220706.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220718.parquet
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220728.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220809.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220819.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220831.parquet
#
# 跳过日期 20220912: 原始数据文件不存在
# 文件已存在，跳过: ./factors/raw_order_APB/20220420.parquet
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220922.parquet
# 跳过日期 20221004: 原始数据文件不存在跳过日期 20221014: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20221026.parquet跳过日期 20220502: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20221107.parquet文件已存在，跳过: ./factors/raw_order_APB/20220512.parquet文件已存在，跳过: ./factors/raw_order_APB/20221117.parquet文件已存在，跳过: ./factors/raw_order_APB/20221129.parquet文件已存在，跳过: ./factors/raw_order_APB/20220524.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20221209.parquet文件已存在，跳过: ./factors/raw_order_APB/20221221.parquet跳过日期 20230102: 原始数据文件不存在
# 文件已存在，跳过: ./factors/raw_order_APB/20230112.parquet
# 跳过日期 20230124: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20230203.parquet跳过日期 20220207: 原始数据文件不存在跳过日期 20220603: 原始数据文件不存在
# 文件已存在，跳过: ./factors/raw_order_APB/20230215.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220217.parquet文件已存在，跳过: ./factors/raw_order_APB/20220615.parquet文件已存在，跳过: ./factors/raw_order_APB/20220627.parquet文件已存在，跳过: ./factors/raw_order_APB/20220707.parquet文件已存在，跳过: ./factors/raw_order_APB/20220719.parquet
#
#
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220729.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220810.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220822.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220901.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220913.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220421.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220923.parquet跳过日期 20221005: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20221017.parquet文件已存在，跳过: ./factors/raw_order_APB/20221027.parquet跳过日期 20220503: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20221108.parquet文件已存在，跳过: ./factors/raw_order_APB/20220513.parquet文件已存在，跳过: ./factors/raw_order_APB/20221118.parquet文件已存在，跳过: ./factors/raw_order_APB/20221130.parquet文件已存在，跳过: ./factors/raw_order_APB/20220525.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20221212.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20221222.parquet文件已存在，跳过: ./factors/raw_order_APB/20230103.parquet文件已存在，跳过: ./factors/raw_order_APB/20230113.parquet跳过日期 20230125: 原始数据文件不存在
# 文件已存在，跳过: ./factors/raw_order_APB/20230206.parquet文件已存在，跳过: ./factors/raw_order_APB/20220208.parquet文件已存在，跳过: ./factors/raw_order_APB/20220606.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230216.parquet文件已存在，跳过: ./factors/raw_order_APB/20220616.parquet文件已存在，跳过: ./factors/raw_order_APB/20220628.parquet文件已存在，跳过: ./factors/raw_order_APB/20220218.parquet文件已存在，跳过: ./factors/raw_order_APB/20220720.parquet文件已存在，跳过: ./factors/raw_order_APB/20220708.parquet
#
#
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220801.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220811.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220823.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220902.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220914.parquet文件已存在，跳过: ./factors/raw_order_APB/20220422.parquet
#
#
#
#
#
# 跳过日期 20220926: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20221018.parquet跳过日期 20221006: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20221028.parquet跳过日期 20220504: 原始数据文件不存在跳过日期 20221109: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20220516.parquet文件已存在，跳过: ./factors/raw_order_APB/20221121.parquet文件已存在，跳过: ./factors/raw_order_APB/20221201.parquet文件已存在，跳过: ./factors/raw_order_APB/20220526.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20221213.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20221223.parquet文件已存在，跳过: ./factors/raw_order_APB/20230104.parquet跳过日期 20230126: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20230116.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230207.parquet文件已存在，跳过: ./factors/raw_order_APB/20220209.parquet文件已存在，跳过: ./factors/raw_order_APB/20220607.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230217.parquet文件已存在，跳过: ./factors/raw_order_APB/20220617.parquet文件已存在，跳过: ./factors/raw_order_APB/20220221.parquet文件已存在，跳过: ./factors/raw_order_APB/20220629.parquet文件已存在，跳过: ./factors/raw_order_APB/20220721.parquet文件已存在，跳过: ./factors/raw_order_APB/20220711.parquet
#
#
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220802.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220812.parquet文件已存在，跳过: ./factors/raw_order_APB/20220824.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220905.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220915.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220425.parquet
#
#
#
#
# 跳过日期 20221019: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20220927.parquet跳过日期 20221007: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20221031.parquet文件已存在，跳过: ./factors/raw_order_APB/20220505.parquet文件已存在，跳过: ./factors/raw_order_APB/20221110.parquet文件已存在，跳过: ./factors/raw_order_APB/20220517.parquet文件已存在，跳过: ./factors/raw_order_APB/20221122.parquet文件已存在，跳过: ./factors/raw_order_APB/20221202.parquet文件已存在，跳过: ./factors/raw_order_APB/20220527.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20221214.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20221226.parquet文件已存在，跳过: ./factors/raw_order_APB/20230105.parquet跳过日期 20230127: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20230117.parquet文件已存在，跳过: ./factors/raw_order_APB/20230208.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220608.parquet文件已存在，跳过: ./factors/raw_order_APB/20230227.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230220.parquet文件已存在，跳过: ./factors/raw_order_APB/20220620.parquet文件已存在，跳过: ./factors/raw_order_APB/20220630.parquet文件已存在，跳过: ./factors/raw_order_APB/20230309.parquet文件已存在，跳过: ./factors/raw_order_APB/20220712.parquet文件已存在，跳过: ./factors/raw_order_APB/20220722.parquet
#
#
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220803.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220825.parquet文件已存在，跳过: ./factors/raw_order_APB/20220815.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220906.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220426.parquet文件已存在，跳过: ./factors/raw_order_APB/20220916.parquet
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20221020.parquet文件已存在，跳过: ./factors/raw_order_APB/20220928.parquet文件已存在，跳过: ./factors/raw_order_APB/20221010.parquet文件已存在，跳过: ./factors/raw_order_APB/20221101.parquet文件已存在，跳过: ./factors/raw_order_APB/20220506.parquet文件已存在，跳过: ./factors/raw_order_APB/20221111.parquet文件已存在，跳过: ./factors/raw_order_APB/20220518.parquet文件已存在，跳过: ./factors/raw_order_APB/20221123.parquet文件已存在，跳过: ./factors/raw_order_APB/20221205.parquet文件已存在，跳过: ./factors/raw_order_APB/20220530.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20221215.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20221227.parquet文件已存在，跳过: ./factors/raw_order_APB/20230106.parquet文件已存在，跳过: ./factors/raw_order_APB/20230130.parquet文件已存在，跳过: ./factors/raw_order_APB/20230118.parquet文件已存在，跳过: ./factors/raw_order_APB/20230209.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220609.parquet文件已存在，跳过: ./factors/raw_order_APB/20230228.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230221.parquet文件已存在，跳过: ./factors/raw_order_APB/20220621.parquet文件已存在，跳过: ./factors/raw_order_APB/20220701.parquet文件已存在，跳过: ./factors/raw_order_APB/20220725.parquet文件已存在，跳过: ./factors/raw_order_APB/20230310.parquet文件已存在，跳过: ./factors/raw_order_APB/20220713.parquet
#
#
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220804.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220826.parquet文件已存在，跳过: ./factors/raw_order_APB/20220816.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220907.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220919.parquet文件已存在，跳过: ./factors/raw_order_APB/20220427.parquet
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20221021.parquet跳过日期 20220929: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20221011.parquet文件已存在，跳过: ./factors/raw_order_APB/20221102.parquet文件已存在，跳过: ./factors/raw_order_APB/20220509.parquet文件已存在，跳过: ./factors/raw_order_APB/20220519.parquet文件已存在，跳过: ./factors/raw_order_APB/20221114.parquet文件已存在，跳过: ./factors/raw_order_APB/20221124.parquet文件已存在，跳过: ./factors/raw_order_APB/20221206.parquet文件已存在，跳过: ./factors/raw_order_APB/20220531.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20221216.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20221228.parquet文件已存在，跳过: ./factors/raw_order_APB/20230109.parquet文件已存在，跳过: ./factors/raw_order_APB/20230131.parquet文件已存在，跳过: ./factors/raw_order_APB/20230119.parquet文件已存在，跳过: ./factors/raw_order_APB/20230210.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220610.parquet文件已存在，跳过: ./factors/raw_order_APB/20230301.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230222.parquet文件已存在，跳过: ./factors/raw_order_APB/20220622.parquet文件已存在，跳过: ./factors/raw_order_APB/20220704.parquet文件已存在，跳过: ./factors/raw_order_APB/20220726.parquet文件已存在，跳过: ./factors/raw_order_APB/20220714.parquet文件已存在，跳过: ./factors/raw_order_APB/20230313.parquet
#
#
#
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220805.parquet文件已存在，跳过: ./factors/raw_order_APB/20220829.parquet文件已存在，跳过: ./factors/raw_order_APB/20220817.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220908.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220920.parquet文件已存在，跳过: ./factors/raw_order_APB/20220428.parquet
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20221024.parquet文件已存在，跳过: ./factors/raw_order_APB/20220930.parquet文件已存在，跳过: ./factors/raw_order_APB/20221012.parquet文件已存在，跳过: ./factors/raw_order_APB/20221103.parquet文件已存在，跳过: ./factors/raw_order_APB/20220510.parquet文件已存在，跳过: ./factors/raw_order_APB/20220520.parquet文件已存在，跳过: ./factors/raw_order_APB/20221115.parquet文件已存在，跳过: ./factors/raw_order_APB/20221125.parquet文件已存在，跳过: ./factors/raw_order_APB/20221207.parquet文件已存在，跳过: ./factors/raw_order_APB/20220601.parquet文件已存在，跳过: ./factors/raw_order_APB/20221219.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20221229.parquet文件已存在，跳过: ./factors/raw_order_APB/20230110.parquet文件已存在，跳过: ./factors/raw_order_APB/20230201.parquet文件已存在，跳过: ./factors/raw_order_APB/20230120.parquet文件已存在，跳过: ./factors/raw_order_APB/20230213.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220613.parquet文件已存在，跳过: ./factors/raw_order_APB/20230302.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230223.parquet文件已存在，跳过: ./factors/raw_order_APB/20220623.parquet文件已存在，跳过: ./factors/raw_order_APB/20220705.parquet文件已存在，跳过: ./factors/raw_order_APB/20220727.parquet文件已存在，跳过: ./factors/raw_order_APB/20220715.parquet文件已存在，跳过: ./factors/raw_order_APB/20230314.parquet
#
#
#
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220808.parquet文件已存在，跳过: ./factors/raw_order_APB/20220830.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20220818.parquet
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220909.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20220921.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230321.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20221025.parquet跳过日期 20221003: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20221013.parquet文件已存在，跳过: ./factors/raw_order_APB/20221104.parquet跳过日期 20230331: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20221116.parquet文件已存在，跳过: ./factors/raw_order_APB/20230412.parquet文件已存在，跳过: ./factors/raw_order_APB/20221128.parquet文件已存在，跳过: ./factors/raw_order_APB/20221208.parquet文件已存在，跳过: ./factors/raw_order_APB/20221220.parquet文件已存在，跳过: ./factors/raw_order_APB/20230424.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20221230.parquet文件已存在，跳过: ./factors/raw_order_APB/20230202.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230111.parquet跳过日期 20230123: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20230214.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230303.parquet文件已存在，跳过: ./factors/raw_order_APB/20230504.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230224.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230516.parquet文件已存在，跳过: ./factors/raw_order_APB/20230526.parquet文件已存在，跳过: ./factors/raw_order_APB/20230619.parquet文件已存在，跳过: ./factors/raw_order_APB/20230315.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230607.parquet
#
#
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230629.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230711.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230721.parquet
#
#
# 跳过日期 20230802: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230814.parquet文件已存在，跳过: ./factors/raw_order_APB/20230322.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230824.parquet文件已存在，跳过: ./factors/raw_order_APB/20230905.parquet文件已存在，跳过: ./factors/raw_order_APB/20230915.parquet文件已存在，跳过: ./factors/raw_order_APB/20230927.parquet文件已存在，跳过: ./factors/raw_order_APB/20230403.parquet文件已存在，跳过: ./factors/raw_order_APB/20230413.parquet文件已存在，跳过: ./factors/raw_order_APB/20231009.parquet文件已存在，跳过: ./factors/raw_order_APB/20231031.parquet文件已存在，跳过: ./factors/raw_order_APB/20231019.parquet文件已存在，跳过: ./factors/raw_order_APB/20230425.parquet文件已存在，跳过: ./factors/raw_order_APB/20231110.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20231122.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20231204.parquet文件已存在，跳过: ./factors/raw_order_APB/20231214.parquet文件已存在，跳过: ./factors/raw_order_APB/20231226.parquet文件已存在，跳过: ./factors/raw_order_APB/20240105.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230306.parquet文件已存在，跳过: ./factors/raw_order_APB/20230505.parquet文件已存在，跳过: ./factors/raw_order_APB/20240117.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230517.parquet文件已存在，跳过: ./factors/raw_order_APB/20230529.parquet文件已存在，跳过: ./factors/raw_order_APB/20230620.parquet文件已存在，跳过: ./factors/raw_order_APB/20230316.parquet文件已存在，跳过: ./factors/raw_order_APB/20230608.parquet
#
#
#
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230630.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230712.parquet文件已存在，跳过: ./factors/raw_order_APB/20230724.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230803.parquet
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230815.parquet文件已存在，跳过: ./factors/raw_order_APB/20230323.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230825.parquet文件已存在，跳过: ./factors/raw_order_APB/20230906.parquet文件已存在，跳过: ./factors/raw_order_APB/20230918.parquet文件已存在，跳过: ./factors/raw_order_APB/20230928.parquet文件已存在，跳过: ./factors/raw_order_APB/20230404.parquet文件已存在，跳过: ./factors/raw_order_APB/20230414.parquet文件已存在，跳过: ./factors/raw_order_APB/20231010.parquet文件已存在，跳过: ./factors/raw_order_APB/20231101.parquet文件已存在，跳过: ./factors/raw_order_APB/20231020.parquet文件已存在，跳过: ./factors/raw_order_APB/20230426.parquet文件已存在，跳过: ./factors/raw_order_APB/20231113.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20231123.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20231205.parquet文件已存在，跳过: ./factors/raw_order_APB/20231215.parquet文件已存在，跳过: ./factors/raw_order_APB/20231227.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240108.parquet文件已存在，跳过: ./factors/raw_order_APB/20230307.parquet文件已存在，跳过: ./factors/raw_order_APB/20230508.parquet文件已存在，跳过: ./factors/raw_order_APB/20240118.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230518.parquet文件已存在，跳过: ./factors/raw_order_APB/20230530.parquet文件已存在，跳过: ./factors/raw_order_APB/20230621.parquet文件已存在，跳过: ./factors/raw_order_APB/20230317.parquet文件已存在，跳过: ./factors/raw_order_APB/20230609.parquet
#
#
#
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230703.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230713.parquet文件已存在，跳过: ./factors/raw_order_APB/20230725.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230804.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230816.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230324.parquet
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230828.parquet文件已存在，跳过: ./factors/raw_order_APB/20230907.parquet文件已存在，跳过: ./factors/raw_order_APB/20230919.parquet跳过日期 20230929: 原始数据文件不存在跳过日期 20230405: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20230417.parquet文件已存在，跳过: ./factors/raw_order_APB/20231011.parquet文件已存在，跳过: ./factors/raw_order_APB/20231102.parquet文件已存在，跳过: ./factors/raw_order_APB/20231023.parquet文件已存在，跳过: ./factors/raw_order_APB/20230427.parquet文件已存在，跳过: ./factors/raw_order_APB/20231114.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20231124.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20231206.parquet文件已存在，跳过: ./factors/raw_order_APB/20231218.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20231228.parquet文件已存在，跳过: ./factors/raw_order_APB/20240109.parquet文件已存在，跳过: ./factors/raw_order_APB/20230308.parquet文件已存在，跳过: ./factors/raw_order_APB/20230509.parquet跳过日期 20240119: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230519.parquet跳过日期 20230622: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20230531.parquet文件已存在，跳过: ./factors/raw_order_APB/20230320.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230612.parquet
#
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230704.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230714.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230726.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230807.parquet
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230817.parquet文件已存在，跳过: ./factors/raw_order_APB/20230327.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230829.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230908.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230920.parquet跳过日期 20231002: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20230406.parquet文件已存在，跳过: ./factors/raw_order_APB/20230418.parquet文件已存在，跳过: ./factors/raw_order_APB/20231012.parquet文件已存在，跳过: ./factors/raw_order_APB/20231103.parquet文件已存在，跳过: ./factors/raw_order_APB/20231024.parquet文件已存在，跳过: ./factors/raw_order_APB/20230428.parquet文件已存在，跳过: ./factors/raw_order_APB/20231115.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20231127.parquet文件已存在，跳过: ./factors/raw_order_APB/20231207.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20231219.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20231229.parquet文件已存在，跳过: ./factors/raw_order_APB/20240110.parquet文件已存在，跳过: ./factors/raw_order_APB/20240129.parquet文件已存在，跳过: ./factors/raw_order_APB/20230510.parquet文件已存在，跳过: ./factors/raw_order_APB/20240122.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230522.parquet
# 跳过日期 20230623: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20230601.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240208.parquet文件已存在，跳过: ./factors/raw_order_APB/20230613.parquet
#
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230705.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230717.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230727.parquet文件已存在，跳过: ./factors/raw_order_APB/20230808.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230818.parquet
# 跳过日期 20230328: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230830.parquet文件已存在，跳过: ./factors/raw_order_APB/20230911.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230921.parquet跳过日期 20231003: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20230407.parquet文件已存在，跳过: ./factors/raw_order_APB/20230419.parquet文件已存在，跳过: ./factors/raw_order_APB/20231013.parquet文件已存在，跳过: ./factors/raw_order_APB/20231106.parquet文件已存在，跳过: ./factors/raw_order_APB/20231025.parquet文件已存在，跳过: ./factors/raw_order_APB/20231116.parquet跳过日期 20230501: 原始数据文件不存在
# 文件已存在，跳过: ./factors/raw_order_APB/20231128.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20231220.parquet文件已存在，跳过: ./factors/raw_order_APB/20231208.parquet
#
# 跳过日期 20240101: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20240111.parquet文件已存在，跳过: ./factors/raw_order_APB/20240130.parquet文件已存在，跳过: ./factors/raw_order_APB/20230511.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240123.parquet文件已存在，跳过: ./factors/raw_order_APB/20230523.parquet文件已存在，跳过: ./factors/raw_order_APB/20230626.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230602.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230614.parquet跳过日期 20240209: 原始数据文件不存在
#
#
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230706.parquet文件已存在，跳过: ./factors/raw_order_APB/20230718.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230728.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230809.parquet
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230821.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230329.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230912.parquet文件已存在，跳过: ./factors/raw_order_APB/20230831.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230922.parquet跳过日期 20231004: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20230410.parquet跳过日期 20230420: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20231016.parquet文件已存在，跳过: ./factors/raw_order_APB/20231107.parquet文件已存在，跳过: ./factors/raw_order_APB/20231117.parquet文件已存在，跳过: ./factors/raw_order_APB/20231026.parquet文件已存在，跳过: ./factors/raw_order_APB/20231129.parquet跳过日期 20230502: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/raw_order_APB/20231221.parquet文件已存在，跳过: ./factors/raw_order_APB/20231211.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240102.parquet文件已存在，跳过: ./factors/raw_order_APB/20240112.parquet文件已存在，跳过: ./factors/raw_order_APB/20240131.parquet文件已存在，跳过: ./factors/raw_order_APB/20230512.parquet文件已存在，跳过: ./factors/raw_order_APB/20240124.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230524.parquet文件已存在，跳过: ./factors/raw_order_APB/20230627.parquet文件已存在，跳过: ./factors/raw_order_APB/20230605.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230615.parquet跳过日期 20240212: 原始数据文件不存在
#
#
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230707.parquet文件已存在，跳过: ./factors/raw_order_APB/20230719.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230731.parquet文件已存在，跳过: ./factors/raw_order_APB/20230810.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230822.parquet
#
#
# 跳过日期 20230330: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20230913.parquet文件已存在，跳过: ./factors/raw_order_APB/20230901.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230925.parquet跳过日期 20231005: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20230411.parquet文件已存在，跳过: ./factors/raw_order_APB/20231017.parquet文件已存在，跳过: ./factors/raw_order_APB/20230421.parquet文件已存在，跳过: ./factors/raw_order_APB/20231108.parquet文件已存在，跳过: ./factors/raw_order_APB/20231120.parquet文件已存在，跳过: ./factors/raw_order_APB/20231027.parquet文件已存在，跳过: ./factors/raw_order_APB/20231130.parquet
# 跳过日期 20230503: 原始数据文件不存在
# 文件已存在，跳过: ./factors/raw_order_APB/20231222.parquet文件已存在，跳过: ./factors/raw_order_APB/20231212.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240103.parquet文件已存在，跳过: ./factors/raw_order_APB/20240115.parquet文件已存在，跳过: ./factors/raw_order_APB/20240201.parquet文件已存在，跳过: ./factors/raw_order_APB/20230515.parquet文件已存在，跳过: ./factors/raw_order_APB/20240125.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230525.parquet文件已存在，跳过: ./factors/raw_order_APB/20230628.parquet文件已存在，跳过: ./factors/raw_order_APB/20230606.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230616.parquet
# 跳过日期 20240213: 原始数据文件不存在
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230720.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230710.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230801.parquet文件已存在，跳过: ./factors/raw_order_APB/20230811.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230823.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20230914.parquet文件已存在，跳过: ./factors/raw_order_APB/20230904.parquet文件已存在，跳过: ./factors/raw_order_APB/20240220.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20230926.parquet
# 跳过日期 20231006: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20240301.parquet文件已存在，跳过: ./factors/raw_order_APB/20231121.parquet文件已存在，跳过: ./factors/raw_order_APB/20240313.parquet文件已存在，跳过: ./factors/raw_order_APB/20231018.parquet文件已存在，跳过: ./factors/raw_order_APB/20231109.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20231030.parquet文件已存在，跳过: ./factors/raw_order_APB/20231201.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240325.parquet文件已存在，跳过: ./factors/raw_order_APB/20231225.parquet文件已存在，跳过: ./factors/raw_order_APB/20231213.parquet
#
# 跳过日期 20240104: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20240116.parquet文件已存在，跳过: ./factors/raw_order_APB/20240202.parquet文件已存在，跳过: ./factors/raw_order_APB/20240126.parquet跳过日期 20240404: 原始数据文件不存在
# 文件已存在，跳过: ./factors/raw_order_APB/20240416.parquet文件已存在，跳过: ./factors/raw_order_APB/20240426.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240508.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240520.parquet跳过日期 20240214: 原始数据文件不存在
#
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240530.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240611.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240621.parquet文件已存在，跳过: ./factors/raw_order_APB/20240703.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240715.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240725.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240806.parquet文件已存在，跳过: ./factors/raw_order_APB/20240221.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240816.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240828.parquet文件已存在，跳过: ./factors/raw_order_APB/20240304.parquet文件已存在，跳过: ./factors/raw_order_APB/20240314.parquet文件已存在，跳过: ./factors/raw_order_APB/20240909.parquet文件已存在，跳过: ./factors/raw_order_APB/20240919.parquet跳过日期 20241001: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20241023.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20241011.parquet文件已存在，跳过: ./factors/raw_order_APB/20240326.parquet文件已存在，跳过: ./factors/raw_order_APB/20241104.parquet文件已存在，跳过: ./factors/raw_order_APB/20241114.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20241126.parquet文件已存在，跳过: ./factors/raw_order_APB/20241206.parquet文件已存在，跳过: ./factors/raw_order_APB/20240205.parquet文件已存在，跳过: ./factors/raw_order_APB/20241218.parquet跳过日期 20240405: 原始数据文件不存在
# 文件已存在，跳过: ./factors/raw_order_APB/20240417.parquet文件已存在，跳过: ./factors/raw_order_APB/20240429.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240509.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240521.parquet跳过日期 20240215: 原始数据文件不存在
#
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240531.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240612.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240704.parquet文件已存在，跳过: ./factors/raw_order_APB/20240624.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240716.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240726.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240807.parquet文件已存在，跳过: ./factors/raw_order_APB/20240222.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240819.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240829.parquet文件已存在，跳过: ./factors/raw_order_APB/20240315.parquet文件已存在，跳过: ./factors/raw_order_APB/20240305.parquet文件已存在，跳过: ./factors/raw_order_APB/20240910.parquet文件已存在，跳过: ./factors/raw_order_APB/20240920.parquet跳过日期 20241002: 原始数据文件不存在
# 文件已存在，跳过: ./factors/raw_order_APB/20241024.parquet文件已存在，跳过: ./factors/raw_order_APB/20241014.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240327.parquet文件已存在，跳过: ./factors/raw_order_APB/20241105.parquet文件已存在，跳过: ./factors/raw_order_APB/20241115.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20241127.parquet文件已存在，跳过: ./factors/raw_order_APB/20240206.parquet文件已存在，跳过: ./factors/raw_order_APB/20241209.parquet文件已存在，跳过: ./factors/raw_order_APB/20241219.parquet文件已存在，跳过: ./factors/raw_order_APB/20240408.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240418.parquet文件已存在，跳过: ./factors/raw_order_APB/20240430.parquet文件已存在，跳过: ./factors/raw_order_APB/20240510.parquet
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240522.parquet跳过日期 20240216: 原始数据文件不存在
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240603.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240613.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240625.parquet文件已存在，跳过: ./factors/raw_order_APB/20240705.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240717.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240729.parquet文件已存在，跳过: ./factors/raw_order_APB/20240808.parquet文件已存在，跳过: ./factors/raw_order_APB/20240223.parquet文件已存在，跳过: ./factors/raw_order_APB/20240820.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240830.parquet文件已存在，跳过: ./factors/raw_order_APB/20240318.parquet文件已存在，跳过: ./factors/raw_order_APB/20240306.parquet文件已存在，跳过: ./factors/raw_order_APB/20240911.parquet文件已存在，跳过: ./factors/raw_order_APB/20240923.parquet
# 跳过日期 20241003: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20241025.parquet文件已存在，跳过: ./factors/raw_order_APB/20241015.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20241106.parquet文件已存在，跳过: ./factors/raw_order_APB/20240328.parquet文件已存在，跳过: ./factors/raw_order_APB/20241118.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20241128.parquet文件已存在，跳过: ./factors/raw_order_APB/20240207.parquet文件已存在，跳过: ./factors/raw_order_APB/20241210.parquet文件已存在，跳过: ./factors/raw_order_APB/20241220.parquet文件已存在，跳过: ./factors/raw_order_APB/20240409.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240419.parquet跳过日期 20240501: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20240513.parquet
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240219.parquet文件已存在，跳过: ./factors/raw_order_APB/20240523.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240604.parquet
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240614.parquet
#
# 跳过日期 20240626: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20240708.parquet
#
#
#
#
# 跳过日期 20240718: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240730.parquet文件已存在，跳过: ./factors/raw_order_APB/20240809.parquet文件已存在，跳过: ./factors/raw_order_APB/20240821.parquet文件已存在，跳过: ./factors/raw_order_APB/20240226.parquet开始使用 30 个进程并行处理 946 个交易日...
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240902.parquet文件已存在，跳过: ./factors/raw_order_APB/20240319.parquet文件已存在，跳过: ./factors/raw_order_APB/20240307.parquet文件已存在，跳过: ./factors/raw_order_APB/20240912.parquet文件已存在，跳过: ./factors/raw_order_APB/20240924.parquet
# 跳过日期 20241004: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20241028.parquet文件已存在，跳过: ./factors/raw_order_APB/20241016.parquet文件已存在，跳过: ./factors/raw_order_APB/20240329.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20241107.parquet文件已存在，跳过: ./factors/raw_order_APB/20241119.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20241129.parquet文件已存在，跳过: ./factors/raw_order_APB/20241230.parquet文件已存在，跳过: ./factors/raw_order_APB/20241211.parquet文件已存在，跳过: ./factors/raw_order_APB/20241223.parquet文件已存在，跳过: ./factors/raw_order_APB/20240410.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240422.parquet跳过日期 20240502: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20240514.parquet
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240524.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240605.parquet
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240617.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240627.parquet文件已存在，跳过: ./factors/raw_order_APB/20240709.parquet
#
#
#
#
# 跳过日期 20240719: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240731.parquet文件已存在，跳过: ./factors/raw_order_APB/20240812.parquet文件已存在，跳过: ./factors/raw_order_APB/20240822.parquet文件已存在，跳过: ./factors/raw_order_APB/20240227.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240903.parquet文件已存在，跳过: ./factors/raw_order_APB/20240320.parquet文件已存在，跳过: ./factors/raw_order_APB/20240308.parquet文件已存在，跳过: ./factors/raw_order_APB/20240913.parquet文件已存在，跳过: ./factors/raw_order_APB/20240925.parquet
# 跳过日期 20241007: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20241029.parquet文件已存在，跳过: ./factors/raw_order_APB/20241017.parquet文件已存在，跳过: ./factors/raw_order_APB/20240401.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20241108.parquet
# 跳过日期 20241120: 原始数据文件不存在
# 文件已存在，跳过: ./factors/raw_order_APB/20241202.parquet文件已存在，跳过: ./factors/raw_order_APB/20241231.parquet文件已存在，跳过: ./factors/raw_order_APB/20241212.parquet文件已存在，跳过: ./factors/raw_order_APB/20241224.parquet文件已存在，跳过: ./factors/raw_order_APB/20240411.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240423.parquet跳过日期 20240503: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20240515.parquet
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240527.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240606.parquet
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240618.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240628.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240710.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240722.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240801.parquet文件已存在，跳过: ./factors/raw_order_APB/20240813.parquet文件已存在，跳过: ./factors/raw_order_APB/20240823.parquet文件已存在，跳过: ./factors/raw_order_APB/20240228.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240904.parquet文件已存在，跳过: ./factors/raw_order_APB/20240321.parquet文件已存在，跳过: ./factors/raw_order_APB/20240311.parquet跳过日期 20240916: 原始数据文件不存在文件已存在，跳过: ./factors/raw_order_APB/20240926.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20241008.parquet文件已存在，跳过: ./factors/raw_order_APB/20241030.parquet文件已存在，跳过: ./factors/raw_order_APB/20241018.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240402.parquet文件已存在，跳过: ./factors/raw_order_APB/20241111.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20241121.parquet文件已存在，跳过: ./factors/raw_order_APB/20241203.parquet文件已存在，跳过: ./factors/raw_order_APB/20241213.parquet文件已存在，跳过: ./factors/raw_order_APB/20241225.parquet文件已存在，跳过: ./factors/raw_order_APB/20240412.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240506.parquet文件已存在，跳过: ./factors/raw_order_APB/20240424.parquet文件已存在，跳过: ./factors/raw_order_APB/20240516.parquet
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240528.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240607.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240701.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240619.parquet文件已存在，跳过: ./factors/raw_order_APB/20240711.parquet
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240723.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240802.parquet文件已存在，跳过: ./factors/raw_order_APB/20240814.parquet文件已存在，跳过: ./factors/raw_order_APB/20240826.parquet文件已存在，跳过: ./factors/raw_order_APB/20240229.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240905.parquet文件已存在，跳过: ./factors/raw_order_APB/20240322.parquet文件已存在，跳过: ./factors/raw_order_APB/20240312.parquet跳过日期 20240917: 原始数据文件不存在
# 文件已存在，跳过: ./factors/raw_order_APB/20240927.parquet文件已存在，跳过: ./factors/raw_order_APB/20241009.parquet文件已存在，跳过: ./factors/raw_order_APB/20241031.parquet文件已存在，跳过: ./factors/raw_order_APB/20241021.parquet文件已存在，跳过: ./factors/raw_order_APB/20240403.parquet文件已存在，跳过: ./factors/raw_order_APB/20241112.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20241122.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20241204.parquet文件已存在，跳过: ./factors/raw_order_APB/20241216.parquet文件已存在，跳过: ./factors/raw_order_APB/20241226.parquet文件已存在，跳过: ./factors/raw_order_APB/20240415.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240507.parquet文件已存在，跳过: ./factors/raw_order_APB/20240425.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240517.parquet
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240529.parquet
#
#
#
# 跳过日期 20240610: 原始数据文件不存在
#
#
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240620.parquet文件已存在，跳过: ./factors/raw_order_APB/20240702.parquet
# 跳过日期 20240712: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240724.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20240805.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240827.parquet文件已存在，跳过: ./factors/raw_order_APB/20240815.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20240906.parquet文件已存在，跳过: ./factors/raw_order_APB/20240918.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20241010.parquet文件已存在，跳过: ./factors/raw_order_APB/20241101.parquet文件已存在，跳过: ./factors/raw_order_APB/20240930.parquet文件已存在，跳过: ./factors/raw_order_APB/20241022.parquet文件已存在，跳过: ./factors/raw_order_APB/20241113.parquet
#
# 文件已存在，跳过: ./factors/raw_order_APB/20241125.parquet
# 文件已存在，跳过: ./factors/raw_order_APB/20241205.parquet文件已存在，跳过: ./factors/raw_order_APB/20241217.parquet文件已存在，跳过: ./factors/raw_order_APB/20241227.parquet
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 处理完成:
# 成功处理 854 个日期
# 跳过 92 个日期
# 所有因子文件已生成在目录: ./factors/raw_order_APB
# 在目录 ./factors/raw_order_APB 中找到 854 个Parquet文件
#
# 处理因子: new_APB
#
# new_APB因子覆盖率统计: 平均=0.92, 最小=0.81
# 共计 4148652 条记录
#
# 数据预览:
#         date security_code  new_APB
# 0 2021-05-18        000001      NaN
# 1 2021-05-18        000002      NaN
# 2 2021-05-18        000004      NaN
# 3 2021-05-18        000005      NaN
# 4 2021-05-18        000006      NaN

# %%
output_path = "/data/home/lexuanchen/Factors/Order/Signal/Improved_APB"
df = pd.read_csv(f'{output_path}/raw_order_APB.csv')
df.rename(columns={'new_APB': 'raw_order_APB'}, inplace=True)

df.to_csv(f'{output_path}/raw_order_APB.csv')


stats = df['raw_order_APB'].describe()
print(stats)
# Out:
# count    4.127222e+06
# mean     1.691010e-04
# std      1.368705e-02
# min     -1.974252e-02
# 25%     -9.191939e-04
# 50%     -2.354157e-04
# 75%      3.001033e-04
# max      2.185038e+00
# Name: raw_order_APB, dtype: float64
