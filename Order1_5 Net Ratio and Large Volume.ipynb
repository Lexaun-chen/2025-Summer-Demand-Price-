# %%
import connectorx as cx
import pandas as pd
import numpy as np
import os
import duckdb
from datetime import datetime
import glob
import multiprocessing as mp
from functools import partial
import time

from tqdm import tqdm

# %%
# # 计算大单买卖比例因子
# def calculate_daily_factor(trading_date):
#     order_pth = f"/data/HighFreqData/Order/l2order/{pd.to_datetime(trading_date).strftime('%Y%m%d')}.parquet"

#     # 检查文件是否存在
#     if not os.path.exists(order_pth):
#         raise FileNotFoundError(f"数据文件不存在: {order_pth}")

#     conn = duckdb.connect(database=':memory:')
    
#     # 首先获取早盘订单数据
#     query = f"""
#     SELECT 
#         security_code,
#         order_side, 
#         order_type,
#         order_details,
#         order_price,
#         order_price_adj,
#         order_volume,
#         order_time
#     FROM '{order_pth}'
#     WHERE order_time >= 93000000 
#         AND order_time < 103000000
#         AND order_type = 'A'
#         AND order_details = 'L'
#     """
    
#     early_orders = conn.execute(query).fetchdf()
    
#     # 对每只股票分别处理
#     result_data = []
#     epsilon = 1e-10  # 数值稳定性
    
#     for code in early_orders['security_code'].unique():
#         try:
#             stock_orders = early_orders[early_orders['security_code'] == code]
            
#             # 如果订单数量太少，跳过
#             if len(stock_orders) < 10:
#                 continue
            
#             # 确定大单阈值（按订单量大小排序，取前10%）
#             large_order_threshold = stock_orders['order_volume'].quantile(0.9)
            
#             # 筛选大单
#             large_orders = stock_orders[stock_orders['order_volume'] >= large_order_threshold]
            
#             # 如果大单数量太少，跳过
#             if len(large_orders) < 5:
#                 continue
            
#             # 计算大单中买单和卖单的数量和总量
#             buy_orders = large_orders[large_orders['order_side'] == 1]
#             sell_orders = large_orders[large_orders['order_side'] == -1]

#             all_buy_orders = stock_orders[stock_orders['order_side'] == 1]
#             all_sell_orders = stock_orders[stock_orders['order_side'] == -1]
            
#             # 安全获取数量和总量
#             buy_count = len(buy_orders)
#             sell_count = len(sell_orders)
#             buy_volume = buy_orders['order_volume'].sum() if buy_count > 0 else 0
#             sell_volume = sell_orders['order_volume'].sum() if sell_count > 0 else 0
            
#             all_buy_count = len(all_buy_orders)
#             all_sell_count = len(all_sell_orders)
#             all_buy_volume = all_buy_orders['order_volume'].sum() if all_buy_count > 0 else 0
#             all_sell_volume = all_sell_orders['order_volume'].sum() if all_sell_count > 0 else 0
            
#             # 计算大单买卖比例指标（添加epsilon避免除零）
#             large_order_count_ratio = (buy_count + epsilon) / (sell_count + epsilon)
#             large_order_volume_ratio = (buy_volume + epsilon) / (sell_volume + epsilon)
            
#             # 取对数使分布更接近正态
#             log_count_ratio = np.log(large_order_count_ratio)
#             log_volume_ratio = np.log(large_order_volume_ratio)

#             # 安全计算净买卖比率
#             if buy_volume + sell_volume <= epsilon:
#                 large_net_order_volume_ratio = np.nan
#             else:
#                 ratio = (buy_volume - sell_volume)/(buy_volume + sell_volume)
#                 large_net_order_volume_ratio = np.sign(ratio) * np.log(1 + abs(ratio))
            
#             if all_buy_volume + all_sell_volume <= epsilon:
#                 net_order_volume_ratio = np.nan
#             else:
#                 ratio_all = (all_buy_volume - all_sell_volume)/(all_buy_volume + all_sell_volume)
#                 net_order_volume_ratio = np.sign(ratio_all) * np.log(1 + abs(ratio_all))
            
#             # 保存结果
#             result_data.append({
#                 'security_code': code,
#                 'large_order_count_ratio': log_count_ratio,
#                 'large_order_volume_ratio': log_volume_ratio,
#                 'large_order_avg_buy_size': buy_volume / (buy_count + epsilon) if buy_count > 0 else np.nan,
#                 'large_order_avg_sell_size': sell_volume / (sell_count + epsilon) if sell_count > 0 else np.nan,
#                 'large_order_threshold': large_order_threshold,
#                 'large_order_count': len(large_orders),
#                 'large_net_order_volume_ratio': large_net_order_volume_ratio,
#                 'net_order_volume_ratio': net_order_volume_ratio
#             })
#         except Exception as e:
#             print(f"处理股票 {code} 时出错: {str(e)}")
    
#     # 转换为DataFrame
#     factor_df = pd.DataFrame(result_data)
    
#     # 处理极端值
#     for col in ['large_order_count_ratio', 'large_order_volume_ratio', 
#                 'large_net_order_volume_ratio', 'net_order_volume_ratio']:
#         if col in factor_df.columns:
#             factor_df[col] = factor_df[col].replace([np.inf, -np.inf], np.nan)
    
#     return factor_df

# %%
def calculate_daily_factor(trading_date):
    order_pth = f"/data/HighFreqData/Order/l2order/{pd.to_datetime(trading_date).strftime('%Y%m%d')}.parquet"

    # 检查文件是否存在
    if not os.path.exists(order_pth):
        raise FileNotFoundError(f"数据文件不存在: {order_pth}")

    conn = duckdb.connect(database=':memory:')
    
    # 使用SQL完成所有计算
    query = f"""
    WITH early_orders AS (
        SELECT 
            security_code,
            order_side, 
            order_volume
        FROM '{order_pth}'
        WHERE order_time >= 93000000 
            AND order_time < 103000000
            AND order_type = 'A'
            AND order_details = 'L'
    ),
    
    -- 计算每只股票的订单量分位数
    stock_thresholds AS (
        SELECT 
            security_code,
            PERCENTILE_CONT(0.9) WITHIN GROUP (ORDER BY order_volume) AS large_order_threshold,
            COUNT(*) AS total_orders
        FROM early_orders
        GROUP BY security_code
        HAVING COUNT(*) >= 10
    ),
    
    -- 标记大单
    large_orders AS (
        SELECT 
            e.*,
            t.large_order_threshold
        FROM early_orders e
        JOIN stock_thresholds t ON e.security_code = t.security_code
        WHERE e.order_volume >= t.large_order_threshold
    ),
    
    -- 按股票分组计算大单统计
    large_order_stats AS (
        SELECT 
            security_code,
            large_order_threshold,
            COUNT(*) AS large_order_count,
            SUM(CASE WHEN order_side = 1 THEN 1 ELSE 0 END) AS buy_count,
            SUM(CASE WHEN order_side = -1 THEN 1 ELSE 0 END) AS sell_count,
            SUM(CASE WHEN order_side = 1 THEN order_volume ELSE 0 END) AS buy_volume,
            SUM(CASE WHEN order_side = -1 THEN order_volume ELSE 0 END) AS sell_volume
        FROM large_orders
        GROUP BY security_code, large_order_threshold
        HAVING COUNT(*) >= 5
    ),
    
    -- 计算所有订单的统计
    all_order_stats AS (
        SELECT 
            security_code,
            SUM(CASE WHEN order_side = 1 THEN order_volume ELSE 0 END) AS all_buy_volume,
            SUM(CASE WHEN order_side = -1 THEN order_volume ELSE 0 END) AS all_sell_volume
        FROM early_orders
        GROUP BY security_code
    )
    
    -- 最终计算各种比率
    SELECT 
        l.security_code,
        -- 大单买卖数量比率（取对数）
        LN((l.buy_count + 1e-10) / (l.sell_count + 1e-10)) AS large_order_count_ratio,
        -- 大单买卖量比率（取对数）
        LN((l.buy_volume + 1e-10) / (l.sell_volume + 1e-10)) AS large_order_volume_ratio,
        -- 大单平均买入规模
        CASE WHEN l.buy_count > 0 THEN l.buy_volume / l.buy_count ELSE NULL END AS large_order_avg_buy_size,
        -- 大单平均卖出规模
        CASE WHEN l.sell_count > 0 THEN l.sell_volume / l.sell_count ELSE NULL END AS large_order_avg_sell_size,
        -- 大单阈值
        l.large_order_threshold,
        -- 大单数量
        l.large_order_count,
        -- 大单净买卖量比率（带符号对数）
        CASE 
            WHEN (l.buy_volume + l.sell_volume) <= 1e-10 THEN NULL
            ELSE 
                SIGN((l.buy_volume - l.sell_volume) / (l.buy_volume + l.sell_volume)) * 
                LN(1 + ABS((l.buy_volume - l.sell_volume) / (l.buy_volume + l.sell_volume)))
        END AS large_net_order_volume_ratio,
        -- 所有订单净买卖量比率（带符号对数）
        CASE 
            WHEN (a.all_buy_volume + a.all_sell_volume) <= 1e-10 THEN NULL
            ELSE 
                SIGN((a.all_buy_volume - a.all_sell_volume) / (a.all_buy_volume + a.all_sell_volume)) * 
                LN(1 + ABS((a.all_buy_volume - a.all_sell_volume) / (a.all_buy_volume + a.all_sell_volume)))
        END AS net_order_volume_ratio
    FROM large_order_stats l
    JOIN all_order_stats a ON l.security_code = a.security_code
    """
    
    try:
        # 执行SQL查询
        factor_df = conn.execute(query).fetchdf()
        
        # 处理极端值（虽然SQL中已经处理了大部分情况，但以防万一）
        for col in ['large_order_count_ratio', 'large_order_volume_ratio', 
                    'large_net_order_volume_ratio', 'net_order_volume_ratio']:
            if col in factor_df.columns:
                factor_df[col] = factor_df[col].replace([np.inf, -np.inf], np.nan)
        
        return factor_df
    
    except Exception as e:
        print(f"SQL查询执行出错: {str(e)}")
        raise
    finally:
        conn.close()

# %%
def process_single_date(trading_date, factor_name):
    
    """处理单个交易日的函数"""
   
    date_str = trading_date.strftime('%Y%m%d')
    output_dir = f"./factors/{factor_name}"
    file_path = f"{output_dir}/{date_str}.parquet"
    
    # 如果文件已存在，跳过处理
    if os.path.exists(file_path):
        print(f"文件已存在，跳过: {file_path}")
        return date_str, True, "已存在"
    
    # 检查原始数据文件是否存在
    data_file = f"/data/HighFreqData/Order/l2order/{date_str}.parquet"
    if not os.path.exists(data_file):
        print(f"跳过日期 {date_str}: 原始数据文件不存在")
        return date_str, False, "数据文件不存在"
    
    try:
        daily_factor_df = calculate_daily_factor(trading_date)
        
        daily_factor_df['date'] = date_str

        daily_factor_df.to_parquet(file_path, index=False)
        print(f"已生成因子文件: {file_path}")
        return date_str, True, "成功"
        
    except Exception as e:
        error_msg = str(e)
        print(f"处理日期 {date_str} 时出错: {error_msg}")
        return date_str, False, error_msg


def derive_daily_factor(start_date, end_date, factor_name, num_processes=10):
    start_time = time.time()
    
    trading_dates = pd.date_range(start=start_date, end=end_date, freq='D')
    
    # 创建输出目录
    output_dir = f"./factors/{factor_name}"
    os.makedirs(output_dir, exist_ok=True)
    
    # 创建进程池
    pool = mp.Pool(processes=num_processes)
    
    # 创建带有固定参数的处理函数
    process_date_with_args = partial(process_single_date, factor_name=factor_name)
    
    # 提交所有任务到进程池并获取结果
    print(f"开始使用 {num_processes} 个进程并行处理 {len(trading_dates)} 个交易日...")
    results = pool.map(process_date_with_args, trading_dates)
    
    # 关闭进程池
    pool.close()
    pool.join()
    
    # 分析处理结果
    processed_dates = [date_str for date_str, success, _ in results if success]
    skipped_dates = [date_str for date_str, success, _ in results if not success]
    
    # 打印处理结果摘要
    print(f"\n处理完成:")
    print(f"成功处理 {len(processed_dates)} 个日期")
    print(f"跳过 {len(skipped_dates)} 个日期")

    return output_dir

# %%
def calculate_rolling_20d_avg(factor_names, factor_dir, start_date=None, end_date=None, min_window=5):
    
    if not isinstance(factor_names, list):
        factor_names = [factor_names]
    
    parquet_pattern = os.path.join(factor_dir, "*.parquet")
    parquet_files = glob.glob(parquet_pattern)
    print(f"在目录 {factor_dir} 中找到 {len(parquet_files)} 个Parquet文件")
    

    conn = duckdb.connect(database=':memory:')
    all_factor_data = conn.execute(f"""
        SELECT * FROM read_parquet('{parquet_pattern}')
    """).fetchdf()
    conn.close()
    

    missing_factors = [f for f in factor_names if f not in all_factor_data.columns]
    if missing_factors:
        raise ValueError(f"在Parquet文件中未找到以下因子列: {', '.join(missing_factors)}")
    
    all_factor_data['date'] = pd.to_datetime(all_factor_data['date'])

    all_factor_data = all_factor_data.sort_values(['date', 'security_code'])
    
    # 筛选日期范围
    if start_date:
        start_date = pd.to_datetime(start_date)
        all_factor_data = all_factor_data[all_factor_data['date'] >= start_date]
    if end_date:
        end_date = pd.to_datetime(end_date)
        all_factor_data = all_factor_data[all_factor_data['date'] <= end_date]

    # 获取所有个股代码
    all_securities = all_factor_data['security_code'].unique()

    result_df = all_factor_data[['date', 'security_code']].copy()

    # 为每个因子计算滚动平均
    for factor_name in factor_names:
        print(f"\n处理因子: {factor_name}")
        
        #转置成宽表
        pivot_data = all_factor_data.pivot(index='date', columns='security_code', values=factor_name)

        # 对宽表直接应用rolling
        rolling_avg = pivot_data.rolling(window=20, min_periods=min_window).mean()

        # 将结果转换回长格式
        factor_df = rolling_avg.stack().reset_index()
        factor_df.columns = ['date', 'security_code', factor_name]
        # factor_df[factor_name] = -factor_df[factor_name]

        # 计算每日因子覆盖率
        # 计算每个日期非NaN的因子值数量
        non_nan_counts = factor_df.dropna(subset=[factor_name]).groupby('date').size()

        # 计算覆盖率
        coverage = non_nan_counts / len(all_securities)
        print(f"\n{factor_name}因子覆盖率统计: 平均={coverage.mean():.2f}, 最小={coverage.min():.2f}")

        result_df = pd.merge(
            result_df, 
            factor_df,
            on=['date', 'security_code'],
            how='left'
        )
    
    return result_df

# %%
def main():

    start_date = '2021-05-18'
    end_date = '2024-12-31'
    
    all_factors = [
        'large_order_count_ratio',
        'large_order_volume_ratio',
        'large_order_avg_buy_size',
        'large_order_avg_sell_size',
        'large_order_threshold',
        'large_order_count',
        'large_net_order_volume_ratio',
        'net_order_volume_ratio'
    ]


    factor_name = "Improved_Early_Order_Size_Ratio"

    # trading_dates = pd.date_range(start=start_date, end=end_date, freq='D')
    
    # for trading_date in trading_dates:
        
    #     process_single_date(trading_date,factor_name)

    # factor_dir = output_dir = f"./factors/{factor_name}"

    factor_dir = derive_daily_factor(start_date, end_date, factor_name, num_processes=10)

    
    print(f"所有因子文件已生成在目录: {factor_dir}")

    result_df = calculate_rolling_20d_avg(all_factors, factor_dir, start_date, end_date, min_window=5)
    
    # 保存结果为CSV
    output_path = "/data/home/lexuanchen/Factors/Order/Signal/Improved_Early_Order_Size_Ratio"
    os.makedirs(output_path, exist_ok=True)

    print(f"共计 {len(result_df)} 条记录")

    print("\n数据预览:")
    print(result_df.head())


    for factor in all_factors:
        output_file_path = f"{output_path}/{factor}.csv"
        factor_df = result_df[['date', 'security_code', factor]]
        factor_df.to_csv(output_file_path, index=False)


# 执行主函数
if __name__ == "__main__":
    main()
# Out:
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210621.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220111.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211104.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210518.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211208.parquet
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220214.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220112.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211105.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210622.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211209.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210519.parquet
#
#
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220113.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210623.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210520.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211210.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220215.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220114.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210521.parquet
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210624.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220216.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210625.parquet
#
# 跳过日期 20211211: 原始数据文件不存在跳过日期 20210626: 原始数据文件不存在跳过日期 20210522: 原始数据文件不存在跳过日期 20220115: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220217.parquet
#
#
# 跳过日期 20211106: 原始数据文件不存在
# 跳过日期 20211212: 原始数据文件不存在
# 跳过日期 20220116: 原始数据文件不存在
#
# 跳过日期 20210523: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220218.parquet跳过日期 20210627: 原始数据文件不存在
#
# 跳过日期 20211107: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211213.parquet
#
# 跳过日期 20211001: 原始数据文件不存在跳过日期 20210725: 原始数据文件不存在跳过日期 20220320: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210524.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220117.parquet
#
# 跳过日期 20210828: 原始数据文件不存在跳过日期 20220219: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210628.parquet
# 跳过日期 20211108: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211214.parquet
#
#
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210525.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220118.parquet跳过日期 20220220: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210629.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211215.parquet跳过日期 20211002: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210726.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220321.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211109.parquet
#
# 跳过日期 20210829: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210526.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220119.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220221.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210630.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211216.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210727.parquet跳过日期 20211003: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220322.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211110.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210830.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210527.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220120.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220222.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210701.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211217.parquet
# 跳过日期 20211004: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210728.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211111.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220323.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210831.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210528.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220121.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210702.parquet跳过日期 20211218: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220223.parquet
# 跳过日期 20211005: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210729.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220324.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210901.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211112.parquet
#
#
# 跳过日期 20210529: 原始数据文件不存在
#
# 跳过日期 20220122: 原始数据文件不存在
#
#
# 跳过日期 20210703: 原始数据文件不存在跳过日期 20211219: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220224.parquet
# 跳过日期 20211006: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210730.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220325.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210902.parquet跳过日期 20211113: 原始数据文件不存在
#
#
# 跳过日期 20210530: 原始数据文件不存在
#
# 跳过日期 20220123: 原始数据文件不存在
#
#
# 跳过日期 20210704: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211220.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220225.parquet跳过日期 20211007: 原始数据文件不存在跳过日期 20210731: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210903.parquet
# 跳过日期 20220326: 原始数据文件不存在跳过日期 20211114: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210531.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220124.parquet
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210705.parquet跳过日期 20220226: 原始数据文件不存在
# 跳过日期 20210801: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211221.parquet
# 跳过日期 20210904: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211008.parquet跳过日期 20220327: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211115.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210601.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220125.parquet
#
#
#
#
# 跳过日期 20220227: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210706.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210802.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211222.parquet跳过日期 20210905: 原始数据文件不存在跳过日期 20211009: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220328.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210602.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211116.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220126.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220228.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210707.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210803.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211223.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210906.parquet跳过日期 20211010: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220329.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211117.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210603.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220127.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220301.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210708.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210804.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211224.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210907.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211011.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211118.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220330.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210604.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220128.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220302.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210709.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210805.parquet跳过日期 20211225: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210908.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211012.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220331.parquet跳过日期 20211119: 原始数据文件不存在跳过日期 20210605: 原始数据文件不存在
#
#
#
# 跳过日期 20220129: 原始数据文件不存在
#
#
#
#
# 跳过日期 20210710: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210806.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220303.parquet跳过日期 20211226: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210909.parquet跳过日期 20211120: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211013.parquet跳过日期 20210606: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220401.parquet跳过日期 20220130: 原始数据文件不存在
#
#
#
# 跳过日期 20210711: 原始数据文件不存在跳过日期 20210807: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211227.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220304.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210910.parquet跳过日期 20211121: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210607.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211014.parquet
#
# 跳过日期 20220402: 原始数据文件不存在
#
# 跳过日期 20220131: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210712.parquet跳过日期 20210808: 原始数据文件不存在
#
# 跳过日期 20211228: 原始数据文件不存在跳过日期 20220305: 原始数据文件不存在跳过日期 20210911: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210608.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211015.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211122.parquet
# 跳过日期 20220403: 原始数据文件不存在
#
#
# 跳过日期 20220201: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210713.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210809.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211229.parquet跳过日期 20220306: 原始数据文件不存在
# 跳过日期 20210912: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210609.parquet跳过日期 20211016: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211123.parquet
# 跳过日期 20220404: 原始数据文件不存在
#
#
#
#
# 跳过日期 20220202: 原始数据文件不存在跳过日期 20210714: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210810.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220307.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210913.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210610.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211230.parquet
# 跳过日期 20211017: 原始数据文件不存在
# 跳过日期 20220405: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211124.parquet
#
#
#
#
#
# 跳过日期 20220203: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210811.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210914.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210715.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210611.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211231.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220308.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211018.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211125.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220406.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210915.parquet跳过日期 20220204: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210812.parquet
#
# 跳过日期 20210612: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210716.parquet跳过日期 20220101: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220309.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211019.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220407.parquet
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210916.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211126.parquet跳过日期 20220205: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210813.parquet
# 跳过日期 20210613: 原始数据文件不存在跳过日期 20210717: 原始数据文件不存在跳过日期 20220102: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220310.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211020.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220408.parquet
#
#
# 跳过日期 20210917: 原始数据文件不存在
#
# 跳过日期 20211127: 原始数据文件不存在跳过日期 20220206: 原始数据文件不存在
#
# 跳过日期 20210814: 原始数据文件不存在跳过日期 20210614: 原始数据文件不存在
# 跳过日期 20210718: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220311.parquet跳过日期 20220103: 原始数据文件不存在
#
# 跳过日期 20211021: 原始数据文件不存在跳过日期 20220409: 原始数据文件不存在
# 跳过日期 20210918: 原始数据文件不存在
#
#
# 跳过日期 20211128: 原始数据文件不存在跳过日期 20220207: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210615.parquet跳过日期 20210815: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210719.parquet跳过日期 20220312: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220104.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211022.parquet
# 跳过日期 20220410: 原始数据文件不存在
#
# 跳过日期 20210919: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211129.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220208.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210616.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210816.parquet
# 跳过日期 20220313: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210720.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220105.parquet跳过日期 20211023: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220411.parquet
#
#
#
#
#
# 跳过日期 20210920: 原始数据文件不存在跳过日期 20211130: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220209.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210617.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220314.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210817.parquet跳过日期 20211024: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220106.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210721.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220412.parquet
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211201.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220210.parquet
# 跳过日期 20210921: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210618.parquet跳过日期 20210818: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220315.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211025.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220107.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210722.parquet
#
#
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220413.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211202.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220211.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210922.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210819.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220316.parquet跳过日期 20210619: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211026.parquet
#
# 跳过日期 20220108: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210723.parquet
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220414.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211203.parquet跳过日期 20220212: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210923.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220317.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210820.parquet跳过日期 20210620: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211027.parquet跳过日期 20220109: 原始数据文件不存在
#
#
# 跳过日期 20210724: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220415.parquet
# 跳过日期 20220213: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220110.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210924.parquet跳过日期 20211204: 原始数据文件不存在
# 跳过日期 20210821: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220318.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211028.parquet
#
#
#
# 跳过日期 20220423: 原始数据文件不存在跳过日期 20220416: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220527.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220630.parquet跳过日期 20210925: 原始数据文件不存在跳过日期 20211205: 原始数据文件不存在
# 跳过日期 20210822: 原始数据文件不存在跳过日期 20220319: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211029.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220803.parquet
#
# 跳过日期 20220424: 原始数据文件不存在跳过日期 20220528: 原始数据文件不存在
# 跳过日期 20220417: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220701.parquet
# 跳过日期 20210926: 原始数据文件不存在跳过日期 20211206: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210823.parquet
#
#
# 跳过日期 20211030: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220906.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220804.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220425.parquet跳过日期 20220529: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220418.parquet
#
#
#
# 跳过日期 20220702: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210927.parquet跳过日期 20211207: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210824.parquet跳过日期 20211031: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220907.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220805.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220530.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220426.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220419.parquet
#
#
#
# 跳过日期 20220703: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210928.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221010.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210825.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211101.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220908.parquet
#
# 跳过日期 20220806: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220531.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220427.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220420.parquet
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220704.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210929.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210826.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221011.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211102.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220909.parquet
# 跳过日期 20220807: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220601.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220428.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220421.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220705.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210930.parquet
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20210827.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221012.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20211103.parquet跳过日期 20220910: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220602.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220808.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220429.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220422.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220706.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221013.parquet跳过日期 20221113: 原始数据文件不存在
# 跳过日期 20221217: 原始数据文件不存在
# 跳过日期 20220911: 原始数据文件不存在跳过日期 20220603: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220809.parquet跳过日期 20220430: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230120.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220707.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230223.parquet
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221114.parquet跳过日期 20221014: 原始数据文件不存在
# 跳过日期 20221218: 原始数据文件不存在
#
# 跳过日期 20220604: 原始数据文件不存在跳过日期 20220912: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220810.parquet跳过日期 20220501: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220708.parquet跳过日期 20230121: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230224.parquet
#
#
# 跳过日期 20221015: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221115.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221219.parquet
#
#
# 跳过日期 20220605: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220811.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220913.parquet跳过日期 20220502: 原始数据文件不存在
#
#
# 跳过日期 20220709: 原始数据文件不存在跳过日期 20230122: 原始数据文件不存在
#
# 跳过日期 20230225: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221116.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221220.parquet跳过日期 20221016: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220606.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220812.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220914.parquet
# 跳过日期 20220503: 原始数据文件不存在
#
# 跳过日期 20220710: 原始数据文件不存在
#
# 跳过日期 20230123: 原始数据文件不存在跳过日期 20230226: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221117.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221221.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221017.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220607.parquet跳过日期 20220813: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220915.parquet
#
# 跳过日期 20220504: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220711.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230227.parquet
# 跳过日期 20230124: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221118.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221222.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221018.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220608.parquet跳过日期 20220814: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220916.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220505.parquet
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230228.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220712.parquet
# 跳过日期 20230125: 原始数据文件不存在跳过日期 20221119: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221223.parquet跳过日期 20221019: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220815.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220609.parquet
# 跳过日期 20220917: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220506.parquet
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230301.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220713.parquet跳过日期 20230126: 原始数据文件不存在跳过日期 20221120: 原始数据文件不存在
# 跳过日期 20221224: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220816.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221020.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220610.parquet跳过日期 20220918: 原始数据文件不存在
#
#
#
#
# 跳过日期 20220507: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230302.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220714.parquet跳过日期 20230127: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221121.parquet跳过日期 20221225: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220817.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221021.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220919.parquet跳过日期 20220611: 原始数据文件不存在
#
#
#
#
#
# 跳过日期 20220508: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230303.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220715.parquet跳过日期 20230128: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221122.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220818.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221226.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220920.parquet
# 跳过日期 20221022: 原始数据文件不存在跳过日期 20220612: 原始数据文件不存在
#
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220509.parquet
# 跳过日期 20230304: 原始数据文件不存在
#
# 跳过日期 20220716: 原始数据文件不存在跳过日期 20230129: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221123.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221227.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220819.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220921.parquet
#
# 跳过日期 20221023: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220613.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220510.parquet跳过日期 20230305: 原始数据文件不存在
# 跳过日期 20220717: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230130.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221124.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221228.parquet跳过日期 20220820: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220922.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221024.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220614.parquet
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220511.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230306.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220718.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221125.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221229.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230131.parquet跳过日期 20220821: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220923.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221025.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220615.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220512.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220719.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230307.parquet
# 跳过日期 20221126: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221230.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220822.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230201.parquet
#
#
# 跳过日期 20220924: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221026.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220616.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220513.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220720.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230308.parquet
#
# 跳过日期 20221127: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220823.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230202.parquet
# 跳过日期 20221231: 原始数据文件不存在
# 跳过日期 20220925: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220617.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221027.parquet
#
# 跳过日期 20220514: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220721.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230309.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220824.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221128.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230203.parquet跳过日期 20220926: 原始数据文件不存在跳过日期 20230101: 原始数据文件不存在
# 跳过日期 20220618: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221028.parquet跳过日期 20220515: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220722.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220825.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230310.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221129.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220927.parquet跳过日期 20230102: 原始数据文件不存在
# 跳过日期 20230204: 原始数据文件不存在
# 跳过日期 20220619: 原始数据文件不存在
#
# 跳过日期 20221029: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220516.parquet
#
#
# 跳过日期 20220723: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220826.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221130.parquet跳过日期 20230311: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220928.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230103.parquet跳过日期 20230205: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220620.parquet
#
# 跳过日期 20221030: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220517.parquet
#
#
# 跳过日期 20220724: 原始数据文件不存在跳过日期 20220827: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221201.parquet
# 跳过日期 20230312: 原始数据文件不存在
# 跳过日期 20220929: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230104.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230206.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220621.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221031.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220518.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220725.parquet
# 跳过日期 20220828: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221202.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230313.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230207.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220930.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230105.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220622.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221101.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220519.parquet
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220726.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220829.parquet跳过日期 20221203: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230314.parquet
# 跳过日期 20221001: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230208.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230106.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220623.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221102.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220520.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220727.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220830.parquet跳过日期 20221204: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230315.parquet跳过日期 20221002: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230209.parquet
# 跳过日期 20230107: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220624.parquet
#
#
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221103.parquet
#
# 跳过日期 20220521: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220728.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220831.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221205.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230316.parquet跳过日期 20221003: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230210.parquet
# 跳过日期 20230108: 原始数据文件不存在
# 跳过日期 20220625: 原始数据文件不存在
#
#
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221104.parquet
# 跳过日期 20220522: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220729.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221206.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230317.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220901.parquet跳过日期 20221004: 原始数据文件不存在
# 跳过日期 20230211: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230109.parquet
#
# 跳过日期 20220626: 原始数据文件不存在
#
#
#
#
# 跳过日期 20221105: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220523.parquet
#
# 跳过日期 20220730: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221207.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220902.parquet跳过日期 20230318: 原始数据文件不存在跳过日期 20221005: 原始数据文件不存在
# 跳过日期 20230212: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230110.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220627.parquet
#
#
#
#
# 跳过日期 20221106: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220524.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221208.parquet跳过日期 20220731: 原始数据文件不存在跳过日期 20220903: 原始数据文件不存在跳过日期 20221006: 原始数据文件不存在跳过日期 20230319: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230213.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230111.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220628.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221107.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220525.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221209.parquet
# 跳过日期 20220904: 原始数据文件不存在跳过日期 20221007: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220801.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230320.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230214.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230112.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220629.parquet
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221108.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220526.parquet跳过日期 20221210: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220905.parquet
# 跳过日期 20221008: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20220802.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230321.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230215.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230113.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230329.parquet
#
#
# 跳过日期 20221109: 原始数据文件不存在跳过日期 20230502: 原始数据文件不存在
# 跳过日期 20221211: 原始数据文件不存在跳过日期 20221009: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230605.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230322.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230216.parquet跳过日期 20230709: 原始数据文件不存在
#
# 跳过日期 20230114: 原始数据文件不存在
#
# 跳过日期 20230330: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221110.parquet
# 跳过日期 20230503: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221212.parquet跳过日期 20230812: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230606.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230217.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230710.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230323.parquet
#
# 跳过日期 20230115: 原始数据文件不存在
#
# 跳过日期 20230331: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221111.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230504.parquet跳过日期 20230813: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221213.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230607.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230711.parquet跳过日期 20230218: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230324.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230116.parquet
#
#
# 跳过日期 20230401: 原始数据文件不存在
# 开始使用 10 个进程并行处理 1324 个交易日...
#
#
#
#
# 跳过日期 20221112: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230505.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230814.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221214.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230608.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230712.parquet跳过日期 20230219: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230117.parquet跳过日期 20230325: 原始数据文件不存在
#
#
#
#
# 跳过日期 20230402: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230915.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230815.parquet跳过日期 20230506: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221215.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230609.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230713.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230118.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230220.parquet跳过日期 20230326: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230403.parquet
#
#
#
# 跳过日期 20230916: 原始数据文件不存在
# 跳过日期 20230507: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230816.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20221216.parquet跳过日期 20230610: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230714.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230119.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230221.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230327.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230404.parquet
#
#
# 跳过日期 20230917: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230508.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230817.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231019.parquet
# 跳过日期 20230611: 原始数据文件不存在跳过日期 20230715: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231122.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230222.parquet跳过日期 20230328: 原始数据文件不存在
#
#
# 跳过日期 20230405: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230918.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230818.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230509.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231020.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230612.parquet跳过日期 20230716: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231123.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231226.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240129.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230406.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230919.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230510.parquet
#
# 跳过日期 20230819: 原始数据文件不存在跳过日期 20231021: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230613.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230717.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231124.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231227.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240130.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230407.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230920.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230511.parquet
#
# 跳过日期 20230820: 原始数据文件不存在跳过日期 20231022: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230718.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230614.parquet
# 跳过日期 20231125: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231228.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240131.parquet
#
# 跳过日期 20230408: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230921.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230512.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230821.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231023.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230719.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230615.parquet
# 跳过日期 20231126: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231229.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240201.parquet
# 跳过日期 20230409: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230922.parquet
#
#
# 跳过日期 20230513: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230822.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231024.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230616.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230720.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231127.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240202.parquet跳过日期 20231230: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230410.parquet
#
# 跳过日期 20230923: 原始数据文件不存在
#
#
#
# 跳过日期 20230514: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230823.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231025.parquet跳过日期 20230617: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231128.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230721.parquet跳过日期 20240203: 原始数据文件不存在跳过日期 20231231: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230411.parquet
#
# 跳过日期 20230924: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230515.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230824.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231026.parquet
# 跳过日期 20230618: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231129.parquet跳过日期 20230722: 原始数据文件不存在跳过日期 20240204: 原始数据文件不存在
# 跳过日期 20240101: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230412.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230925.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230516.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230825.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231027.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230619.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240205.parquet跳过日期 20230723: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231130.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240102.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230413.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230926.parquet
#
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230517.parquet跳过日期 20230826: 原始数据文件不存在
# 跳过日期 20231028: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230620.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230724.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240206.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231201.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240103.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230414.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230927.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230518.parquet
# 跳过日期 20230827: 原始数据文件不存在
# 跳过日期 20231029: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230621.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230725.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240207.parquet跳过日期 20231202: 原始数据文件不存在
# 跳过日期 20240104: 原始数据文件不存在跳过日期 20230415: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230928.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230519.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230828.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231030.parquet跳过日期 20230622: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230726.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240208.parquet跳过日期 20231203: 原始数据文件不存在
#
# 跳过日期 20230416: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240105.parquet
#
# 跳过日期 20230929: 原始数据文件不存在
# 跳过日期 20230520: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230829.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231031.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230727.parquet跳过日期 20230623: 原始数据文件不存在
#
# 跳过日期 20240209: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231204.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230417.parquet
#
#
# 跳过日期 20240106: 原始数据文件不存在
# 跳过日期 20230930: 原始数据文件不存在跳过日期 20230521: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230830.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231101.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230728.parquet跳过日期 20230624: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230418.parquet跳过日期 20240210: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231205.parquet
#
# 跳过日期 20240107: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230522.parquet跳过日期 20231001: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230831.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231102.parquet
# 跳过日期 20230729: 原始数据文件不存在跳过日期 20230625: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230419.parquet
# 跳过日期 20240211: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231206.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240108.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230523.parquet跳过日期 20231002: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230901.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231103.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230626.parquet
#
# 跳过日期 20230730: 原始数据文件不存在跳过日期 20230420: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231207.parquet跳过日期 20240212: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240109.parquet
#
# 跳过日期 20231003: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230524.parquet
# 跳过日期 20230902: 原始数据文件不存在
#
#
#
# 跳过日期 20231104: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230627.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230421.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230731.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231208.parquet跳过日期 20240213: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240110.parquet跳过日期 20231004: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230525.parquet
# 跳过日期 20230903: 原始数据文件不存在
#
#
#
#
# 跳过日期 20231105: 原始数据文件不存在
# 跳过日期 20230422: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230628.parquet跳过日期 20231209: 原始数据文件不存在跳过日期 20240214: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230801.parquet跳过日期 20231005: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240111.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230904.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230526.parquet
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20231106.parquet跳过日期 20230423: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230629.parquet
# 跳过日期 20240215: 原始数据文件不存在
# 跳过日期 20230802: 原始数据文件不存在
# 跳过日期 20231006: 原始数据文件不存在跳过日期 20231210: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240112.parquet
# 跳过日期 20230527: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20230905.parquet
#
# ...
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240925.parquet
#
# 跳过日期 20240414: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240724.parquet
# 跳过日期 20241201: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240312.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241029.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240621.parquet跳过日期 20240518: 原始数据文件不存在
# 跳过日期 20240825: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240926.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240415.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240725.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241202.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240313.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241030.parquet跳过日期 20240519: 原始数据文件不存在跳过日期 20240622: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240826.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240927.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240416.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240726.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241203.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240314.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241031.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240520.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240827.parquet跳过日期 20240623: 原始数据文件不存在跳过日期 20240928: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240417.parquet
#
# 跳过日期 20240727: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241204.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240315.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241101.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240521.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240828.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240624.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240418.parquet跳过日期 20240929: 原始数据文件不存在
#
#
# 跳过日期 20240728: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241205.parquet
#
# 跳过日期 20241102: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240522.parquet跳过日期 20240316: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240829.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240625.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240930.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240419.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240729.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241206.parquet
#
# 跳过日期 20241103: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240523.parquet跳过日期 20240317: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240830.parquet跳过日期 20240626: 原始数据文件不存在
# 跳过日期 20241001: 原始数据文件不存在
# 跳过日期 20240420: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240730.parquet
#
# 跳过日期 20241207: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241104.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240318.parquet
# 跳过日期 20240831: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240524.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240627.parquet
# 跳过日期 20241002: 原始数据文件不存在
# 跳过日期 20240421: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240731.parquet
#
# 跳过日期 20241208: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241105.parquet
# 跳过日期 20240901: 原始数据文件不存在跳过日期 20240525: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240319.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240628.parquet跳过日期 20241003: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240422.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240801.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241209.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241106.parquet
#
# 跳过日期 20240526: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240902.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240320.parquet跳过日期 20241004: 原始数据文件不存在跳过日期 20240629: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240423.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240802.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241210.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241107.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240903.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240527.parquet
#
# 跳过日期 20241005: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240321.parquet
# 跳过日期 20240630: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241211.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240424.parquet跳过日期 20240803: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241108.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240904.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240528.parquet
#
# 跳过日期 20241006: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240322.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240701.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241212.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240425.parquet跳过日期 20240804: 原始数据文件不存在
#
#
# 跳过日期 20241109: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240905.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240529.parquet
#
# 跳过日期 20240323: 原始数据文件不存在跳过日期 20241007: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240702.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241213.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240426.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240805.parquet
# 跳过日期 20241110: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240906.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240530.parquet
# 跳过日期 20240324: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241008.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240703.parquet跳过日期 20241214: 原始数据文件不存在
# 跳过日期 20240427: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240806.parquet
# 跳过日期 20240907: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241111.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240531.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240325.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241009.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240704.parquet跳过日期 20241215: 原始数据文件不存在
#
# 跳过日期 20240428: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240807.parquet跳过日期 20240908: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241112.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240326.parquet跳过日期 20240601: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241010.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241216.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240705.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240429.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240909.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240808.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241113.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240327.parquet
#
# 跳过日期 20240602: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241011.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241217.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240910.parquet跳过日期 20240706: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240430.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240809.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241114.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240328.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240603.parquet
#
#
# 跳过日期 20241012: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241218.parquet
#
# 跳过日期 20240707: 原始数据文件不存在
# 跳过日期 20240501: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240911.parquet跳过日期 20240810: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241115.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240329.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240604.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241219.parquet
# 跳过日期 20241013: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240708.parquet跳过日期 20240502: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240912.parquet
# 跳过日期 20240811: 原始数据文件不存在
# 跳过日期 20241116: 原始数据文件不存在跳过日期 20240330: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240605.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241220.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240709.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241014.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240913.parquet跳过日期 20240503: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240812.parquet
# 跳过日期 20241117: 原始数据文件不存在
#
# 跳过日期 20240331: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240606.parquet
#
# 跳过日期 20241221: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241015.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240710.parquet
#
# 跳过日期 20240914: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240813.parquet跳过日期 20240504: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241118.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240401.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240607.parquet
#
#
#
# 跳过日期 20241222: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241016.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240711.parquet跳过日期 20240915: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240814.parquet跳过日期 20240505: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241119.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240402.parquet
# 跳过日期 20240608: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241223.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241017.parquet
# 跳过日期 20240712: 原始数据文件不存在
# 跳过日期 20240916: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240815.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240506.parquet
# 跳过日期 20241120: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240403.parquet跳过日期 20240609: 原始数据文件不存在
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241224.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241018.parquet
# 跳过日期 20240713: 原始数据文件不存在
# 跳过日期 20240917: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240507.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240816.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241121.parquet
#
# 跳过日期 20240404: 原始数据文件不存在跳过日期 20240610: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241225.parquet
#
# 跳过日期 20241019: 原始数据文件不存在
# 跳过日期 20240714: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240918.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240508.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241122.parquet跳过日期 20240817: 原始数据文件不存在
# 跳过日期 20240405: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240611.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241226.parquet
#
# 跳过日期 20241020: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240715.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240919.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240509.parquet跳过日期 20241123: 原始数据文件不存在
# 跳过日期 20240818: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240612.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241227.parquet
#
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241021.parquet文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240716.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240920.parquet跳过日期 20241124: 原始数据文件不存在
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20240819.parquet
#
# 跳过日期 20241228: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241022.parquet
# 跳过日期 20240921: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241125.parquet
# 跳过日期 20241229: 原始数据文件不存在
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241023.parquet
# 跳过日期 20240922: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241126.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241230.parquet
#
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241024.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241127.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241231.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241025.parquet
# 文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241128.parquet
#
# 跳过日期 20241026: 原始数据文件不存在文件已存在，跳过: ./factors/Improved_Early_Order_Size_Ratio/20241129.parquet
#
#
# 处理完成:
# 成功处理 854 个日期
# 跳过 470 个日期
# 所有因子文件已生成在目录: ./factors/Improved_Early_Order_Size_Ratio
# 在目录 ./factors/Improved_Early_Order_Size_Ratio 中找到 854 个Parquet文件
#
# 处理因子: large_order_count_ratio
#
# large_order_count_ratio因子覆盖率统计: 平均=0.92, 最小=0.81
#
# 处理因子: large_order_volume_ratio
#
# large_order_volume_ratio因子覆盖率统计: 平均=0.92, 最小=0.81
#
# 处理因子: large_order_avg_buy_size
#
# large_order_avg_buy_size因子覆盖率统计: 平均=0.92, 最小=0.81
#
# 处理因子: large_order_avg_sell_size
#
# large_order_avg_sell_size因子覆盖率统计: 平均=0.92, 最小=0.81
#
# 处理因子: large_order_threshold
#
# large_order_threshold因子覆盖率统计: 平均=0.92, 最小=0.81
#
# 处理因子: large_order_count
#
# large_order_count因子覆盖率统计: 平均=0.92, 最小=0.81
#
# 处理因子: large_net_order_volume_ratio
#
# large_net_order_volume_ratio因子覆盖率统计: 平均=0.92, 最小=0.81
#
# 处理因子: net_order_volume_ratio
#
# net_order_volume_ratio因子覆盖率统计: 平均=0.92, 最小=0.81
# 共计 4148651 条记录
#
# 数据预览:
#         date security_code  large_order_count_ratio  large_order_volume_ratio  \
# 0 2021-05-18        000001                      NaN                       NaN
# 1 2021-05-18        000002                      NaN                       NaN
# 2 2021-05-18        000004                      NaN                       NaN
# 3 2021-05-18        000005                      NaN                       NaN
# 4 2021-05-18        000006                      NaN                       NaN
#
#    large_order_avg_buy_size  large_order_avg_sell_size  large_order_threshold  \
# 0                       NaN                        NaN                    NaN
# 1                       NaN                        NaN                    NaN
# 2                       NaN                        NaN                    NaN
# 3                       NaN                        NaN                    NaN
# 4                       NaN                        NaN                    NaN
#
#    large_order_count  large_net_order_volume_ratio  net_order_volume_ratio
# 0                NaN                           NaN                     NaN
# 1                NaN                           NaN                     NaN
# 2                NaN                           NaN                     NaN
# 3                NaN                           NaN                     NaN
# 4                NaN                           NaN                     NaN

# %%
def main():

    start_date = '2016-06-20'
    end_date = '2025-06-30'
    
    all_factors = [
    'early_930_1030_net_order_volume_ratio',
    'early_930_1000_net_order_volume_ratio',
    'early_1000_1030_net_order_volume_ratio',
    'early_930_1030_avg_order_volume_ratio',
    'early_930_1000_avg_order_volume_ratio',
    'early_1000_1030_avg_order_volume_ratio',
    'early_930_1030_sum_order_volume_ratio',
    'early_930_1000_sum_order_volume_ratio',
    'early_1000_1030_sum_order_volume_ratio'
    ]


    factor_name = "Improved_Early_Order_Size_Ratio_3_2"

    # trading_dates = pd.date_range(start=start_date, end=end_date, freq='D')
    
    # for trading_date in trading_dates:
        
    #     process_single_date(trading_date,factor_name)

    # factor_dir = output_dir = f"./factors/{factor_name}"

    factor_dir = "/data/home/lexuanchen/.conda/envs/Order_Improvement/factors/Improved_Early_Order_Size_Ratio_3"
    # factor_dir = derive_daily_factor(start_date, end_date, factor_name, num_processes=10)

    
    print(f"所有因子文件已生成在目录: {factor_dir}")

    result_df = calculate_rolling_20d_avg(all_factors, factor_dir, start_date, end_date, min_window=5)
    
    # 保存结果为CSV
    output_path = "/data/home/lexuanchen/Factors/Order/Signal/Improved_Early_Order_Size_Ratio_3_2"
    os.makedirs(output_path, exist_ok=True)

    print(f"共计 {len(result_df)} 条记录")

    print("\n数据预览:")
    print(result_df.head())


    for factor in all_factors:
        output_file_path = f"{output_path}/{factor}.csv"
        factor_df = result_df[['date', 'security_code', factor]]
        factor_df.to_csv(output_file_path, index=False)

# 执行主函数
if __name__ == "__main__":
    main()
# Out:
# 所有因子文件已生成在目录: /data/home/lexuanchen/.conda/envs/Order_Improvement/factors/Improved_Early_Order_Size_Ratio_3
# 在目录 /data/home/lexuanchen/.conda/envs/Order_Improvement/factors/Improved_Early_Order_Size_Ratio_3 中找到 2193 个Parquet文件
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 处理因子: early_930_1030_net_order_volume_ratio
#
# early_930_1030_net_order_volume_ratio因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: early_930_1000_net_order_volume_ratio
#
# early_930_1000_net_order_volume_ratio因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: early_1000_1030_net_order_volume_ratio
#
# early_1000_1030_net_order_volume_ratio因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: early_930_1030_avg_order_volume_ratio
#
# early_930_1030_avg_order_volume_ratio因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: early_930_1000_avg_order_volume_ratio
#
# early_930_1000_avg_order_volume_ratio因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: early_1000_1030_avg_order_volume_ratio
#
# early_1000_1030_avg_order_volume_ratio因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: early_930_1030_sum_order_volume_ratio
#
# early_930_1030_sum_order_volume_ratio因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: early_930_1000_sum_order_volume_ratio
#
# early_930_1000_sum_order_volume_ratio因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: early_1000_1030_sum_order_volume_ratio
#
# early_1000_1030_sum_order_volume_ratio因子覆盖率统计: 平均=0.77, 最小=0.47
# 共计 8996951 条记录
#
# 数据预览:
#         date security_code  early_930_1030_net_order_volume_ratio  \
# 0 2016-06-20        000001                                    NaN
# 1 2016-06-20        000005                                    NaN
# 2 2016-06-20        000006                                    NaN
# 3 2016-06-20        000008                                    NaN
# 4 2016-06-20        000009                                    NaN
#
#    early_930_1000_net_order_volume_ratio  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    early_1000_1030_net_order_volume_ratio  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    early_930_1030_avg_order_volume_ratio  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    early_930_1000_avg_order_volume_ratio  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    early_1000_1030_avg_order_volume_ratio  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    early_930_1030_sum_order_volume_ratio  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    early_930_1000_sum_order_volume_ratio  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    early_1000_1030_sum_order_volume_ratio
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
