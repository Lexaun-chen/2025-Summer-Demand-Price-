# %%
import connectorx as cx
import pandas as pd
import numpy as np
import os
import duckdb
from datetime import datetime, timedelta
import glob
import multiprocessing 
from functools import partial
import time
import traceback

# %%
duckdb.query("SET worker_threads=1")

# %%
import os
import glob
import logging
import pandas as pd
import numpy as np
import duckdb
from datetime import datetime, timedelta

# 设置日志
logger = logging.getLogger(__name__)
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)


def calculate_minute_level_apb(trading_date):
    """计算分钟级APB因子"""

    trading_date = pd.to_datetime(trading_date)

    date_str = trading_date.strftime('%Y%m%d')
    
    order_pth = f"/data/cephfs/transaction/{date_str}.parquet"
    
    # 确保输出目录存在
    output_dir = "./factors/Transaction_minute_level_APB"
    os.makedirs(output_dir, exist_ok=True)

    output_file = f"{output_dir}/{date_str}.parquet"
    
    if not os.path.exists(order_pth):
        return
        # raise FileNotFoundError(f"订单数据文件不存在: {order_pth}")
    
    # 如果该日期的文件已存在，跳过处理
    if os.path.exists(output_file):
        # print(f"日期 {date_str} 已处理，跳过")
        return

    conn = duckdb.connect(database=':memory:')

    # 1. 读取毫秒级订单簿数据并转换为分钟级
    query_order = f"""
        WITH buy_orders_with_time AS(
            SELECT 
                security_code,
                order_side, 
                order_type,
                order_details,
                order_price,
                order_price_adj,
                order_volume,
                order_time,
                ('{date_str}'::DATE + MAKE_TIME(
                    FLOOR(order_time / 10000000)::int,
                    (FLOOR(order_time / 100000) % 100)::int,
                    (FLOOR(order_time / 1000) % 100)::numeric + 
                    (order_time % 1000)::numeric / 1000)
                )::TIMESTAMP AS formatted_time
            FROM '{order_pth}'
            WHERE order_side = 1
                AND order_type = 'A'
                AND order_details = 'L'
                AND order_price > 0
                AND order_volume > 0
                AND order_time >= 93000000
                AND order_time < 145700000
        )
        SELECT
            security_code,
            order_price,
            order_volume,
            DATE_TRUNC('minute', formatted_time) AS order_minute
        FROM buy_orders_with_time
        """

    # 将数据加载到临时表中
    conn.execute(f"CREATE TEMPORARY TABLE minute_order AS {query_order}")

    # 2. 计算每分钟的VWAP和TWAP
    minute_apb_query = """
        WITH minute_level_stats AS (
            -- 直接计算每分钟的VWAP和TWAP
            SELECT 
                security_code,
                order_minute,
                SUM(order_volume * order_price) / SUM(order_volume) AS vwap,
                AVG(order_price) AS twap,
                SUM(order_volume) AS total_volume
            FROM minute_order
            GROUP BY security_code, order_minute
        )
        -- 计算APB因子
        SELECT 
            '{date_str}' AS date_str,
            security_code,
            order_minute,
            vwap,
            twap,
            CASE 
                WHEN twap > 0 AND vwap > 0 THEN LN(twap / vwap)
                ELSE NULL
            END AS apb,
            (twap - vwap) / vwap AS apb_alt,
            total_volume
        FROM minute_level_stats
        WHERE total_volume > 0
        ORDER BY security_code
    """

    # 3. 保存分钟级数据
    minute_apb_df = conn.execute(minute_apb_query).fetchdf()
    
    # 保存分钟级数据
    minute_apb_df.to_parquet(output_file)
    
    return minute_apb_df

def process_all_trading_days(trading_dates):
    """处理所有交易日的数据"""
    for date in trading_dates:
        try:
            calculate_minute_level_apb(date)
            # print(f"成功处理日期: {date}")
        except Exception as e:
            print(f"处理日期 {date} 时出错: {str(e)}")



# def calculate_rolling_average(window_size=1200, daily_min=400,start_date=None, end_date=None):
#     """计算滚动平均APB因子，采用分批处理方式"""
#     data_dir = "./factors/minute_level_APB"  
#     parquet_files = sorted(glob.glob(os.path.join(data_dir, "*.parquet")))

#     if not parquet_files:
#         raise ValueError("未找到分钟级数据文件")

#     logger.info(f"找到 {len(parquet_files)} 个分钟级数据文件")
    
#     # 假设文件名是日期格式，如 "20210602.parquet"
#     # 提取文件名中的日期并排序
#     file_dates = []
#     for file_path in parquet_files:
#         file_name = os.path.basename(file_path)
#         date_str = file_name.split('.')[0]  # 假设文件名格式为 "YYYYMMDD.parquet"
#         file_dates.append((date_str, file_path))
    
#     # 按日期排序
#     file_dates.sort(key=lambda x: x[0])
    
#     # 如果指定了日期范围，筛选文件
#     if start_date and end_date:
#         file_dates = [(date, path) for date, path in file_dates 
#                       if start_date <= date <= end_date]
    
#     if not file_dates:
#         raise ValueError("筛选后没有符合条件的数据文件")
    
#     output_dir = "./factors/minute_level_APB/1200_Rolling"

#     # 确保输出目录存在
#     os.makedirs(output_dir, exist_ok=True)

#     for i in range(5,len(file_dates)):  # 从第6个文件开始，确保有前5天的数据
#         current_date, current_file = file_dates[i]
#         logger.info(f"处理日期 {current_date} 的数据")
        
#         # 检查输出文件是否已存在
#         output_file = os.path.join(output_dir, f"{current_date}.parquet")
#         if os.path.exists(output_file):
#             logger.info(f"日期 {current_date} 的结果文件已存在，跳过处理")
#             continue
        
#         # 获取当前日期和前5天的文件
#         start_idx = max(0, i-5)  # 确保不会索引到负数
#         recent_files = [path for _, path in file_dates[start_idx:i+1]]
        
#         # 读取这些天的数据
#         dfs = []
#         for file_path in recent_files:
#             try:
#                 df = pd.read_parquet(file_path)
#                 # 修复date_str列
#                 df['date_str'] = df['order_minute'].dt.strftime('%Y%m%d')
#                 # 添加分钟时间
#                 df['order_minute'] = df['order_minute'].dt.strftime('%H:%M')
#                 dfs.append(df)
#             except Exception as e:
#                 logger.error(f"读取文件 {file_path} 时出错: {str(e)}")
#                 continue
        
#         if not dfs:
#             logger.warning(f"日期 {current_date} 没有有效数据，跳过")
#             continue
        
#         # 合并数据
#         combined_data = pd.concat(dfs, ignore_index=True)
        
#         try:
#             # 只处理当前日期的结果
#             # 使用透视表方式计算滚动平均
#             # 先创建一个唯一的时间索引，确保数据按时间顺序排列
#             combined_data.sort_values(['security_code', 'date_str', 'order_minute'], inplace=True)
#             combined_data['time_idx'] = combined_data.groupby('security_code').cumcount()
            
#             # 为每个股票创建透视表
#             pivot_data = combined_data.pivot_table(
#                 index='time_idx', 
#                 columns='security_code', 
#                 values='apb',
#                 aggfunc='first'  # 如果有重复的time_idx，取第一个值
#             )
            
#             # 计算滚动平均
#             rolling_avg = pivot_data.rolling(window=window_size, min_periods=daily_min).mean()
            
#             # 将结果转回长格式
#             rolling_result = rolling_avg.stack().reset_index()
#             rolling_result.columns = ['time_idx', 'security_code', 'rolling_apb']
            
#             # 与原始数据合并，获取日期信息
#             rolling_result = pd.merge(
#                 rolling_result,
#                 combined_data[['security_code', 'time_idx', 'date_str', 'order_minute']],
#                 on=['security_code', 'time_idx'],
#                 how='left'
#             )
            
#             # 只保留当前日期的数据
#             current_date_result = rolling_result[rolling_result['date_str'] == current_date].copy()
            
#             # 计算每日平均值
#             daily_factor = current_date_result.groupby(['date_str', 'security_code'])['rolling_apb'].mean().reset_index()

#             daily_factor.columns = ['date', 'security_code', 'rolling_apb']
            
#             # 保存当天的结果到parquet文件
#             daily_factor.to_parquet(output_file)
#             logger.info(f"已保存日期 {current_date} 的结果到 {output_file}")
            
            
#             # 清理内存
#             del combined_data, pivot_data, rolling_avg, rolling_result, current_date_result, daily_factor
#             import gc
#             gc.collect()
            
#         except Exception as e:
#             logger.error(f"处理日期 {current_date} 时发生错误: {str(e)}")
#             import traceback
#             logger.error(traceback.format_exc())
    
    # return output_dir

# %%
import concurrent.futures
import os
import glob
import pandas as pd
import logging
import traceback
import gc
from functools import partial

def process_single_date(date_info, window_size=1200, min_periods=400, output_dir="./factors/minute_level_APB/1200_Rolling"):
    """处理单个日期的数据"""
    current_date, current_file, recent_files = date_info
    
    # 设置每个线程的logger
    thread_logger = logging.getLogger(f"thread_{current_date}")
    if not thread_logger.handlers:
        handler = logging.StreamHandler()
        formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
        handler.setFormatter(formatter)
        thread_logger.addHandler(handler)
        thread_logger.setLevel(logging.INFO)
    
    thread_logger.info(f"开始处理日期 {current_date} 的数据")
    
    # 检查输出文件是否已存在
    output_file = os.path.join(output_dir, f"{current_date}.parquet")
    if os.path.exists(output_file):
        thread_logger.info(f"日期 {current_date} 的结果文件已存在，跳过处理")
        return current_date, True, "文件已存在"
    
    try:
        # 读取这些天的数据
        dfs = []
        for file_path in recent_files:
            try:
                df = pd.read_parquet(file_path)
                # 修复date_str列
                df['date_str'] = df['order_minute'].dt.strftime('%Y%m%d')
                # 添加分钟时间
                df['order_minute'] = df['order_minute'].dt.strftime('%H:%M')
                dfs.append(df)
            except Exception as e:
                thread_logger.error(f"读取文件 {file_path} 时出错: {str(e)}")
                continue
        
        if not dfs:
            thread_logger.warning(f"日期 {current_date} 没有有效数据，跳过")
            return current_date, False, "没有有效数据"
        
        # 合并数据
        combined_data = pd.concat(dfs, ignore_index=True)
        
        # 使用透视表方式计算滚动平均
        # 先创建一个唯一的时间索引，确保数据按时间顺序排列
        combined_data.sort_values(['security_code', 'date_str', 'order_minute'], inplace=True)
        combined_data['time_idx'] = combined_data.groupby('security_code').cumcount()
        
        # 为每个股票创建透视表
        pivot_data = combined_data.pivot_table(
            index='time_idx', 
            columns='security_code', 
            values='apb',
            aggfunc='first'  # 如果有重复的time_idx，取第一个值
        )
        
        # 计算滚动平均
        rolling_avg = pivot_data.rolling(window=window_size, min_periods=min_periods).mean()
        
        # 将结果转回长格式
        rolling_result = rolling_avg.stack().reset_index()
        rolling_result.columns = ['time_idx', 'security_code', 'rolling_apb']
        
        # 与原始数据合并，获取日期信息
        rolling_result = pd.merge(
            rolling_result,
            combined_data[['security_code', 'time_idx', 'date_str', 'order_minute']],
            on=['security_code', 'time_idx'],
            how='left'
        )
        
        # 只保留当前日期的数据
        current_date_result = rolling_result[rolling_result['date_str'] == current_date].copy()
        
        # 计算每日平均值
        daily_factor = current_date_result.groupby(['date_str', 'security_code'])['rolling_apb'].mean().reset_index()
        daily_factor.columns = ['date', 'security_code', 'rolling_apb']
        
        # 保存当天的结果到parquet文件
        daily_factor.to_parquet(output_file)
        thread_logger.info(f"已保存日期 {current_date} 的结果到 {output_file}")
        
        # 清理内存
        del combined_data, pivot_data, rolling_avg, rolling_result, current_date_result, daily_factor
        gc.collect()
        
        return current_date, True, f"处理成功，结果已保存到 {output_file}"
        
    except Exception as e:
        error_msg = f"处理日期 {current_date} 时发生错误: {str(e)}\n{traceback.format_exc()}"
        thread_logger.error(error_msg)
        return current_date, False, error_msg

def calculate_rolling_average(window_size=1200, daily_min=400, start_date=None, end_date=None, max_workers=4):
    """计算滚动平均APB因子，采用多线程分批处理方式"""
    # 设置主logger
    logger = logging.getLogger("main")
    if not logger.handlers:
        handler = logging.StreamHandler()
        formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
        handler.setFormatter(formatter)
        logger.addHandler(handler)
        logger.setLevel(logging.INFO)
    
    data_dir = "./factors/minute_level_APB"  
    parquet_files = sorted(glob.glob(os.path.join(data_dir, "*.parquet")))

    if not parquet_files:
        raise ValueError("未找到分钟级数据文件")

    logger.info(f"找到 {len(parquet_files)} 个分钟级数据文件")
    
    # 假设文件名是日期格式，如 "20210602.parquet"
    # 提取文件名中的日期并排序
    file_dates = []
    for file_path in parquet_files:
        file_name = os.path.basename(file_path)
        date_str = file_name.split('.')[0]  # 假设文件名格式为 "YYYYMMDD.parquet"
        file_dates.append((date_str, file_path))
    
    # 按日期排序
    file_dates.sort(key=lambda x: x[0])
    
    # 如果指定了日期范围，筛选文件
    if start_date and end_date:
        file_dates = [(date, path) for date, path in file_dates 
                      if start_date <= date <= end_date]
    
    if not file_dates:
        raise ValueError("筛选后没有符合条件的数据文件")
    
    output_dir = "./factors/minute_level_APB/1200_Rolling"

    # 确保输出目录存在
    os.makedirs(output_dir, exist_ok=True)

    # 准备任务列表
    tasks = []
    for i in range(5, len(file_dates)):  # 从第6个文件开始，确保有前5天的数据
        current_date, current_file = file_dates[i]
        
        # 检查输出文件是否已存在（快速检查，避免创建不必要的任务）
        output_file = os.path.join(output_dir, f"{current_date}.parquet")
        if os.path.exists(output_file):
            logger.info(f"日期 {current_date} 的结果文件已存在，跳过处理")
            continue
            
        # 获取当前日期和前5天的文件
        start_idx = max(0, i-5)  # 确保不会索引到负数
        recent_files = [path for _, path in file_dates[start_idx:i+1]]
        
        tasks.append((current_date, current_file, recent_files))
    
    if not tasks:
        logger.info("没有需要处理的新数据")
        return output_dir
    
    logger.info(f"准备处理 {len(tasks)} 个日期的数据")
    
    # 创建处理函数的偏函数，固定window_size和min_periods参数
    process_func = partial(process_single_date, window_size=window_size, min_periods=daily_min, output_dir=output_dir)
    
    # 使用线程池并行处理
    results = []
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_date = {executor.submit(process_func, task): task[0] for task in tasks}
        for future in concurrent.futures.as_completed(future_to_date):
            date = future_to_date[future]
            try:
                result = future.result()
                results.append(result)
                logger.info(f"日期 {date} 处理完成: {result[2]}")
            except Exception as exc:
                logger.error(f"日期 {date} 处理失败: {str(exc)}")
    
    # 汇总处理结果
    success_count = sum(1 for _, success, _ in results if success)
    logger.info(f"处理完成。成功: {success_count}/{len(tasks)}")
    
    return output_dir

# %%
def calculate_rolling_20d_avg(factor_names, factor_dir, min_window=5):
    
    if not isinstance(factor_names, list):
        factor_names = [factor_names]
    
    parquet_pattern = os.path.join(factor_dir, "*.parquet")
    parquet_files = glob.glob(parquet_pattern)
    print(f"在目录 {factor_dir} 中找到 {len(parquet_files)} 个Parquet文件")
    

    conn = duckdb.connect(database=':memory:')
    all_factor_data = conn.execute(f"""
        SELECT * FROM read_parquet('{parquet_pattern}')
    """).fetchdf()
    conn.close()
    

    missing_factors = [f for f in factor_names if f not in all_factor_data.columns]
    if missing_factors:
        raise ValueError(f"在Parquet文件中未找到以下因子列: {', '.join(missing_factors)}")
    
    all_factor_data['date'] = pd.to_datetime(all_factor_data['date'])

    all_factor_data = all_factor_data.sort_values(['date', 'security_code'])


    # 获取所有个股代码
    all_securities = all_factor_data['security_code'].unique()

    result_df = all_factor_data[['date', 'security_code']].copy()

    # 为每个因子计算滚动平均
    for factor_name in factor_names:
        print(f"\n处理因子: {factor_name}")
        
        #转置成宽表
        pivot_data = all_factor_data.pivot(index='date', columns='security_code', values=factor_name)

        # 对宽表直接应用rolling
        rolling_avg = pivot_data.rolling(window=20, min_periods=min_window).mean()

        # 将结果转换回长格式
        factor_df = rolling_avg.stack().reset_index()
        factor_df.columns = ['date', 'security_code', factor_name]
        factor_df[factor_name] = - factor_df[factor_name]

        # 计算每日因子覆盖率
        # 计算每个日期非NaN的因子值数量
        non_nan_counts = factor_df.dropna(subset=[factor_name]).groupby('date').size()

        # 计算覆盖率
        coverage = non_nan_counts / len(all_securities)
        print(f"\n{factor_name}因子覆盖率统计: 平均={coverage.mean():.2f}, 最小={coverage.min():.2f}")

        result_df = pd.merge(
            result_df, 
            factor_df,
            on=['date', 'security_code'],
            how='left'
        )
    
    return result_df

# %%
def main():
    # 获取所有交易日期
    start_date = '2019-01-01'
    end_date = '2025-05-31'

    trading_dates = pd.date_range(start=start_date, end=end_date, freq='D')
    
    # 1. 计算所有交易日的分钟级APB
    process_all_trading_days(trading_dates)
    
    # # 2. 计算滚动平均和每日因子值
    # rolling_df_dir = calculate_rolling_average(window_size=1200,daily_min=400)

    # factor_name ='rolling_apb'
    # daily_factor = calculate_rolling_20d_avg(factor_name,rolling_df_dir)
    
    # # 保存结果为CSV
    # output_path = "/data/home/lexuanchen/Factors/Order/Signal/Improved_APB"
    # os.makedirs(output_path, exist_ok=True)
    # output_file_path = f"{output_path}/MinuteRoll_Raw_Order_APB.csv"
    # daily_factor.to_csv(output_file_path, index=False)
    
    # print("APB因子计算完成")
    # print(daily_factor.head())

if __name__ == "__main__":
    main()

# %%
# 查看结果统计
output_path = "/data/home/lexuanchen/Factors/Order/Signal/Improved_APB"
order_pth = f"{output_path}/MinuteRoll_Raw_Order_APB.csv"
factor_df = pd.read_csv(f'{order_pth}')
factor_name = 'rolling_apb'
factor_df[factor_name] = - factor_df[factor_name]

output_path = "/data/home/lexuanchen/Factors/Order/Signal/Improved_APB"
os.makedirs(output_path, exist_ok=True)
output_file_path = f"{output_path}/MinuteRoll_Raw_Order_APB.csv"
factor_df.to_csv(output_file_path,index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 11
#       9 os.makedirs(output_path, exist_ok=True)
#      10 output_file_path = f"{output_path}/MinuteRoll_Raw_Order_APB.csv"
# ---> 11 factor_df.to_csv(output_file_path,index=False)
#
# File ~/.conda/envs/test1/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/.conda/envs/test1/lib/python3.11/site-packages/pandas/core/generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)   3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~/.conda/envs/test1/lib/python3.11/site-packages/pandas/io/formats/format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)   1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~/.conda/envs/test1/lib/python3.11/site-packages/pandas/io/formats/csvs.py:270, in CSVFormatter.save(self)
#     251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#    (...)    258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)    267         quotechar=self.quotechar,
#     268     )
# --> 270     self._save()
#
# File ~/.conda/envs/test1/lib/python3.11/site-packages/pandas/io/formats/csvs.py:275, in CSVFormatter._save(self)
#     273 if self._need_to_save_header:
#     274     self._save_header()
# --> 275 self._save_body()
#
# File ~/.conda/envs/test1/lib/python3.11/site-packages/pandas/io/formats/csvs.py:313, in CSVFormatter._save_body(self)
#     311 if start_i >= end_i:
#     312     break
# --> 313 self._save_chunk(start_i, end_i)
#
# File ~/.conda/envs/test1/lib/python3.11/site-packages/pandas/io/formats/csvs.py:320, in CSVFormatter._save_chunk(self, start_i, end_i)
#     317 slicer = slice(start_i, end_i)
#     318 df = self.obj.iloc[slicer]
# --> 320 res = df._get_values_for_csv(**self._number_format)
#     321 data = list(res._iter_column_arrays())
#     323 ix = self.data_index[slicer]._get_values_for_csv(**self._number_format)
#
# File ~/.conda/envs/test1/lib/python3.11/site-packages/pandas/core/frame.py:1410, in DataFrame._get_values_for_csv(self, float_format, date_format, decimal, na_rep, quoting)
#    1400 def _get_values_for_csv(
#    1401     self,
#    1402     *,
#    (...)   1408 ) -> Self:
#    1409     # helper used by to_csv
# -> 1410     mgr = self._mgr.get_values_for_csv(
#    1411         float_format=float_format,
#    1412         date_format=date_format,
#    1413         decimal=decimal,
#    1414         na_rep=na_rep,
#    1415         quoting=quoting,
#    1416     )
#    1417     # error: Incompatible return value type (got "DataFrame", expected "Self")
#    1418     return self._constructor_from_mgr(mgr, axes=mgr.axes)
#
# File ~/.conda/envs/test1/lib/python3.11/site-packages/pandas/core/internals/managers.py:466, in BaseBlockManager.get_values_for_csv(self, float_format, date_format, decimal, na_rep, quoting)
#     459 def get_values_for_csv(
#     460     self, *, float_format, date_format, decimal, na_rep: str = "nan", quoting=None
#     461 ) -> Self:
#     462     """
#     463     Convert values to native types (strings / python objects) that are used
#     464     in formatting (repr / csv).
#     465     """
# --> 466     return self.apply(
#     467         "get_values_for_csv",
#     468         na_rep=na_rep,
#     469         quoting=quoting,
#     470         float_format=float_format,
#     471         date_format=date_format,
#     472         decimal=decimal,
#     473     )
#
# File ~/.conda/envs/test1/lib/python3.11/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/.conda/envs/test1/lib/python3.11/site-packages/pandas/core/internals/blocks.py:780, in Block.get_values_for_csv(self, float_format, date_format, decimal, na_rep, quoting)
#     775 @final
#     776 def get_values_for_csv(
#     777     self, *, float_format, date_format, decimal, na_rep: str = "nan", quoting=None
#     778 ) -> Block:
#     779     """convert to our native types format"""
# --> 780     result = get_values_for_csv(
#     781         self.values,
#     782         na_rep=na_rep,
#     783         quoting=quoting,
#     784         float_format=float_format,
#     785         date_format=date_format,
#     786         decimal=decimal,
#     787     )
#     788     return self.make_block(result)
#
# File ~/.conda/envs/test1/lib/python3.11/site-packages/pandas/core/indexes/base.py:7834, in get_values_for_csv(values, date_format, na_rep, quoting, float_format, decimal)
#    7831 mask = isna(values)
#    7833 if not quoting:
# -> 7834     values = values.astype(str)
#    7835 else:
#    7836     values = np.array(values, dtype="object")
#
# KeyboardInterrupt:

# %%
import logging

# 设置日志
logger = logging.getLogger(__name__)
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)


def calculate_minute_level_apb(trading_date):
    """计算分钟级APB因子"""
    try:
        # 尝试在函数内部导入pandas，避免全局导入
        import pandas as pd
        
        # 如果传入的是字符串，转换为datetime对象
        if isinstance(trading_date, str):
            trading_date = pd.to_datetime(trading_date)
        
        date_str = trading_date.strftime('%Y%m%d')
        
        order_pth = f"/data/cephfs/order/{date_str}.parquet"
        
        # 确保输出目录存在
        output_dir = "./factors/Ask_minute_level_APB"
        os.makedirs(output_dir, exist_ok=True)

        output_file = f"{output_dir}/{date_str}.parquet"
        
        if not os.path.exists(order_pth):
            # logger.info(f"订单数据文件不存在: {order_pth}")
            return
        
        # 如果该日期的文件已存在，跳过处理
        if os.path.exists(output_file):
            logger.info(f"日期 {date_str} 已处理，跳过")
            return

        conn = duckdb.connect(database=':memory:')

        # 1. 读取毫秒级订单簿数据并转换为分钟级
        query_order = f"""
            WITH buy_orders_with_time AS(
                SELECT 
                    security_code,
                    order_side, 
                    order_type,
                    order_details,
                    order_price,
                    order_price_adj,
                    order_volume,
                    order_time,
                    ('{trading_date}'::DATE + MAKE_TIME(
                        FLOOR(order_time / 10000000)::int,
                        (FLOOR(order_time / 100000) % 100)::int,
                        (FLOOR(order_time / 1000) % 100)::numeric + 
                        (order_time % 1000)::numeric / 1000)
                    )::TIMESTAMP AS formatted_time
                FROM '{order_pth}'
                WHERE order_side = 1
                    AND order_type = 'A'
                    AND order_details = 'L'
                    AND order_time >= 93000000
                    AND order_time < 145700000
            )
            SELECT
                security_code,
                order_price,
                order_volume,
                DATE_TRUNC('minute', formatted_time) AS order_minute
            FROM buy_orders_with_time
            """

        # 将数据加载到临时表中
        conn.execute(f"CREATE TEMPORARY TABLE minute_order AS {query_order}")

        # 2. 计算每分钟的VWAP和TWAP
        minute_apb_query = f"""
            WITH minute_level_stats AS (
                -- 直接计算每分钟的VWAP和TWAP
                SELECT 
                    security_code,
                    order_minute,
                    SUM(order_volume * order_price) / SUM(order_volume) AS vwap,
                    AVG(order_price) AS twap,
                    SUM(order_volume) AS total_volume
                FROM minute_order
                GROUP BY security_code, order_minute
            )
            -- 计算APB因子
            SELECT 
                '{date_str}' AS date,
                security_code,
                order_minute,
                vwap,
                twap,
                CASE 
                    WHEN twap > 0 AND vwap > 0 THEN LN(twap / vwap)
                    ELSE NULL
                END AS apb,
                (twap - vwap) / vwap AS apb_alt,
                total_volume
            FROM minute_level_stats
            WHERE total_volume > 0
            ORDER BY security_code
        """

        # 3. 保存分钟级数据
        minute_apb_df = conn.execute(minute_apb_query).fetchdf()
        
        # 保存分钟级数据
        minute_apb_df.to_parquet(output_file)
        
        logger.info(f"成功处理日期: {date_str}")
        return True
    except Exception as e:
        logger.error(f"处理日期 {trading_date} 时出错: {str(e)}")
        logger.error(traceback.format_exc())
        return False


def worker_process(date):
    """工作进程函数"""
    try:
        result = calculate_minute_level_apb(date)
        return (date, result, None)
    except Exception as e:
        return (date, False, str(e))


def process_all_trading_days(trading_dates, num_processes=None):
    """使用多进程处理所有交易日的数据
    
    Args:
        trading_dates: 要处理的交易日列表
        num_processes: 进程数，默认为CPU核心数
    """
    if num_processes is None:
        num_processes = multiprocessing.cpu_count()
    
    # 确保输出目录存在
    output_dir = "./factors/Percent_Bid_minute_level_APB"
    os.makedirs(output_dir, exist_ok=True)
    
    # 过滤掉已经处理过的日期
    dates_to_process = []
    for date in trading_dates:
        # 如果是字符串格式，转换为datetime对象
        if isinstance(date, str):
            try:
                date_obj = datetime.strptime(date, '%Y-%m-%d')
            except ValueError:
                try:
                    date_obj = datetime.strptime(date, '%Y%m%d')
                except ValueError:
                    logger.error(f"无法解析日期格式: {date}")
                    continue
        else:
            date_obj = date
            
        date_str = date_obj.strftime('%Y%m%d')
        output_file = f"{output_dir}/{date_str}.parquet"
        
        if not os.path.exists(output_file):
            dates_to_process.append(date)
    
    total_dates = len(dates_to_process)
    if total_dates == 0:
        logger.info("所有日期已处理完毕，无需再次处理")
        return
    
    logger.info(f"开始处理 {total_dates} 个交易日，使用 {num_processes} 个进程")
    
    # 创建进程池
    pool = multiprocessing.Pool(processes=num_processes)
    
    # 提交所有任务
    results = []
    for date in dates_to_process:
        result = pool.apply_async(worker_process, (date,))
        results.append(result)
    
    # 关闭进程池，不再接受新任务
    pool.close()
    
    # 显示进度
    completed = 0
    while completed < total_dates:
        completed = sum(1 for r in results if r.ready())
        logger.info(f"进度: {completed}/{total_dates}")
        time.sleep(10)  # 每10秒更新一次进度
    
    # 等待所有进程完成
    pool.join()
    
    # 处理结果
    success_count = 0
    for result in results:
        date, success, error = result.get()
        if success:
            success_count += 1
        else:
            logger.error(f"处理日期 {date} 时出错: {error}")
    
    logger.info(f"处理完成: 成功 {success_count}/{total_dates}")


# 使用示例
if __name__ == "__main__":

    start_date = '2019-01-01'
    end_date = '2025-05-31'

    trading_dates = pd.date_range(start=start_date, end=end_date, freq='D')
    
    process_all_trading_days(trading_dates, num_processes=20)
# Out:
# 2025-06-30 13:21:22,434 - __main__ - INFO - 开始处理 790 个交易日，使用 20 个进程
# 2025-06-30 13:21:22,651 - __main__ - INFO - 进度: 0/790
# 2025-06-30 13:21:32,658 - __main__ - INFO - 进度: 790/790
# 2025-06-30 13:21:42,660 - __main__ - ERROR - 处理日期 2019-01-01 00:00:00 时出错: None
# 2025-06-30 13:21:42,661 - __main__ - ERROR - 处理日期 2019-01-05 00:00:00 时出错: None
# 2025-06-30 13:21:42,662 - __main__ - ERROR - 处理日期 2019-01-06 00:00:00 时出错: None
# 2025-06-30 13:21:42,664 - __main__ - ERROR - 处理日期 2019-01-12 00:00:00 时出错: None
# 2025-06-30 13:21:42,665 - __main__ - ERROR - 处理日期 2019-01-13 00:00:00 时出错: None
# 2025-06-30 13:21:42,666 - __main__ - ERROR - 处理日期 2019-01-19 00:00:00 时出错: None
# 2025-06-30 13:21:42,667 - __main__ - ERROR - 处理日期 2019-01-20 00:00:00 时出错: None
# 2025-06-30 13:21:42,668 - __main__ - ERROR - 处理日期 2019-01-26 00:00:00 时出错: None
# 2025-06-30 13:21:42,668 - __main__ - ERROR - 处理日期 2019-01-27 00:00:00 时出错: None
# 2025-06-30 13:21:42,669 - __main__ - ERROR - 处理日期 2019-02-02 00:00:00 时出错: None
# 2025-06-30 13:21:42,670 - __main__ - ERROR - 处理日期 2019-02-03 00:00:00 时出错: None
# 2025-06-30 13:21:42,671 - __main__ - ERROR - 处理日期 2019-02-04 00:00:00 时出错: None
# 2025-06-30 13:21:42,672 - __main__ - ERROR - 处理日期 2019-02-05 00:00:00 时出错: None
# 2025-06-30 13:21:42,673 - __main__ - ERROR - 处理日期 2019-02-06 00:00:00 时出错: None
# 2025-06-30 13:21:42,674 - __main__ - ERROR - 处理日期 2019-02-07 00:00:00 时出错: None
# 2025-06-30 13:21:42,675 - __main__ - ERROR - 处理日期 2019-02-08 00:00:00 时出错: None
# 2025-06-30 13:21:42,676 - __main__ - ERROR - 处理日期 2019-02-09 00:00:00 时出错: None
# 2025-06-30 13:21:42,677 - __main__ - ERROR - 处理日期 2019-02-10 00:00:00 时出错: None
# 2025-06-30 13:21:42,678 - __main__ - ERROR - 处理日期 2019-02-16 00:00:00 时出错: None
# 2025-06-30 13:21:42,679 - __main__ - ERROR - 处理日期 2019-02-17 00:00:00 时出错: None
# 2025-06-30 13:21:42,679 - __main__ - ERROR - 处理日期 2019-02-23 00:00:00 时出错: None
# 2025-06-30 13:21:42,680 - __main__ - ERROR - 处理日期 2019-02-24 00:00:00 时出错: None
# 2025-06-30 13:21:42,681 - __main__ - ERROR - 处理日期 2019-03-02 00:00:00 时出错: None
# 2025-06-30 13:21:42,682 - __main__ - ERROR - 处理日期 2019-03-03 00:00:00 时出错: None
# 2025-06-30 13:21:42,683 - __main__ - ERROR - 处理日期 2019-03-09 00:00:00 时出错: None
# 2025-06-30 13:21:42,684 - __main__ - ERROR - 处理日期 2019-03-10 00:00:00 时出错: None
# 2025-06-30 13:21:42,685 - __main__ - ERROR - 处理日期 2019-03-16 00:00:00 时出错: None
# 2025-06-30 13:21:42,686 - __main__ - ERROR - 处理日期 2019-03-17 00:00:00 时出错: None
# 2025-06-30 13:21:42,687 - __main__ - ERROR - 处理日期 2019-03-23 00:00:00 时出错: None
# 2025-06-30 13:21:42,688 - __main__ - ERROR - 处理日期 2019-03-24 00:00:00 时出错: None
# 2025-06-30 13:21:42,689 - __main__ - ERROR - 处理日期 2019-03-30 00:00:00 时出错: None
# 2025-06-30 13:21:42,690 - __main__ - ERROR - 处理日期 2019-03-31 00:00:00 时出错: None
# 2025-06-30 13:21:42,691 - __main__ - ERROR - 处理日期 2019-04-05 00:00:00 时出错: None
# 2025-06-30 13:21:42,692 - __main__ - ERROR - 处理日期 2019-04-06 00:00:00 时出错: None
# 2025-06-30 13:21:42,693 - __main__ - ERROR - 处理日期 2019-04-07 00:00:00 时出错: None
# 2025-06-30 13:21:42,694 - __main__ - ERROR - 处理日期 2019-04-13 00:00:00 时出错: None
# 2025-06-30 13:21:42,695 - __main__ - ERROR - 处理日期 2019-04-14 00:00:00 时出错: None
# 2025-06-30 13:21:42,696 - __main__ - ERROR - 处理日期 2019-04-20 00:00:00 时出错: None
# 2025-06-30 13:21:42,697 - __main__ - ERROR - 处理日期 2019-04-21 00:00:00 时出错: None
# 2025-06-30 13:21:42,698 - __main__ - ERROR - 处理日期 2019-04-27 00:00:00 时出错: None
# 2025-06-30 13:21:42,699 - __main__ - ERROR - 处理日期 2019-04-28 00:00:00 时出错: None
# 2025-06-30 13:21:42,700 - __main__ - ERROR - 处理日期 2019-05-01 00:00:00 时出错: None
# 2025-06-30 13:21:42,700 - __main__ - ERROR - 处理日期 2019-05-02 00:00:00 时出错: None
# 2025-06-30 13:21:42,701 - __main__ - ERROR - 处理日期 2019-05-03 00:00:00 时出错: None
# 2025-06-30 13:21:42,702 - __main__ - ERROR - 处理日期 2019-05-04 00:00:00 时出错: None
# 2025-06-30 13:21:42,703 - __main__ - ERROR - 处理日期 2019-05-05 00:00:00 时出错: None
# 2025-06-30 13:21:42,704 - __main__ - ERROR - 处理日期 2019-05-11 00:00:00 时出错: None
# 2025-06-30 13:21:42,705 - __main__ - ERROR - 处理日期 2019-05-12 00:00:00 时出错: None
# 2025-06-30 13:21:42,706 - __main__ - ERROR - 处理日期 2019-05-18 00:00:00 时出错: None
# 2025-06-30 13:21:42,707 - __main__ - ERROR - 处理日期 2019-05-19 00:00:00 时出错: None
# 2025-06-30 13:21:42,708 - __main__ - ERROR - 处理日期 2019-05-25 00:00:00 时出错: None
# 2025-06-30 13:21:42,709 - __main__ - ERROR - 处理日期 2019-05-26 00:00:00 时出错: None
# 2025-06-30 13:21:42,710 - __main__ - ERROR - 处理日期 2019-06-01 00:00:00 时出错: None
# 2025-06-30 13:21:42,711 - __main__ - ERROR - 处理日期 2019-06-02 00:00:00 时出错: None
# 2025-06-30 13:21:42,712 - __main__ - ERROR - 处理日期 2019-06-07 00:00:00 时出错: None
# 2025-06-30 13:21:42,713 - __main__ - ERROR - 处理日期 2019-06-08 00:00:00 时出错: None
# 2025-06-30 13:21:42,713 - __main__ - ERROR - 处理日期 2019-06-09 00:00:00 时出错: None
# 2025-06-30 13:21:42,714 - __main__ - ERROR - 处理日期 2019-06-15 00:00:00 时出错: None
# 2025-06-30 13:21:42,715 - __main__ - ERROR - 处理日期 2019-06-16 00:00:00 时出错: None
# 2025-06-30 13:21:42,716 - __main__ - ERROR - 处理日期 2019-06-22 00:00:00 时出错: None
# 2025-06-30 13:21:42,717 - __main__ - ERROR - 处理日期 2019-06-23 00:00:00 时出错: None
# 2025-06-30 13:21:42,718 - __main__ - ERROR - 处理日期 2019-06-29 00:00:00 时出错: None
# 2025-06-30 13:21:42,719 - __main__ - ERROR - 处理日期 2019-06-30 00:00:00 时出错: None
# 2025-06-30 13:21:42,720 - __main__ - ERROR - 处理日期 2019-07-06 00:00:00 时出错: None
# 2025-06-30 13:21:42,721 - __main__ - ERROR - 处理日期 2019-07-07 00:00:00 时出错: None
# 2025-06-30 13:21:42,722 - __main__ - ERROR - 处理日期 2019-07-13 00:00:00 时出错: None
# 2025-06-30 13:21:42,723 - __main__ - ERROR - 处理日期 2019-07-14 00:00:00 时出错: None
# 2025-06-30 13:21:42,724 - __main__ - ERROR - 处理日期 2019-07-20 00:00:00 时出错: None
# 2025-06-30 13:21:42,725 - __main__ - ERROR - 处理日期 2019-07-21 00:00:00 时出错: None
# 2025-06-30 13:21:42,726 - __main__ - ERROR - 处理日期 2019-07-27 00:00:00 时出错: None
# 2025-06-30 13:21:42,727 - __main__ - ERROR - 处理日期 2019-07-28 00:00:00 时出错: None
# 2025-06-30 13:21:42,728 - __main__ - ERROR - 处理日期 2019-08-03 00:00:00 时出错: None
# 2025-06-30 13:21:42,729 - __main__ - ERROR - 处理日期 2019-08-04 00:00:00 时出错: None
# 2025-06-30 13:21:42,730 - __main__ - ERROR - 处理日期 2019-08-10 00:00:00 时出错: None
# 2025-06-30 13:21:42,731 - __main__ - ERROR - 处理日期 2019-08-11 00:00:00 时出错: None
# 2025-06-30 13:21:42,732 - __main__ - ERROR - 处理日期 2019-08-17 00:00:00 时出错: None
# 2025-06-30 13:21:42,733 - __main__ - ERROR - 处理日期 2019-08-18 00:00:00 时出错: None
# 2025-06-30 13:21:42,734 - __main__ - ERROR - 处理日期 2019-08-24 00:00:00 时出错: None
# 2025-06-30 13:21:42,735 - __main__ - ERROR - 处理日期 2019-08-25 00:00:00 时出错: None
# 2025-06-30 13:21:42,736 - __main__ - ERROR - 处理日期 2019-08-31 00:00:00 时出错: None
# 2025-06-30 13:21:42,737 - __main__ - ERROR - 处理日期 2019-09-01 00:00:00 时出错: None
# 2025-06-30 13:21:42,738 - __main__ - ERROR - 处理日期 2019-09-07 00:00:00 时出错: None
# 2025-06-30 13:21:42,739 - __main__ - ERROR - 处理日期 2019-09-08 00:00:00 时出错: None
# 2025-06-30 13:21:42,740 - __main__ - ERROR - 处理日期 2019-09-13 00:00:00 时出错: None
# 2025-06-30 13:21:42,741 - __main__ - ERROR - 处理日期 2019-09-14 00:00:00 时出错: None
# 2025-06-30 13:21:42,742 - __main__ - ERROR - 处理日期 2019-09-15 00:00:00 时出错: None
# 2025-06-30 13:21:42,743 - __main__ - ERROR - 处理日期 2019-09-21 00:00:00 时出错: None
# 2025-06-30 13:21:42,744 - __main__ - ERROR - 处理日期 2019-09-22 00:00:00 时出错: None
# 2025-06-30 13:21:42,745 - __main__ - ERROR - 处理日期 2019-09-28 00:00:00 时出错: None
# 2025-06-30 13:21:42,746 - __main__ - ERROR - 处理日期 2019-09-29 00:00:00 时出错: None
# 2025-06-30 13:21:42,747 - __main__ - ERROR - 处理日期 2019-10-01 00:00:00 时出错: None
# 2025-06-30 13:21:42,748 - __main__ - ERROR - 处理日期 2019-10-02 00:00:00 时出错: None
# 2025-06-30 13:21:42,749 - __main__ - ERROR - 处理日期 2019-10-03 00:00:00 时出错: None
# 2025-06-30 13:21:42,750 - __main__ - ERROR - 处理日期 2019-10-04 00:00:00 时出错: None
# 2025-06-30 13:21:42,751 - __main__ - ERROR - 处理日期 2019-10-05 00:00:00 时出错: None
# 2025-06-30 13:21:42,752 - __main__ - ERROR - 处理日期 2019-10-06 00:00:00 时出错: None
# 2025-06-30 13:21:42,753 - __main__ - ERROR - 处理日期 2019-10-07 00:00:00 时出错: None
# 2025-06-30 13:21:42,754 - __main__ - ERROR - 处理日期 2019-10-12 00:00:00 时出错: None
# 2025-06-30 13:21:42,755 - __main__ - ERROR - 处理日期 2019-10-13 00:00:00 时出错: None
# 2025-06-30 13:21:42,756 - __main__ - ERROR - 处理日期 2019-10-19 00:00:00 时出错: None
# 2025-06-30 13:21:42,757 - __main__ - ERROR - 处理日期 2019-10-20 00:00:00 时出错: None
# 2025-06-30 13:21:42,758 - __main__ - ERROR - 处理日期 2019-10-26 00:00:00 时出错: None
# 2025-06-30 13:21:42,759 - __main__ - ERROR - 处理日期 2019-10-27 00:00:00 时出错: None
# 2025-06-30 13:21:42,760 - __main__ - ERROR - 处理日期 2019-11-02 00:00:00 时出错: None
# 2025-06-30 13:21:42,761 - __main__ - ERROR - 处理日期 2019-11-03 00:00:00 时出错: None
# 2025-06-30 13:21:42,762 - __main__ - ERROR - 处理日期 2019-11-09 00:00:00 时出错: None
# 2025-06-30 13:21:42,763 - __main__ - ERROR - 处理日期 2019-11-10 00:00:00 时出错: None
# 2025-06-30 13:21:42,764 - __main__ - ERROR - 处理日期 2019-11-16 00:00:00 时出错: None
# 2025-06-30 13:21:42,765 - __main__ - ERROR - 处理日期 2019-11-17 00:00:00 时出错: None
# 2025-06-30 13:21:42,766 - __main__ - ERROR - 处理日期 2019-11-23 00:00:00 时出错: None
# 2025-06-30 13:21:42,767 - __main__ - ERROR - 处理日期 2019-11-24 00:00:00 时出错: None
# 2025-06-30 13:21:42,768 - __main__ - ERROR - 处理日期 2019-11-30 00:00:00 时出错: None
# 2025-06-30 13:21:42,769 - __main__ - ERROR - 处理日期 2019-12-01 00:00:00 时出错: None
# 2025-06-30 13:21:42,770 - __main__ - ERROR - 处理日期 2019-12-07 00:00:00 时出错: None
# 2025-06-30 13:21:42,771 - __main__ - ERROR - 处理日期 2019-12-08 00:00:00 时出错: None
# 2025-06-30 13:21:42,772 - __main__ - ERROR - 处理日期 2019-12-14 00:00:00 时出错: None
# 2025-06-30 13:21:42,773 - __main__ - ERROR - 处理日期 2019-12-15 00:00:00 时出错: None
# 2025-06-30 13:21:42,774 - __main__ - ERROR - 处理日期 2019-12-21 00:00:00 时出错: None
# 2025-06-30 13:21:42,775 - __main__ - ERROR - 处理日期 2019-12-22 00:00:00 时出错: None
# 2025-06-30 13:21:42,776 - __main__ - ERROR - 处理日期 2019-12-28 00:00:00 时出错: None
# 2025-06-30 13:21:42,777 - __main__ - ERROR - 处理日期 2019-12-29 00:00:00 时出错: None
# 2025-06-30 13:21:42,778 - __main__ - ERROR - 处理日期 2020-01-01 00:00:00 时出错: None
# 2025-06-30 13:21:42,779 - __main__ - ERROR - 处理日期 2020-01-04 00:00:00 时出错: None
# 2025-06-30 13:21:42,780 - __main__ - ERROR - 处理日期 2020-01-05 00:00:00 时出错: None
# 2025-06-30 13:21:42,781 - __main__ - ERROR - 处理日期 2020-01-11 00:00:00 时出错: None
# 2025-06-30 13:21:42,782 - __main__ - ERROR - 处理日期 2020-01-12 00:00:00 时出错: None
# 2025-06-30 13:21:42,782 - __main__ - ERROR - 处理日期 2020-01-18 00:00:00 时出错: None
# 2025-06-30 13:21:42,783 - __main__ - ERROR - 处理日期 2020-01-19 00:00:00 时出错: None
# 2025-06-30 13:21:42,784 - __main__ - ERROR - 处理日期 2020-01-24 00:00:00 时出错: None
# 2025-06-30 13:21:42,785 - __main__ - ERROR - 处理日期 2020-01-25 00:00:00 时出错: None
# 2025-06-30 13:21:42,786 - __main__ - ERROR - 处理日期 2020-01-26 00:00:00 时出错: None
# 2025-06-30 13:21:42,787 - __main__ - ERROR - 处理日期 2020-01-27 00:00:00 时出错: None
# 2025-06-30 13:21:42,788 - __main__ - ERROR - 处理日期 2020-01-28 00:00:00 时出错: None
# 2025-06-30 13:21:42,789 - __main__ - ERROR - 处理日期 2020-01-29 00:00:00 时出错: None
# 2025-06-30 13:21:42,790 - __main__ - ERROR - 处理日期 2020-01-30 00:00:00 时出错: None
# 2025-06-30 13:21:42,791 - __main__ - ERROR - 处理日期 2020-01-31 00:00:00 时出错: None
# 2025-06-30 13:21:42,792 - __main__ - ERROR - 处理日期 2020-02-01 00:00:00 时出错: None
# 2025-06-30 13:21:42,793 - __main__ - ERROR - 处理日期 2020-02-02 00:00:00 时出错: None
# 2025-06-30 13:21:42,794 - __main__ - ERROR - 处理日期 2020-02-08 00:00:00 时出错: None
# 2025-06-30 13:21:42,795 - __main__ - ERROR - 处理日期 2020-02-09 00:00:00 时出错: None
# 2025-06-30 13:21:42,796 - __main__ - ERROR - 处理日期 2020-02-15 00:00:00 时出错: None
# 2025-06-30 13:21:42,797 - __main__ - ERROR - 处理日期 2020-02-16 00:00:00 时出错: None
# 2025-06-30 13:21:42,798 - __main__ - ERROR - 处理日期 2020-02-22 00:00:00 时出错: None
# 2025-06-30 13:21:42,799 - __main__ - ERROR - 处理日期 2020-02-23 00:00:00 时出错: None
# 2025-06-30 13:21:42,800 - __main__ - ERROR - 处理日期 2020-02-29 00:00:00 时出错: None
# 2025-06-30 13:21:42,801 - __main__ - ERROR - 处理日期 2020-03-01 00:00:00 时出错: None
# 2025-06-30 13:21:42,802 - __main__ - ERROR - 处理日期 2020-03-07 00:00:00 时出错: None
# 2025-06-30 13:21:42,803 - __main__ - ERROR - 处理日期 2020-03-08 00:00:00 时出错: None
# 2025-06-30 13:21:42,804 - __main__ - ERROR - 处理日期 2020-03-14 00:00:00 时出错: None
# 2025-06-30 13:21:42,805 - __main__ - ERROR - 处理日期 2020-03-15 00:00:00 时出错: None
# 2025-06-30 13:21:42,806 - __main__ - ERROR - 处理日期 2020-03-21 00:00:00 时出错: None
# 2025-06-30 13:21:42,807 - __main__ - ERROR - 处理日期 2020-03-22 00:00:00 时出错: None
# 2025-06-30 13:21:42,808 - __main__ - ERROR - 处理日期 2020-03-28 00:00:00 时出错: None
# 2025-06-30 13:21:42,809 - __main__ - ERROR - 处理日期 2020-03-29 00:00:00 时出错: None
# 2025-06-30 13:21:42,810 - __main__ - ERROR - 处理日期 2020-04-04 00:00:00 时出错: None
# 2025-06-30 13:21:42,811 - __main__ - ERROR - 处理日期 2020-04-05 00:00:00 时出错: None
# 2025-06-30 13:21:42,812 - __main__ - ERROR - 处理日期 2020-04-06 00:00:00 时出错: None
# 2025-06-30 13:21:42,813 - __main__ - ERROR - 处理日期 2020-04-11 00:00:00 时出错: None
# 2025-06-30 13:21:42,814 - __main__ - ERROR - 处理日期 2020-04-12 00:00:00 时出错: None
# 2025-06-30 13:21:42,815 - __main__ - ERROR - 处理日期 2020-04-18 00:00:00 时出错: None
# 2025-06-30 13:21:42,816 - __main__ - ERROR - 处理日期 2020-04-19 00:00:00 时出错: None
# 2025-06-30 13:21:42,817 - __main__ - ERROR - 处理日期 2020-04-25 00:00:00 时出错: None
# 2025-06-30 13:21:42,818 - __main__ - ERROR - 处理日期 2020-04-26 00:00:00 时出错: None
# 2025-06-30 13:21:42,819 - __main__ - ERROR - 处理日期 2020-05-01 00:00:00 时出错: None
# 2025-06-30 13:21:42,820 - __main__ - ERROR - 处理日期 2020-05-02 00:00:00 时出错: None
# 2025-06-30 13:21:42,821 - __main__ - ERROR - 处理日期 2020-05-03 00:00:00 时出错: None
# 2025-06-30 13:21:42,822 - __main__ - ERROR - 处理日期 2020-05-04 00:00:00 时出错: None
# 2025-06-30 13:21:42,823 - __main__ - ERROR - 处理日期 2020-05-05 00:00:00 时出错: None
# 2025-06-30 13:21:42,824 - __main__ - ERROR - 处理日期 2020-05-09 00:00:00 时出错: None
# 2025-06-30 13:21:42,825 - __main__ - ERROR - 处理日期 2020-05-10 00:00:00 时出错: None
# 2025-06-30 13:21:42,826 - __main__ - ERROR - 处理日期 2020-05-16 00:00:00 时出错: None
# 2025-06-30 13:21:42,827 - __main__ - ERROR - 处理日期 2020-05-17 00:00:00 时出错: None
# 2025-06-30 13:21:42,828 - __main__ - ERROR - 处理日期 2020-05-23 00:00:00 时出错: None
# 2025-06-30 13:21:42,829 - __main__ - ERROR - 处理日期 2020-05-24 00:00:00 时出错: None
# 2025-06-30 13:21:42,830 - __main__ - ERROR - 处理日期 2020-05-30 00:00:00 时出错: None
# 2025-06-30 13:21:42,831 - __main__ - ERROR - 处理日期 2020-05-31 00:00:00 时出错: None
# 2025-06-30 13:21:42,832 - __main__ - ERROR - 处理日期 2020-06-06 00:00:00 时出错: None
# 2025-06-30 13:21:42,833 - __main__ - ERROR - 处理日期 2020-06-07 00:00:00 时出错: None
# 2025-06-30 13:21:42,834 - __main__ - ERROR - 处理日期 2020-06-13 00:00:00 时出错: None
# 2025-06-30 13:21:42,835 - __main__ - ERROR - 处理日期 2020-06-14 00:00:00 时出错: None
# 2025-06-30 13:21:42,836 - __main__ - ERROR - 处理日期 2020-06-20 00:00:00 时出错: None
# 2025-06-30 13:21:42,837 - __main__ - ERROR - 处理日期 2020-06-21 00:00:00 时出错: None
# 2025-06-30 13:21:42,838 - __main__ - ERROR - 处理日期 2020-06-25 00:00:00 时出错: None
# 2025-06-30 13:21:42,839 - __main__ - ERROR - 处理日期 2020-06-26 00:00:00 时出错: None
# 2025-06-30 13:21:42,840 - __main__ - ERROR - 处理日期 2020-06-27 00:00:00 时出错: None
# 2025-06-30 13:21:42,841 - __main__ - ERROR - 处理日期 2020-06-28 00:00:00 时出错: None
# 2025-06-30 13:21:42,842 - __main__ - ERROR - 处理日期 2020-07-04 00:00:00 时出错: None
# 2025-06-30 13:21:42,843 - __main__ - ERROR - 处理日期 2020-07-05 00:00:00 时出错: None
# 2025-06-30 13:21:42,844 - __main__ - ERROR - 处理日期 2020-07-11 00:00:00 时出错: None
# 2025-06-30 13:21:42,845 - __main__ - ERROR - 处理日期 2020-07-12 00:00:00 时出错: None
# 2025-06-30 13:21:42,846 - __main__ - ERROR - 处理日期 2020-07-18 00:00:00 时出错: None
# 2025-06-30 13:21:42,847 - __main__ - ERROR - 处理日期 2020-07-19 00:00:00 时出错: None
# 2025-06-30 13:21:42,848 - __main__ - ERROR - 处理日期 2020-07-25 00:00:00 时出错: None
# 2025-06-30 13:21:42,849 - __main__ - ERROR - 处理日期 2020-07-26 00:00:00 时出错: None
# 2025-06-30 13:21:42,850 - __main__ - ERROR - 处理日期 2020-08-01 00:00:00 时出错: None
# 2025-06-30 13:21:42,851 - __main__ - ERROR - 处理日期 2020-08-02 00:00:00 时出错: None
# 2025-06-30 13:21:42,852 - __main__ - ERROR - 处理日期 2020-08-08 00:00:00 时出错: None
# 2025-06-30 13:21:42,853 - __main__ - ERROR - 处理日期 2020-08-09 00:00:00 时出错: None
# 2025-06-30 13:21:42,854 - __main__ - ERROR - 处理日期 2020-08-15 00:00:00 时出错: None
# 2025-06-30 13:21:42,855 - __main__ - ERROR - 处理日期 2020-08-16 00:00:00 时出错: None
# 2025-06-30 13:21:42,856 - __main__ - ERROR - 处理日期 2020-08-22 00:00:00 时出错: None
# 2025-06-30 13:21:42,857 - __main__ - ERROR - 处理日期 2020-08-23 00:00:00 时出错: None
# 2025-06-30 13:21:42,858 - __main__ - ERROR - 处理日期 2020-08-29 00:00:00 时出错: None
# 2025-06-30 13:21:42,858 - __main__ - ERROR - 处理日期 2020-08-30 00:00:00 时出错: None
# 2025-06-30 13:21:42,859 - __main__ - ERROR - 处理日期 2020-09-05 00:00:00 时出错: None
# 2025-06-30 13:21:42,860 - __main__ - ERROR - 处理日期 2020-09-06 00:00:00 时出错: None
# 2025-06-30 13:21:42,861 - __main__ - ERROR - 处理日期 2020-09-12 00:00:00 时出错: None
# 2025-06-30 13:21:42,862 - __main__ - ERROR - 处理日期 2020-09-13 00:00:00 时出错: None
# 2025-06-30 13:21:42,863 - __main__ - ERROR - 处理日期 2020-09-19 00:00:00 时出错: None
# 2025-06-30 13:21:42,864 - __main__ - ERROR - 处理日期 2020-09-20 00:00:00 时出错: None
# 2025-06-30 13:21:42,865 - __main__ - ERROR - 处理日期 2020-09-26 00:00:00 时出错: None
# 2025-06-30 13:21:42,866 - __main__ - ERROR - 处理日期 2020-09-27 00:00:00 时出错: None
# 2025-06-30 13:21:42,867 - __main__ - ERROR - 处理日期 2020-10-01 00:00:00 时出错: None
# 2025-06-30 13:21:42,868 - __main__ - ERROR - 处理日期 2020-10-02 00:00:00 时出错: None
# 2025-06-30 13:21:42,869 - __main__ - ERROR - 处理日期 2020-10-03 00:00:00 时出错: None
# 2025-06-30 13:21:42,870 - __main__ - ERROR - 处理日期 2020-10-04 00:00:00 时出错: None
# 2025-06-30 13:21:42,871 - __main__ - ERROR - 处理日期 2020-10-05 00:00:00 时出错: None
# 2025-06-30 13:21:42,872 - __main__ - ERROR - 处理日期 2020-10-06 00:00:00 时出错: None
# 2025-06-30 13:21:42,873 - __main__ - ERROR - 处理日期 2020-10-07 00:00:00 时出错: None
# 2025-06-30 13:21:42,874 - __main__ - ERROR - 处理日期 2020-10-08 00:00:00 时出错: None
# 2025-06-30 13:21:42,875 - __main__ - ERROR - 处理日期 2020-10-10 00:00:00 时出错: None
# 2025-06-30 13:21:42,876 - __main__ - ERROR - 处理日期 2020-10-11 00:00:00 时出错: None
# 2025-06-30 13:21:42,877 - __main__ - ERROR - 处理日期 2020-10-17 00:00:00 时出错: None
# 2025-06-30 13:21:42,878 - __main__ - ERROR - 处理日期 2020-10-18 00:00:00 时出错: None
# 2025-06-30 13:21:42,879 - __main__ - ERROR - 处理日期 2020-10-24 00:00:00 时出错: None
# 2025-06-30 13:21:42,879 - __main__ - ERROR - 处理日期 2020-10-25 00:00:00 时出错: None
# 2025-06-30 13:21:42,922 - __main__ - ERROR - 处理日期 2020-10-31 00:00:00 时出错: None
# 2025-06-30 13:21:42,923 - __main__ - ERROR - 处理日期 2020-11-01 00:00:00 时出错: None
# 2025-06-30 13:21:42,923 - __main__ - ERROR - 处理日期 2020-11-07 00:00:00 时出错: None
# 2025-06-30 13:21:42,925 - __main__ - ERROR - 处理日期 2020-11-08 00:00:00 时出错: None
# 2025-06-30 13:21:42,926 - __main__ - ERROR - 处理日期 2020-11-14 00:00:00 时出错: None
# 2025-06-30 13:21:42,926 - __main__ - ERROR - 处理日期 2020-11-15 00:00:00 时出错: None
# 2025-06-30 13:21:42,928 - __main__ - ERROR - 处理日期 2020-11-21 00:00:00 时出错: None
# 2025-06-30 13:21:42,929 - __main__ - ERROR - 处理日期 2020-11-22 00:00:00 时出错: None
# 2025-06-30 13:21:42,930 - __main__ - ERROR - 处理日期 2020-11-28 00:00:00 时出错: None
# 2025-06-30 13:21:42,931 - __main__ - ERROR - 处理日期 2020-11-29 00:00:00 时出错: None
# 2025-06-30 13:21:42,932 - __main__ - ERROR - 处理日期 2020-12-05 00:00:00 时出错: None
# 2025-06-30 13:21:42,933 - __main__ - ERROR - 处理日期 2020-12-06 00:00:00 时出错: None
# 2025-06-30 13:21:42,934 - __main__ - ERROR - 处理日期 2020-12-12 00:00:00 时出错: None
# 2025-06-30 13:21:42,935 - __main__ - ERROR - 处理日期 2020-12-13 00:00:00 时出错: None
# 2025-06-30 13:21:42,936 - __main__ - ERROR - 处理日期 2020-12-19 00:00:00 时出错: None
# 2025-06-30 13:21:42,937 - __main__ - ERROR - 处理日期 2020-12-20 00:00:00 时出错: None
# 2025-06-30 13:21:42,938 - __main__ - ERROR - 处理日期 2020-12-26 00:00:00 时出错: None
# 2025-06-30 13:21:42,939 - __main__ - ERROR - 处理日期 2020-12-27 00:00:00 时出错: None
# 2025-06-30 13:21:42,940 - __main__ - ERROR - 处理日期 2021-01-01 00:00:00 时出错: None
# 2025-06-30 13:21:42,941 - __main__ - ERROR - 处理日期 2021-01-02 00:00:00 时出错: None
# 2025-06-30 13:21:42,941 - __main__ - ERROR - 处理日期 2021-01-03 00:00:00 时出错: None
# 2025-06-30 13:21:42,942 - __main__ - ERROR - 处理日期 2021-01-09 00:00:00 时出错: None
# 2025-06-30 13:21:42,943 - __main__ - ERROR - 处理日期 2021-01-10 00:00:00 时出错: None
# 2025-06-30 13:21:42,944 - __main__ - ERROR - 处理日期 2021-01-16 00:00:00 时出错: None
# 2025-06-30 13:21:42,945 - __main__ - ERROR - 处理日期 2021-01-17 00:00:00 时出错: None
# 2025-06-30 13:21:42,946 - __main__ - ERROR - 处理日期 2021-01-23 00:00:00 时出错: None
# 2025-06-30 13:21:42,947 - __main__ - ERROR - 处理日期 2021-01-24 00:00:00 时出错: None
# 2025-06-30 13:21:42,948 - __main__ - ERROR - 处理日期 2021-01-30 00:00:00 时出错: None
# 2025-06-30 13:21:42,949 - __main__ - ERROR - 处理日期 2021-01-31 00:00:00 时出错: None
# 2025-06-30 13:21:42,950 - __main__ - ERROR - 处理日期 2021-02-06 00:00:00 时出错: None
# 2025-06-30 13:21:42,951 - __main__ - ERROR - 处理日期 2021-02-07 00:00:00 时出错: None
# 2025-06-30 13:21:42,952 - __main__ - ERROR - 处理日期 2021-02-11 00:00:00 时出错: None
# 2025-06-30 13:21:42,953 - __main__ - ERROR - 处理日期 2021-02-12 00:00:00 时出错: None
# 2025-06-30 13:21:42,953 - __main__ - ERROR - 处理日期 2021-02-13 00:00:00 时出错: None
# 2025-06-30 13:21:42,954 - __main__ - ERROR - 处理日期 2021-02-14 00:00:00 时出错: None
# 2025-06-30 13:21:42,955 - __main__ - ERROR - 处理日期 2021-02-15 00:00:00 时出错: None
# 2025-06-30 13:21:42,956 - __main__ - ERROR - 处理日期 2021-02-16 00:00:00 时出错: None
# 2025-06-30 13:21:42,957 - __main__ - ERROR - 处理日期 2021-02-17 00:00:00 时出错: None
# 2025-06-30 13:21:42,958 - __main__ - ERROR - 处理日期 2021-02-20 00:00:00 时出错: None
# 2025-06-30 13:21:42,960 - __main__ - ERROR - 处理日期 2021-02-21 00:00:00 时出错: None
# 2025-06-30 13:21:42,961 - __main__ - ERROR - 处理日期 2021-02-27 00:00:00 时出错: None
# 2025-06-30 13:21:42,962 - __main__ - ERROR - 处理日期 2021-02-28 00:00:00 时出错: None
# 2025-06-30 13:21:42,963 - __main__ - ERROR - 处理日期 2021-03-06 00:00:00 时出错: None
# 2025-06-30 13:21:42,964 - __main__ - ERROR - 处理日期 2021-03-07 00:00:00 时出错: None
# 2025-06-30 13:21:42,965 - __main__ - ERROR - 处理日期 2021-03-13 00:00:00 时出错: None
# 2025-06-30 13:21:42,966 - __main__ - ERROR - 处理日期 2021-03-14 00:00:00 时出错: None
# 2025-06-30 13:21:42,967 - __main__ - ERROR - 处理日期 2021-03-20 00:00:00 时出错: None
# 2025-06-30 13:21:42,968 - __main__ - ERROR - 处理日期 2021-03-21 00:00:00 时出错: None
# 2025-06-30 13:21:42,969 - __main__ - ERROR - 处理日期 2021-03-27 00:00:00 时出错: None
# 2025-06-30 13:21:42,970 - __main__ - ERROR - 处理日期 2021-03-28 00:00:00 时出错: None
# 2025-06-30 13:21:42,971 - __main__ - ERROR - 处理日期 2021-04-03 00:00:00 时出错: None
# 2025-06-30 13:21:42,971 - __main__ - ERROR - 处理日期 2021-04-04 00:00:00 时出错: None
# 2025-06-30 13:21:42,973 - __main__ - ERROR - 处理日期 2021-04-05 00:00:00 时出错: None
# 2025-06-30 13:21:42,973 - __main__ - ERROR - 处理日期 2021-04-10 00:00:00 时出错: None
# 2025-06-30 13:21:42,974 - __main__ - ERROR - 处理日期 2021-04-11 00:00:00 时出错: None
# 2025-06-30 13:21:42,975 - __main__ - ERROR - 处理日期 2021-04-17 00:00:00 时出错: None
# 2025-06-30 13:21:42,976 - __main__ - ERROR - 处理日期 2021-04-18 00:00:00 时出错: None
# 2025-06-30 13:21:42,977 - __main__ - ERROR - 处理日期 2021-04-24 00:00:00 时出错: None
# 2025-06-30 13:21:42,978 - __main__ - ERROR - 处理日期 2021-04-25 00:00:00 时出错: None
# 2025-06-30 13:21:42,979 - __main__ - ERROR - 处理日期 2021-05-01 00:00:00 时出错: None
# 2025-06-30 13:21:42,980 - __main__ - ERROR - 处理日期 2021-05-02 00:00:00 时出错: None
# 2025-06-30 13:21:42,981 - __main__ - ERROR - 处理日期 2021-05-03 00:00:00 时出错: None
# 2025-06-30 13:21:42,982 - __main__ - ERROR - 处理日期 2021-05-04 00:00:00 时出错: None
# 2025-06-30 13:21:42,983 - __main__ - ERROR - 处理日期 2021-05-05 00:00:00 时出错: None
# 2025-06-30 13:21:42,984 - __main__ - ERROR - 处理日期 2021-05-08 00:00:00 时出错: None
# 2025-06-30 13:21:42,985 - __main__ - ERROR - 处理日期 2021-05-09 00:00:00 时出错: None
# 2025-06-30 13:21:42,986 - __main__ - ERROR - 处理日期 2021-05-15 00:00:00 时出错: None
# 2025-06-30 13:21:42,987 - __main__ - ERROR - 处理日期 2021-05-16 00:00:00 时出错: None
# 2025-06-30 13:21:42,988 - __main__ - ERROR - 处理日期 2021-05-22 00:00:00 时出错: None
# 2025-06-30 13:21:42,989 - __main__ - ERROR - 处理日期 2021-05-23 00:00:00 时出错: None
# 2025-06-30 13:21:42,990 - __main__ - ERROR - 处理日期 2021-05-29 00:00:00 时出错: None
# 2025-06-30 13:21:42,991 - __main__ - ERROR - 处理日期 2021-05-30 00:00:00 时出错: None
# 2025-06-30 13:21:42,992 - __main__ - ERROR - 处理日期 2021-06-05 00:00:00 时出错: None
# 2025-06-30 13:21:42,993 - __main__ - ERROR - 处理日期 2021-06-06 00:00:00 时出错: None
# 2025-06-30 13:21:42,994 - __main__ - ERROR - 处理日期 2021-06-12 00:00:00 时出错: None
# 2025-06-30 13:21:42,995 - __main__ - ERROR - 处理日期 2021-06-13 00:00:00 时出错: None
# 2025-06-30 13:21:42,996 - __main__ - ERROR - 处理日期 2021-06-14 00:00:00 时出错: None
# 2025-06-30 13:21:42,997 - __main__ - ERROR - 处理日期 2021-06-19 00:00:00 时出错: None
# 2025-06-30 13:21:42,998 - __main__ - ERROR - 处理日期 2021-06-20 00:00:00 时出错: None
# 2025-06-30 13:21:42,999 - __main__ - ERROR - 处理日期 2021-06-26 00:00:00 时出错: None
# 2025-06-30 13:21:43,000 - __main__ - ERROR - 处理日期 2021-06-27 00:00:00 时出错: None
# 2025-06-30 13:21:43,001 - __main__ - ERROR - 处理日期 2021-07-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,002 - __main__ - ERROR - 处理日期 2021-07-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,002 - __main__ - ERROR - 处理日期 2021-07-10 00:00:00 时出错: None
# 2025-06-30 13:21:43,003 - __main__ - ERROR - 处理日期 2021-07-11 00:00:00 时出错: None
# 2025-06-30 13:21:43,004 - __main__ - ERROR - 处理日期 2021-07-17 00:00:00 时出错: None
# 2025-06-30 13:21:43,005 - __main__ - ERROR - 处理日期 2021-07-18 00:00:00 时出错: None
# 2025-06-30 13:21:43,006 - __main__ - ERROR - 处理日期 2021-07-24 00:00:00 时出错: None
# 2025-06-30 13:21:43,007 - __main__ - ERROR - 处理日期 2021-07-25 00:00:00 时出错: None
# 2025-06-30 13:21:43,008 - __main__ - ERROR - 处理日期 2021-07-31 00:00:00 时出错: None
# 2025-06-30 13:21:43,009 - __main__ - ERROR - 处理日期 2021-08-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,010 - __main__ - ERROR - 处理日期 2021-08-07 00:00:00 时出错: None
# 2025-06-30 13:21:43,011 - __main__ - ERROR - 处理日期 2021-08-08 00:00:00 时出错: None
# 2025-06-30 13:21:43,012 - __main__ - ERROR - 处理日期 2021-08-14 00:00:00 时出错: None
# 2025-06-30 13:21:43,013 - __main__ - ERROR - 处理日期 2021-08-15 00:00:00 时出错: None
# 2025-06-30 13:21:43,014 - __main__ - ERROR - 处理日期 2021-08-21 00:00:00 时出错: None
# 2025-06-30 13:21:43,015 - __main__ - ERROR - 处理日期 2021-08-22 00:00:00 时出错: None
# 2025-06-30 13:21:43,016 - __main__ - ERROR - 处理日期 2021-08-28 00:00:00 时出错: None
# 2025-06-30 13:21:43,017 - __main__ - ERROR - 处理日期 2021-08-29 00:00:00 时出错: None
# 2025-06-30 13:21:43,018 - __main__ - ERROR - 处理日期 2021-09-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,019 - __main__ - ERROR - 处理日期 2021-09-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,020 - __main__ - ERROR - 处理日期 2021-09-11 00:00:00 时出错: None
# 2025-06-30 13:21:43,021 - __main__ - ERROR - 处理日期 2021-09-12 00:00:00 时出错: None
# 2025-06-30 13:21:43,022 - __main__ - ERROR - 处理日期 2021-09-18 00:00:00 时出错: None
# 2025-06-30 13:21:43,023 - __main__ - ERROR - 处理日期 2021-09-19 00:00:00 时出错: None
# 2025-06-30 13:21:43,024 - __main__ - ERROR - 处理日期 2021-09-20 00:00:00 时出错: None
# 2025-06-30 13:21:43,025 - __main__ - ERROR - 处理日期 2021-09-21 00:00:00 时出错: None
# 2025-06-30 13:21:43,026 - __main__ - ERROR - 处理日期 2021-09-25 00:00:00 时出错: None
# 2025-06-30 13:21:43,027 - __main__ - ERROR - 处理日期 2021-09-26 00:00:00 时出错: None
# 2025-06-30 13:21:43,028 - __main__ - ERROR - 处理日期 2021-10-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,029 - __main__ - ERROR - 处理日期 2021-10-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,030 - __main__ - ERROR - 处理日期 2021-10-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,031 - __main__ - ERROR - 处理日期 2021-10-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,032 - __main__ - ERROR - 处理日期 2021-10-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,033 - __main__ - ERROR - 处理日期 2021-10-06 00:00:00 时出错: None
# 2025-06-30 13:21:43,034 - __main__ - ERROR - 处理日期 2021-10-07 00:00:00 时出错: None
# 2025-06-30 13:21:43,035 - __main__ - ERROR - 处理日期 2021-10-09 00:00:00 时出错: None
# 2025-06-30 13:21:43,036 - __main__ - ERROR - 处理日期 2021-10-10 00:00:00 时出错: None
# 2025-06-30 13:21:43,037 - __main__ - ERROR - 处理日期 2021-10-16 00:00:00 时出错: None
# 2025-06-30 13:21:43,038 - __main__ - ERROR - 处理日期 2021-10-17 00:00:00 时出错: None
# 2025-06-30 13:21:43,039 - __main__ - ERROR - 处理日期 2021-10-23 00:00:00 时出错: None
# 2025-06-30 13:21:43,040 - __main__ - ERROR - 处理日期 2021-10-24 00:00:00 时出错: None
# 2025-06-30 13:21:43,041 - __main__ - ERROR - 处理日期 2021-10-30 00:00:00 时出错: None
# 2025-06-30 13:21:43,042 - __main__ - ERROR - 处理日期 2021-10-31 00:00:00 时出错: None
# 2025-06-30 13:21:43,043 - __main__ - ERROR - 处理日期 2021-11-06 00:00:00 时出错: None
# 2025-06-30 13:21:43,044 - __main__ - ERROR - 处理日期 2021-11-07 00:00:00 时出错: None
# 2025-06-30 13:21:43,045 - __main__ - ERROR - 处理日期 2021-11-13 00:00:00 时出错: None
# 2025-06-30 13:21:43,046 - __main__ - ERROR - 处理日期 2021-11-14 00:00:00 时出错: None
# 2025-06-30 13:21:43,047 - __main__ - ERROR - 处理日期 2021-11-20 00:00:00 时出错: None
# 2025-06-30 13:21:43,048 - __main__ - ERROR - 处理日期 2021-11-21 00:00:00 时出错: None
# 2025-06-30 13:21:43,049 - __main__ - ERROR - 处理日期 2021-11-27 00:00:00 时出错: None
# 2025-06-30 13:21:43,050 - __main__ - ERROR - 处理日期 2021-11-28 00:00:00 时出错: None
# 2025-06-30 13:21:43,051 - __main__ - ERROR - 处理日期 2021-12-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,051 - __main__ - ERROR - 处理日期 2021-12-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,052 - __main__ - ERROR - 处理日期 2021-12-11 00:00:00 时出错: None
# 2025-06-30 13:21:43,053 - __main__ - ERROR - 处理日期 2021-12-12 00:00:00 时出错: None
# 2025-06-30 13:21:43,054 - __main__ - ERROR - 处理日期 2021-12-18 00:00:00 时出错: None
# 2025-06-30 13:21:43,055 - __main__ - ERROR - 处理日期 2021-12-19 00:00:00 时出错: None
# 2025-06-30 13:21:43,056 - __main__ - ERROR - 处理日期 2021-12-25 00:00:00 时出错: None
# 2025-06-30 13:21:43,057 - __main__ - ERROR - 处理日期 2021-12-26 00:00:00 时出错: None
# 2025-06-30 13:21:43,058 - __main__ - ERROR - 处理日期 2022-01-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,059 - __main__ - ERROR - 处理日期 2022-01-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,060 - __main__ - ERROR - 处理日期 2022-01-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,061 - __main__ - ERROR - 处理日期 2022-01-08 00:00:00 时出错: None
# 2025-06-30 13:21:43,062 - __main__ - ERROR - 处理日期 2022-01-09 00:00:00 时出错: None
# 2025-06-30 13:21:43,064 - __main__ - ERROR - 处理日期 2022-01-15 00:00:00 时出错: None
# 2025-06-30 13:21:43,064 - __main__ - ERROR - 处理日期 2022-01-16 00:00:00 时出错: None
# 2025-06-30 13:21:43,065 - __main__ - ERROR - 处理日期 2022-01-22 00:00:00 时出错: None
# 2025-06-30 13:21:43,066 - __main__ - ERROR - 处理日期 2022-01-23 00:00:00 时出错: None
# 2025-06-30 13:21:43,067 - __main__ - ERROR - 处理日期 2022-01-29 00:00:00 时出错: None
# 2025-06-30 13:21:43,070 - __main__ - ERROR - 处理日期 2022-01-30 00:00:00 时出错: None
# 2025-06-30 13:21:43,071 - __main__ - ERROR - 处理日期 2022-01-31 00:00:00 时出错: None
# 2025-06-30 13:21:43,072 - __main__ - ERROR - 处理日期 2022-02-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,073 - __main__ - ERROR - 处理日期 2022-02-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,074 - __main__ - ERROR - 处理日期 2022-02-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,075 - __main__ - ERROR - 处理日期 2022-02-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,076 - __main__ - ERROR - 处理日期 2022-02-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,077 - __main__ - ERROR - 处理日期 2022-02-06 00:00:00 时出错: None
# 2025-06-30 13:21:43,078 - __main__ - ERROR - 处理日期 2022-02-12 00:00:00 时出错: None
# 2025-06-30 13:21:43,078 - __main__ - ERROR - 处理日期 2022-02-13 00:00:00 时出错: None
# 2025-06-30 13:21:43,079 - __main__ - ERROR - 处理日期 2022-02-19 00:00:00 时出错: None
# 2025-06-30 13:21:43,080 - __main__ - ERROR - 处理日期 2022-02-20 00:00:00 时出错: None
# 2025-06-30 13:21:43,081 - __main__ - ERROR - 处理日期 2022-02-26 00:00:00 时出错: None
# 2025-06-30 13:21:43,082 - __main__ - ERROR - 处理日期 2022-02-27 00:00:00 时出错: None
# 2025-06-30 13:21:43,083 - __main__ - ERROR - 处理日期 2022-03-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,084 - __main__ - ERROR - 处理日期 2022-03-06 00:00:00 时出错: None
# 2025-06-30 13:21:43,085 - __main__ - ERROR - 处理日期 2022-03-12 00:00:00 时出错: None
# 2025-06-30 13:21:43,086 - __main__ - ERROR - 处理日期 2022-03-13 00:00:00 时出错: None
# 2025-06-30 13:21:43,087 - __main__ - ERROR - 处理日期 2022-03-19 00:00:00 时出错: None
# 2025-06-30 13:21:43,087 - __main__ - ERROR - 处理日期 2022-03-20 00:00:00 时出错: None
# 2025-06-30 13:21:43,088 - __main__ - ERROR - 处理日期 2022-03-26 00:00:00 时出错: None
# 2025-06-30 13:21:43,089 - __main__ - ERROR - 处理日期 2022-03-27 00:00:00 时出错: None
# 2025-06-30 13:21:43,090 - __main__ - ERROR - 处理日期 2022-04-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,091 - __main__ - ERROR - 处理日期 2022-04-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,092 - __main__ - ERROR - 处理日期 2022-04-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,093 - __main__ - ERROR - 处理日期 2022-04-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,094 - __main__ - ERROR - 处理日期 2022-04-09 00:00:00 时出错: None
# 2025-06-30 13:21:43,095 - __main__ - ERROR - 处理日期 2022-04-10 00:00:00 时出错: None
# 2025-06-30 13:21:43,095 - __main__ - ERROR - 处理日期 2022-04-16 00:00:00 时出错: None
# 2025-06-30 13:21:43,096 - __main__ - ERROR - 处理日期 2022-04-17 00:00:00 时出错: None
# 2025-06-30 13:21:43,097 - __main__ - ERROR - 处理日期 2022-04-23 00:00:00 时出错: None
# 2025-06-30 13:21:43,098 - __main__ - ERROR - 处理日期 2022-04-24 00:00:00 时出错: None
# 2025-06-30 13:21:43,099 - __main__ - ERROR - 处理日期 2022-04-30 00:00:00 时出错: None
# 2025-06-30 13:21:43,100 - __main__ - ERROR - 处理日期 2022-05-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,100 - __main__ - ERROR - 处理日期 2022-05-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,101 - __main__ - ERROR - 处理日期 2022-05-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,102 - __main__ - ERROR - 处理日期 2022-05-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,103 - __main__ - ERROR - 处理日期 2022-05-07 00:00:00 时出错: None
# 2025-06-30 13:21:43,104 - __main__ - ERROR - 处理日期 2022-05-08 00:00:00 时出错: None
# 2025-06-30 13:21:43,105 - __main__ - ERROR - 处理日期 2022-05-14 00:00:00 时出错: None
# 2025-06-30 13:21:43,106 - __main__ - ERROR - 处理日期 2022-05-15 00:00:00 时出错: None
# 2025-06-30 13:21:43,106 - __main__ - ERROR - 处理日期 2022-05-21 00:00:00 时出错: None
# 2025-06-30 13:21:43,107 - __main__ - ERROR - 处理日期 2022-05-22 00:00:00 时出错: None
# 2025-06-30 13:21:43,108 - __main__ - ERROR - 处理日期 2022-05-28 00:00:00 时出错: None
# 2025-06-30 13:21:43,109 - __main__ - ERROR - 处理日期 2022-05-29 00:00:00 时出错: None
# 2025-06-30 13:21:43,110 - __main__ - ERROR - 处理日期 2022-06-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,111 - __main__ - ERROR - 处理日期 2022-06-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,112 - __main__ - ERROR - 处理日期 2022-06-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,113 - __main__ - ERROR - 处理日期 2022-06-11 00:00:00 时出错: None
# 2025-06-30 13:21:43,114 - __main__ - ERROR - 处理日期 2022-06-12 00:00:00 时出错: None
# 2025-06-30 13:21:43,114 - __main__ - ERROR - 处理日期 2022-06-18 00:00:00 时出错: None
# 2025-06-30 13:21:43,115 - __main__ - ERROR - 处理日期 2022-06-19 00:00:00 时出错: None
# 2025-06-30 13:21:43,116 - __main__ - ERROR - 处理日期 2022-06-25 00:00:00 时出错: None
# 2025-06-30 13:21:43,117 - __main__ - ERROR - 处理日期 2022-06-26 00:00:00 时出错: None
# 2025-06-30 13:21:43,118 - __main__ - ERROR - 处理日期 2022-07-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,119 - __main__ - ERROR - 处理日期 2022-07-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,120 - __main__ - ERROR - 处理日期 2022-07-09 00:00:00 时出错: None
# 2025-06-30 13:21:43,121 - __main__ - ERROR - 处理日期 2022-07-10 00:00:00 时出错: None
# 2025-06-30 13:21:43,122 - __main__ - ERROR - 处理日期 2022-07-16 00:00:00 时出错: None
# 2025-06-30 13:21:43,123 - __main__ - ERROR - 处理日期 2022-07-17 00:00:00 时出错: None
# 2025-06-30 13:21:43,124 - __main__ - ERROR - 处理日期 2022-07-23 00:00:00 时出错: None
# 2025-06-30 13:21:43,124 - __main__ - ERROR - 处理日期 2022-07-24 00:00:00 时出错: None
# 2025-06-30 13:21:43,125 - __main__ - ERROR - 处理日期 2022-07-30 00:00:00 时出错: None
# 2025-06-30 13:21:43,126 - __main__ - ERROR - 处理日期 2022-07-31 00:00:00 时出错: None
# 2025-06-30 13:21:43,127 - __main__ - ERROR - 处理日期 2022-08-06 00:00:00 时出错: None
# 2025-06-30 13:21:43,128 - __main__ - ERROR - 处理日期 2022-08-07 00:00:00 时出错: None
# 2025-06-30 13:21:43,129 - __main__ - ERROR - 处理日期 2022-08-13 00:00:00 时出错: None
# 2025-06-30 13:21:43,130 - __main__ - ERROR - 处理日期 2022-08-14 00:00:00 时出错: None
# 2025-06-30 13:21:43,131 - __main__ - ERROR - 处理日期 2022-08-20 00:00:00 时出错: None
# 2025-06-30 13:21:43,132 - __main__ - ERROR - 处理日期 2022-08-21 00:00:00 时出错: None
# 2025-06-30 13:21:43,133 - __main__ - ERROR - 处理日期 2022-08-27 00:00:00 时出错: None
# 2025-06-30 13:21:43,134 - __main__ - ERROR - 处理日期 2022-08-28 00:00:00 时出错: None
# 2025-06-30 13:21:43,135 - __main__ - ERROR - 处理日期 2022-09-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,136 - __main__ - ERROR - 处理日期 2022-09-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,137 - __main__ - ERROR - 处理日期 2022-09-10 00:00:00 时出错: None
# 2025-06-30 13:21:43,138 - __main__ - ERROR - 处理日期 2022-09-11 00:00:00 时出错: None
# 2025-06-30 13:21:43,139 - __main__ - ERROR - 处理日期 2022-09-12 00:00:00 时出错: None
# 2025-06-30 13:21:43,140 - __main__ - ERROR - 处理日期 2022-09-17 00:00:00 时出错: None
# 2025-06-30 13:21:43,141 - __main__ - ERROR - 处理日期 2022-09-18 00:00:00 时出错: None
# 2025-06-30 13:21:43,142 - __main__ - ERROR - 处理日期 2022-09-24 00:00:00 时出错: None
# 2025-06-30 13:21:43,143 - __main__ - ERROR - 处理日期 2022-09-25 00:00:00 时出错: None
# 2025-06-30 13:21:43,144 - __main__ - ERROR - 处理日期 2022-10-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,145 - __main__ - ERROR - 处理日期 2022-10-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,146 - __main__ - ERROR - 处理日期 2022-10-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,147 - __main__ - ERROR - 处理日期 2022-10-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,148 - __main__ - ERROR - 处理日期 2022-10-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,149 - __main__ - ERROR - 处理日期 2022-10-06 00:00:00 时出错: None
# 2025-06-30 13:21:43,150 - __main__ - ERROR - 处理日期 2022-10-07 00:00:00 时出错: None
# 2025-06-30 13:21:43,151 - __main__ - ERROR - 处理日期 2022-10-08 00:00:00 时出错: None
# 2025-06-30 13:21:43,152 - __main__ - ERROR - 处理日期 2022-10-09 00:00:00 时出错: None
# 2025-06-30 13:21:43,153 - __main__ - ERROR - 处理日期 2022-10-15 00:00:00 时出错: None
# 2025-06-30 13:21:43,153 - __main__ - ERROR - 处理日期 2022-10-16 00:00:00 时出错: None
# 2025-06-30 13:21:43,154 - __main__ - ERROR - 处理日期 2022-10-22 00:00:00 时出错: None
# 2025-06-30 13:21:43,155 - __main__ - ERROR - 处理日期 2022-10-23 00:00:00 时出错: None
# 2025-06-30 13:21:43,156 - __main__ - ERROR - 处理日期 2022-10-29 00:00:00 时出错: None
# 2025-06-30 13:21:43,157 - __main__ - ERROR - 处理日期 2022-10-30 00:00:00 时出错: None
# 2025-06-30 13:21:43,158 - __main__ - ERROR - 处理日期 2022-11-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,159 - __main__ - ERROR - 处理日期 2022-11-06 00:00:00 时出错: None
# 2025-06-30 13:21:43,160 - __main__ - ERROR - 处理日期 2022-11-12 00:00:00 时出错: None
# 2025-06-30 13:21:43,161 - __main__ - ERROR - 处理日期 2022-11-13 00:00:00 时出错: None
# 2025-06-30 13:21:43,162 - __main__ - ERROR - 处理日期 2022-11-19 00:00:00 时出错: None
# 2025-06-30 13:21:43,163 - __main__ - ERROR - 处理日期 2022-11-20 00:00:00 时出错: None
# 2025-06-30 13:21:43,164 - __main__ - ERROR - 处理日期 2022-11-26 00:00:00 时出错: None
# 2025-06-30 13:21:43,165 - __main__ - ERROR - 处理日期 2022-11-27 00:00:00 时出错: None
# 2025-06-30 13:21:43,166 - __main__ - ERROR - 处理日期 2022-12-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,167 - __main__ - ERROR - 处理日期 2022-12-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,168 - __main__ - ERROR - 处理日期 2022-12-10 00:00:00 时出错: None
# 2025-06-30 13:21:43,169 - __main__ - ERROR - 处理日期 2022-12-11 00:00:00 时出错: None
# 2025-06-30 13:21:43,170 - __main__ - ERROR - 处理日期 2022-12-17 00:00:00 时出错: None
# 2025-06-30 13:21:43,180 - __main__ - ERROR - 处理日期 2022-12-18 00:00:00 时出错: None
# 2025-06-30 13:21:43,180 - __main__ - ERROR - 处理日期 2022-12-24 00:00:00 时出错: None
# 2025-06-30 13:21:43,181 - __main__ - ERROR - 处理日期 2022-12-25 00:00:00 时出错: None
# 2025-06-30 13:21:43,182 - __main__ - ERROR - 处理日期 2022-12-31 00:00:00 时出错: None
# 2025-06-30 13:21:43,183 - __main__ - ERROR - 处理日期 2023-01-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,184 - __main__ - ERROR - 处理日期 2023-01-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,185 - __main__ - ERROR - 处理日期 2023-01-07 00:00:00 时出错: None
# 2025-06-30 13:21:43,186 - __main__ - ERROR - 处理日期 2023-01-08 00:00:00 时出错: None
# 2025-06-30 13:21:43,187 - __main__ - ERROR - 处理日期 2023-01-14 00:00:00 时出错: None
# 2025-06-30 13:21:43,188 - __main__ - ERROR - 处理日期 2023-01-15 00:00:00 时出错: None
# 2025-06-30 13:21:43,189 - __main__ - ERROR - 处理日期 2023-01-21 00:00:00 时出错: None
# 2025-06-30 13:21:43,189 - __main__ - ERROR - 处理日期 2023-01-22 00:00:00 时出错: None
# 2025-06-30 13:21:43,190 - __main__ - ERROR - 处理日期 2023-01-23 00:00:00 时出错: None
# 2025-06-30 13:21:43,191 - __main__ - ERROR - 处理日期 2023-01-24 00:00:00 时出错: None
# 2025-06-30 13:21:43,192 - __main__ - ERROR - 处理日期 2023-01-25 00:00:00 时出错: None
# 2025-06-30 13:21:43,193 - __main__ - ERROR - 处理日期 2023-01-26 00:00:00 时出错: None
# 2025-06-30 13:21:43,194 - __main__ - ERROR - 处理日期 2023-01-27 00:00:00 时出错: None
# 2025-06-30 13:21:43,195 - __main__ - ERROR - 处理日期 2023-01-28 00:00:00 时出错: None
# 2025-06-30 13:21:43,196 - __main__ - ERROR - 处理日期 2023-01-29 00:00:00 时出错: None
# 2025-06-30 13:21:43,197 - __main__ - ERROR - 处理日期 2023-02-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,198 - __main__ - ERROR - 处理日期 2023-02-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,199 - __main__ - ERROR - 处理日期 2023-02-11 00:00:00 时出错: None
# 2025-06-30 13:21:43,200 - __main__ - ERROR - 处理日期 2023-02-12 00:00:00 时出错: None
# 2025-06-30 13:21:43,201 - __main__ - ERROR - 处理日期 2023-02-18 00:00:00 时出错: None
# 2025-06-30 13:21:43,201 - __main__ - ERROR - 处理日期 2023-02-19 00:00:00 时出错: None
# 2025-06-30 13:21:43,216 - __main__ - ERROR - 处理日期 2023-02-25 00:00:00 时出错: None
# 2025-06-30 13:21:43,243 - __main__ - ERROR - 处理日期 2023-02-26 00:00:00 时出错: None
# 2025-06-30 13:21:43,244 - __main__ - ERROR - 处理日期 2023-03-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,245 - __main__ - ERROR - 处理日期 2023-03-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,246 - __main__ - ERROR - 处理日期 2023-03-11 00:00:00 时出错: None
# 2025-06-30 13:21:43,247 - __main__ - ERROR - 处理日期 2023-03-12 00:00:00 时出错: None
# 2025-06-30 13:21:43,248 - __main__ - ERROR - 处理日期 2023-03-18 00:00:00 时出错: None
# 2025-06-30 13:21:43,248 - __main__ - ERROR - 处理日期 2023-03-19 00:00:00 时出错: None
# 2025-06-30 13:21:43,249 - __main__ - ERROR - 处理日期 2023-03-25 00:00:00 时出错: None
# 2025-06-30 13:21:43,250 - __main__ - ERROR - 处理日期 2023-03-26 00:00:00 时出错: None
# 2025-06-30 13:21:43,251 - __main__ - ERROR - 处理日期 2023-04-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,252 - __main__ - ERROR - 处理日期 2023-04-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,253 - __main__ - ERROR - 处理日期 2023-04-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,253 - __main__ - ERROR - 处理日期 2023-04-08 00:00:00 时出错: None
# 2025-06-30 13:21:43,254 - __main__ - ERROR - 处理日期 2023-04-09 00:00:00 时出错: None
# 2025-06-30 13:21:43,255 - __main__ - ERROR - 处理日期 2023-04-15 00:00:00 时出错: None
# 2025-06-30 13:21:43,256 - __main__ - ERROR - 处理日期 2023-04-16 00:00:00 时出错: None
# 2025-06-30 13:21:43,260 - __main__ - ERROR - 处理日期 2023-04-22 00:00:00 时出错: None
# 2025-06-30 13:21:43,261 - __main__ - ERROR - 处理日期 2023-04-23 00:00:00 时出错: None
# 2025-06-30 13:21:43,262 - __main__ - ERROR - 处理日期 2023-04-29 00:00:00 时出错: None
# 2025-06-30 13:21:43,263 - __main__ - ERROR - 处理日期 2023-04-30 00:00:00 时出错: None
# 2025-06-30 13:21:43,264 - __main__ - ERROR - 处理日期 2023-05-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,265 - __main__ - ERROR - 处理日期 2023-05-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,265 - __main__ - ERROR - 处理日期 2023-05-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,266 - __main__ - ERROR - 处理日期 2023-05-06 00:00:00 时出错: None
# 2025-06-30 13:21:43,267 - __main__ - ERROR - 处理日期 2023-05-07 00:00:00 时出错: None
# 2025-06-30 13:21:43,268 - __main__ - ERROR - 处理日期 2023-05-13 00:00:00 时出错: None
# 2025-06-30 13:21:43,269 - __main__ - ERROR - 处理日期 2023-05-14 00:00:00 时出错: None
# 2025-06-30 13:21:43,270 - __main__ - ERROR - 处理日期 2023-05-20 00:00:00 时出错: None
# 2025-06-30 13:21:43,271 - __main__ - ERROR - 处理日期 2023-05-21 00:00:00 时出错: None
# 2025-06-30 13:21:43,272 - __main__ - ERROR - 处理日期 2023-05-27 00:00:00 时出错: None
# 2025-06-30 13:21:43,272 - __main__ - ERROR - 处理日期 2023-05-28 00:00:00 时出错: None
# 2025-06-30 13:21:43,273 - __main__ - ERROR - 处理日期 2023-06-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,274 - __main__ - ERROR - 处理日期 2023-06-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,275 - __main__ - ERROR - 处理日期 2023-06-10 00:00:00 时出错: None
# 2025-06-30 13:21:43,276 - __main__ - ERROR - 处理日期 2023-06-11 00:00:00 时出错: None
# 2025-06-30 13:21:43,277 - __main__ - ERROR - 处理日期 2023-06-17 00:00:00 时出错: None
# 2025-06-30 13:21:43,278 - __main__ - ERROR - 处理日期 2023-06-18 00:00:00 时出错: None
# 2025-06-30 13:21:43,279 - __main__ - ERROR - 处理日期 2023-06-22 00:00:00 时出错: None
# 2025-06-30 13:21:43,280 - __main__ - ERROR - 处理日期 2023-06-23 00:00:00 时出错: None
# 2025-06-30 13:21:43,281 - __main__ - ERROR - 处理日期 2023-06-24 00:00:00 时出错: None
# 2025-06-30 13:21:43,282 - __main__ - ERROR - 处理日期 2023-06-25 00:00:00 时出错: None
# 2025-06-30 13:21:43,283 - __main__ - ERROR - 处理日期 2023-07-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,284 - __main__ - ERROR - 处理日期 2023-07-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,284 - __main__ - ERROR - 处理日期 2023-07-08 00:00:00 时出错: None
# 2025-06-30 13:21:43,285 - __main__ - ERROR - 处理日期 2023-07-09 00:00:00 时出错: None
# 2025-06-30 13:21:43,286 - __main__ - ERROR - 处理日期 2023-07-15 00:00:00 时出错: None
# 2025-06-30 13:21:43,287 - __main__ - ERROR - 处理日期 2023-07-16 00:00:00 时出错: None
# 2025-06-30 13:21:43,288 - __main__ - ERROR - 处理日期 2023-07-22 00:00:00 时出错: None
# 2025-06-30 13:21:43,289 - __main__ - ERROR - 处理日期 2023-07-23 00:00:00 时出错: None
# 2025-06-30 13:21:43,290 - __main__ - ERROR - 处理日期 2023-07-29 00:00:00 时出错: None
# 2025-06-30 13:21:43,291 - __main__ - ERROR - 处理日期 2023-07-30 00:00:00 时出错: None
# 2025-06-30 13:21:43,291 - __main__ - ERROR - 处理日期 2023-08-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,292 - __main__ - ERROR - 处理日期 2023-08-06 00:00:00 时出错: None
# 2025-06-30 13:21:43,293 - __main__ - ERROR - 处理日期 2023-08-12 00:00:00 时出错: None
# 2025-06-30 13:21:43,294 - __main__ - ERROR - 处理日期 2023-08-13 00:00:00 时出错: None
# 2025-06-30 13:21:43,295 - __main__ - ERROR - 处理日期 2023-08-19 00:00:00 时出错: None
# 2025-06-30 13:21:43,296 - __main__ - ERROR - 处理日期 2023-08-20 00:00:00 时出错: None
# 2025-06-30 13:21:43,297 - __main__ - ERROR - 处理日期 2023-08-26 00:00:00 时出错: None
# 2025-06-30 13:21:43,298 - __main__ - ERROR - 处理日期 2023-08-27 00:00:00 时出错: None
# 2025-06-30 13:21:43,299 - __main__ - ERROR - 处理日期 2023-09-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,299 - __main__ - ERROR - 处理日期 2023-09-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,300 - __main__ - ERROR - 处理日期 2023-09-09 00:00:00 时出错: None
# 2025-06-30 13:21:43,301 - __main__ - ERROR - 处理日期 2023-09-10 00:00:00 时出错: None
# 2025-06-30 13:21:43,302 - __main__ - ERROR - 处理日期 2023-09-16 00:00:00 时出错: None
# 2025-06-30 13:21:43,303 - __main__ - ERROR - 处理日期 2023-09-17 00:00:00 时出错: None
# 2025-06-30 13:21:43,313 - __main__ - ERROR - 处理日期 2023-09-23 00:00:00 时出错: None
# 2025-06-30 13:21:43,314 - __main__ - ERROR - 处理日期 2023-09-24 00:00:00 时出错: None
# 2025-06-30 13:21:43,315 - __main__ - ERROR - 处理日期 2023-09-29 00:00:00 时出错: None
# 2025-06-30 13:21:43,316 - __main__ - ERROR - 处理日期 2023-09-30 00:00:00 时出错: None
# 2025-06-30 13:21:43,317 - __main__ - ERROR - 处理日期 2023-10-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,318 - __main__ - ERROR - 处理日期 2023-10-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,319 - __main__ - ERROR - 处理日期 2023-10-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,319 - __main__ - ERROR - 处理日期 2023-10-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,320 - __main__ - ERROR - 处理日期 2023-10-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,321 - __main__ - ERROR - 处理日期 2023-10-06 00:00:00 时出错: None
# 2025-06-30 13:21:43,322 - __main__ - ERROR - 处理日期 2023-10-07 00:00:00 时出错: None
# 2025-06-30 13:21:43,323 - __main__ - ERROR - 处理日期 2023-10-08 00:00:00 时出错: None
# 2025-06-30 13:21:43,324 - __main__ - ERROR - 处理日期 2023-10-14 00:00:00 时出错: None
# 2025-06-30 13:21:43,325 - __main__ - ERROR - 处理日期 2023-10-15 00:00:00 时出错: None
# 2025-06-30 13:21:43,326 - __main__ - ERROR - 处理日期 2023-10-21 00:00:00 时出错: None
# 2025-06-30 13:21:43,327 - __main__ - ERROR - 处理日期 2023-10-22 00:00:00 时出错: None
# 2025-06-30 13:21:43,328 - __main__ - ERROR - 处理日期 2023-10-28 00:00:00 时出错: None
# 2025-06-30 13:21:43,328 - __main__ - ERROR - 处理日期 2023-10-29 00:00:00 时出错: None
# 2025-06-30 13:21:43,329 - __main__ - ERROR - 处理日期 2023-11-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,330 - __main__ - ERROR - 处理日期 2023-11-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,331 - __main__ - ERROR - 处理日期 2023-11-11 00:00:00 时出错: None
# 2025-06-30 13:21:43,332 - __main__ - ERROR - 处理日期 2023-11-12 00:00:00 时出错: None
# 2025-06-30 13:21:43,332 - __main__ - ERROR - 处理日期 2023-11-18 00:00:00 时出错: None
# 2025-06-30 13:21:43,333 - __main__ - ERROR - 处理日期 2023-11-19 00:00:00 时出错: None
# 2025-06-30 13:21:43,334 - __main__ - ERROR - 处理日期 2023-11-25 00:00:00 时出错: None
# 2025-06-30 13:21:43,335 - __main__ - ERROR - 处理日期 2023-11-26 00:00:00 时出错: None
# 2025-06-30 13:21:43,336 - __main__ - ERROR - 处理日期 2023-12-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,337 - __main__ - ERROR - 处理日期 2023-12-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,338 - __main__ - ERROR - 处理日期 2023-12-09 00:00:00 时出错: None
# 2025-06-30 13:21:43,339 - __main__ - ERROR - 处理日期 2023-12-10 00:00:00 时出错: None
# 2025-06-30 13:21:43,340 - __main__ - ERROR - 处理日期 2023-12-16 00:00:00 时出错: None
# 2025-06-30 13:21:43,346 - __main__ - ERROR - 处理日期 2023-12-17 00:00:00 时出错: None
# 2025-06-30 13:21:43,347 - __main__ - ERROR - 处理日期 2023-12-23 00:00:00 时出错: None
# 2025-06-30 13:21:43,348 - __main__ - ERROR - 处理日期 2023-12-24 00:00:00 时出错: None
# 2025-06-30 13:21:43,349 - __main__ - ERROR - 处理日期 2023-12-30 00:00:00 时出错: None
# 2025-06-30 13:21:43,350 - __main__ - ERROR - 处理日期 2023-12-31 00:00:00 时出错: None
# 2025-06-30 13:21:43,350 - __main__ - ERROR - 处理日期 2024-01-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,351 - __main__ - ERROR - 处理日期 2024-01-06 00:00:00 时出错: None
# 2025-06-30 13:21:43,352 - __main__ - ERROR - 处理日期 2024-01-07 00:00:00 时出错: None
# 2025-06-30 13:21:43,353 - __main__ - ERROR - 处理日期 2024-01-13 00:00:00 时出错: None
# 2025-06-30 13:21:43,354 - __main__ - ERROR - 处理日期 2024-01-14 00:00:00 时出错: None
# 2025-06-30 13:21:43,355 - __main__ - ERROR - 处理日期 2024-01-20 00:00:00 时出错: None
# 2025-06-30 13:21:43,356 - __main__ - ERROR - 处理日期 2024-01-21 00:00:00 时出错: None
# 2025-06-30 13:21:43,357 - __main__ - ERROR - 处理日期 2024-01-27 00:00:00 时出错: None
# 2025-06-30 13:21:43,361 - __main__ - ERROR - 处理日期 2024-01-28 00:00:00 时出错: None
# 2025-06-30 13:21:43,362 - __main__ - ERROR - 处理日期 2024-02-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,363 - __main__ - ERROR - 处理日期 2024-02-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,364 - __main__ - ERROR - 处理日期 2024-02-09 00:00:00 时出错: None
# 2025-06-30 13:21:43,365 - __main__ - ERROR - 处理日期 2024-02-10 00:00:00 时出错: None
# 2025-06-30 13:21:43,366 - __main__ - ERROR - 处理日期 2024-02-11 00:00:00 时出错: None
# 2025-06-30 13:21:43,367 - __main__ - ERROR - 处理日期 2024-02-12 00:00:00 时出错: None
# 2025-06-30 13:21:43,368 - __main__ - ERROR - 处理日期 2024-02-13 00:00:00 时出错: None
# 2025-06-30 13:21:43,369 - __main__ - ERROR - 处理日期 2024-02-14 00:00:00 时出错: None
# 2025-06-30 13:21:43,369 - __main__ - ERROR - 处理日期 2024-02-15 00:00:00 时出错: None
# 2025-06-30 13:21:43,370 - __main__ - ERROR - 处理日期 2024-02-16 00:00:00 时出错: None
# 2025-06-30 13:21:43,371 - __main__ - ERROR - 处理日期 2024-02-17 00:00:00 时出错: None
# 2025-06-30 13:21:43,372 - __main__ - ERROR - 处理日期 2024-02-18 00:00:00 时出错: None
# 2025-06-30 13:21:43,373 - __main__ - ERROR - 处理日期 2024-02-24 00:00:00 时出错: None
# 2025-06-30 13:21:43,374 - __main__ - ERROR - 处理日期 2024-02-25 00:00:00 时出错: None
# 2025-06-30 13:21:43,375 - __main__ - ERROR - 处理日期 2024-03-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,376 - __main__ - ERROR - 处理日期 2024-03-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,377 - __main__ - ERROR - 处理日期 2024-03-09 00:00:00 时出错: None
# 2025-06-30 13:21:43,378 - __main__ - ERROR - 处理日期 2024-03-10 00:00:00 时出错: None
# 2025-06-30 13:21:43,379 - __main__ - ERROR - 处理日期 2024-03-16 00:00:00 时出错: None
# 2025-06-30 13:21:43,379 - __main__ - ERROR - 处理日期 2024-03-17 00:00:00 时出错: None
# 2025-06-30 13:21:43,380 - __main__ - ERROR - 处理日期 2024-03-23 00:00:00 时出错: None
# 2025-06-30 13:21:43,381 - __main__ - ERROR - 处理日期 2024-03-24 00:00:00 时出错: None
# 2025-06-30 13:21:43,382 - __main__ - ERROR - 处理日期 2024-03-30 00:00:00 时出错: None
# 2025-06-30 13:21:43,383 - __main__ - ERROR - 处理日期 2024-03-31 00:00:00 时出错: None
# 2025-06-30 13:21:43,384 - __main__ - ERROR - 处理日期 2024-04-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,385 - __main__ - ERROR - 处理日期 2024-04-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,386 - __main__ - ERROR - 处理日期 2024-04-06 00:00:00 时出错: None
# 2025-06-30 13:21:43,386 - __main__ - ERROR - 处理日期 2024-04-07 00:00:00 时出错: None
# 2025-06-30 13:21:43,387 - __main__ - ERROR - 处理日期 2024-04-13 00:00:00 时出错: None
# 2025-06-30 13:21:43,388 - __main__ - ERROR - 处理日期 2024-04-14 00:00:00 时出错: None
# 2025-06-30 13:21:43,389 - __main__ - ERROR - 处理日期 2024-04-20 00:00:00 时出错: None
# 2025-06-30 13:21:43,390 - __main__ - ERROR - 处理日期 2024-04-21 00:00:00 时出错: None
# 2025-06-30 13:21:43,391 - __main__ - ERROR - 处理日期 2024-04-27 00:00:00 时出错: None
# 2025-06-30 13:21:43,392 - __main__ - ERROR - 处理日期 2024-04-28 00:00:00 时出错: None
# 2025-06-30 13:21:43,393 - __main__ - ERROR - 处理日期 2024-05-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,394 - __main__ - ERROR - 处理日期 2024-05-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,402 - __main__ - ERROR - 处理日期 2024-05-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,403 - __main__ - ERROR - 处理日期 2024-05-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,404 - __main__ - ERROR - 处理日期 2024-05-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,404 - __main__ - ERROR - 处理日期 2024-05-11 00:00:00 时出错: None
# 2025-06-30 13:21:43,405 - __main__ - ERROR - 处理日期 2024-05-12 00:00:00 时出错: None
# 2025-06-30 13:21:43,406 - __main__ - ERROR - 处理日期 2024-05-18 00:00:00 时出错: None
# 2025-06-30 13:21:43,407 - __main__ - ERROR - 处理日期 2024-05-19 00:00:00 时出错: None
# 2025-06-30 13:21:43,408 - __main__ - ERROR - 处理日期 2024-05-25 00:00:00 时出错: None
# 2025-06-30 13:21:43,409 - __main__ - ERROR - 处理日期 2024-05-26 00:00:00 时出错: None
# 2025-06-30 13:21:43,410 - __main__ - ERROR - 处理日期 2024-06-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,411 - __main__ - ERROR - 处理日期 2024-06-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,412 - __main__ - ERROR - 处理日期 2024-06-08 00:00:00 时出错: None
# 2025-06-30 13:21:43,413 - __main__ - ERROR - 处理日期 2024-06-09 00:00:00 时出错: None
# 2025-06-30 13:21:43,413 - __main__ - ERROR - 处理日期 2024-06-10 00:00:00 时出错: None
# 2025-06-30 13:21:43,414 - __main__ - ERROR - 处理日期 2024-06-15 00:00:00 时出错: None
# 2025-06-30 13:21:43,415 - __main__ - ERROR - 处理日期 2024-06-16 00:00:00 时出错: None
# 2025-06-30 13:21:43,416 - __main__ - ERROR - 处理日期 2024-06-22 00:00:00 时出错: None
# 2025-06-30 13:21:43,417 - __main__ - ERROR - 处理日期 2024-06-23 00:00:00 时出错: None
# 2025-06-30 13:21:43,418 - __main__ - ERROR - 处理日期 2024-06-29 00:00:00 时出错: None
# 2025-06-30 13:21:43,419 - __main__ - ERROR - 处理日期 2024-06-30 00:00:00 时出错: None
# 2025-06-30 13:21:43,420 - __main__ - ERROR - 处理日期 2024-07-06 00:00:00 时出错: None
# 2025-06-30 13:21:43,421 - __main__ - ERROR - 处理日期 2024-07-07 00:00:00 时出错: None
# 2025-06-30 13:21:43,422 - __main__ - ERROR - 处理日期 2024-07-13 00:00:00 时出错: None
# 2025-06-30 13:21:43,423 - __main__ - ERROR - 处理日期 2024-07-14 00:00:00 时出错: None
# 2025-06-30 13:21:43,423 - __main__ - ERROR - 处理日期 2024-07-20 00:00:00 时出错: None
# 2025-06-30 13:21:43,424 - __main__ - ERROR - 处理日期 2024-07-21 00:00:00 时出错: None
# 2025-06-30 13:21:43,425 - __main__ - ERROR - 处理日期 2024-07-27 00:00:00 时出错: None
# 2025-06-30 13:21:43,426 - __main__ - ERROR - 处理日期 2024-07-28 00:00:00 时出错: None
# 2025-06-30 13:21:43,427 - __main__ - ERROR - 处理日期 2024-08-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,428 - __main__ - ERROR - 处理日期 2024-08-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,429 - __main__ - ERROR - 处理日期 2024-08-10 00:00:00 时出错: None
# 2025-06-30 13:21:43,430 - __main__ - ERROR - 处理日期 2024-08-11 00:00:00 时出错: None
# 2025-06-30 13:21:43,431 - __main__ - ERROR - 处理日期 2024-08-17 00:00:00 时出错: None
# 2025-06-30 13:21:43,432 - __main__ - ERROR - 处理日期 2024-08-18 00:00:00 时出错: None
# 2025-06-30 13:21:43,432 - __main__ - ERROR - 处理日期 2024-08-24 00:00:00 时出错: None
# 2025-06-30 13:21:43,433 - __main__ - ERROR - 处理日期 2024-08-25 00:00:00 时出错: None
# 2025-06-30 13:21:43,434 - __main__ - ERROR - 处理日期 2024-08-31 00:00:00 时出错: None
# 2025-06-30 13:21:43,435 - __main__ - ERROR - 处理日期 2024-09-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,436 - __main__ - ERROR - 处理日期 2024-09-07 00:00:00 时出错: None
# 2025-06-30 13:21:43,437 - __main__ - ERROR - 处理日期 2024-09-08 00:00:00 时出错: None
# 2025-06-30 13:21:43,438 - __main__ - ERROR - 处理日期 2024-09-14 00:00:00 时出错: None
# 2025-06-30 13:21:43,439 - __main__ - ERROR - 处理日期 2024-09-15 00:00:00 时出错: None
# 2025-06-30 13:21:43,440 - __main__ - ERROR - 处理日期 2024-09-16 00:00:00 时出错: None
# 2025-06-30 13:21:43,441 - __main__ - ERROR - 处理日期 2024-09-17 00:00:00 时出错: None
# 2025-06-30 13:21:43,441 - __main__ - ERROR - 处理日期 2024-09-21 00:00:00 时出错: None
# 2025-06-30 13:21:43,442 - __main__ - ERROR - 处理日期 2024-09-22 00:00:00 时出错: None
# 2025-06-30 13:21:43,443 - __main__ - ERROR - 处理日期 2024-09-28 00:00:00 时出错: None
# 2025-06-30 13:21:43,444 - __main__ - ERROR - 处理日期 2024-09-29 00:00:00 时出错: None
# 2025-06-30 13:21:43,445 - __main__ - ERROR - 处理日期 2024-10-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,454 - __main__ - ERROR - 处理日期 2024-10-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,455 - __main__ - ERROR - 处理日期 2024-10-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,456 - __main__ - ERROR - 处理日期 2024-10-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,457 - __main__ - ERROR - 处理日期 2024-10-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,458 - __main__ - ERROR - 处理日期 2024-10-06 00:00:00 时出错: None
# 2025-06-30 13:21:43,459 - __main__ - ERROR - 处理日期 2024-10-07 00:00:00 时出错: None
# 2025-06-30 13:21:43,460 - __main__ - ERROR - 处理日期 2024-10-12 00:00:00 时出错: None
# 2025-06-30 13:21:43,461 - __main__ - ERROR - 处理日期 2024-10-13 00:00:00 时出错: None
# 2025-06-30 13:21:43,462 - __main__ - ERROR - 处理日期 2024-10-19 00:00:00 时出错: None
# 2025-06-30 13:21:43,463 - __main__ - ERROR - 处理日期 2024-10-20 00:00:00 时出错: None
# 2025-06-30 13:21:43,464 - __main__ - ERROR - 处理日期 2024-10-26 00:00:00 时出错: None
# 2025-06-30 13:21:43,465 - __main__ - ERROR - 处理日期 2024-10-27 00:00:00 时出错: None
# 2025-06-30 13:21:43,466 - __main__ - ERROR - 处理日期 2024-11-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,467 - __main__ - ERROR - 处理日期 2024-11-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,468 - __main__ - ERROR - 处理日期 2024-11-09 00:00:00 时出错: None
# 2025-06-30 13:21:43,469 - __main__ - ERROR - 处理日期 2024-11-10 00:00:00 时出错: None
# 2025-06-30 13:21:43,469 - __main__ - ERROR - 处理日期 2024-11-16 00:00:00 时出错: None
# 2025-06-30 13:21:43,470 - __main__ - ERROR - 处理日期 2024-11-17 00:00:00 时出错: None
# 2025-06-30 13:21:43,471 - __main__ - ERROR - 处理日期 2024-11-23 00:00:00 时出错: None
# 2025-06-30 13:21:43,472 - __main__ - ERROR - 处理日期 2024-11-24 00:00:00 时出错: None
# 2025-06-30 13:21:43,473 - __main__ - ERROR - 处理日期 2024-11-30 00:00:00 时出错: None
# 2025-06-30 13:21:43,474 - __main__ - ERROR - 处理日期 2024-12-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,475 - __main__ - ERROR - 处理日期 2024-12-07 00:00:00 时出错: None
# 2025-06-30 13:21:43,476 - __main__ - ERROR - 处理日期 2024-12-08 00:00:00 时出错: None
# 2025-06-30 13:21:43,477 - __main__ - ERROR - 处理日期 2024-12-14 00:00:00 时出错: None
# 2025-06-30 13:21:43,478 - __main__ - ERROR - 处理日期 2024-12-15 00:00:00 时出错: None
# 2025-06-30 13:21:43,479 - __main__ - ERROR - 处理日期 2024-12-21 00:00:00 时出错: None
# 2025-06-30 13:21:43,480 - __main__ - ERROR - 处理日期 2024-12-22 00:00:00 时出错: None
# 2025-06-30 13:21:43,481 - __main__ - ERROR - 处理日期 2024-12-28 00:00:00 时出错: None
# 2025-06-30 13:21:43,482 - __main__ - ERROR - 处理日期 2024-12-29 00:00:00 时出错: None
# 2025-06-30 13:21:43,482 - __main__ - ERROR - 处理日期 2025-01-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,483 - __main__ - ERROR - 处理日期 2025-01-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,484 - __main__ - ERROR - 处理日期 2025-01-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,485 - __main__ - ERROR - 处理日期 2025-01-11 00:00:00 时出错: None
# 2025-06-30 13:21:43,486 - __main__ - ERROR - 处理日期 2025-01-12 00:00:00 时出错: None
# 2025-06-30 13:21:43,487 - __main__ - ERROR - 处理日期 2025-01-18 00:00:00 时出错: None
# 2025-06-30 13:21:43,488 - __main__ - ERROR - 处理日期 2025-01-19 00:00:00 时出错: None
# 2025-06-30 13:21:43,489 - __main__ - ERROR - 处理日期 2025-01-25 00:00:00 时出错: None
# 2025-06-30 13:21:43,490 - __main__ - ERROR - 处理日期 2025-01-26 00:00:00 时出错: None
# 2025-06-30 13:21:43,491 - __main__ - ERROR - 处理日期 2025-01-28 00:00:00 时出错: None
# 2025-06-30 13:21:43,492 - __main__ - ERROR - 处理日期 2025-01-29 00:00:00 时出错: None
# 2025-06-30 13:21:43,493 - __main__ - ERROR - 处理日期 2025-01-30 00:00:00 时出错: None
# 2025-06-30 13:21:43,493 - __main__ - ERROR - 处理日期 2025-01-31 00:00:00 时出错: None
# 2025-06-30 13:21:43,497 - __main__ - ERROR - 处理日期 2025-02-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,504 - __main__ - ERROR - 处理日期 2025-02-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,505 - __main__ - ERROR - 处理日期 2025-02-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,506 - __main__ - ERROR - 处理日期 2025-02-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,507 - __main__ - ERROR - 处理日期 2025-02-08 00:00:00 时出错: None
# 2025-06-30 13:21:43,508 - __main__ - ERROR - 处理日期 2025-02-09 00:00:00 时出错: None
# 2025-06-30 13:21:43,509 - __main__ - ERROR - 处理日期 2025-02-15 00:00:00 时出错: None
# 2025-06-30 13:21:43,510 - __main__ - ERROR - 处理日期 2025-02-16 00:00:00 时出错: None
# 2025-06-30 13:21:43,510 - __main__ - ERROR - 处理日期 2025-02-22 00:00:00 时出错: None
# 2025-06-30 13:21:43,511 - __main__ - ERROR - 处理日期 2025-02-23 00:00:00 时出错: None
# 2025-06-30 13:21:43,512 - __main__ - ERROR - 处理日期 2025-03-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,513 - __main__ - ERROR - 处理日期 2025-03-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,514 - __main__ - ERROR - 处理日期 2025-03-08 00:00:00 时出错: None
# 2025-06-30 13:21:43,515 - __main__ - ERROR - 处理日期 2025-03-09 00:00:00 时出错: None
# 2025-06-30 13:21:43,518 - __main__ - ERROR - 处理日期 2025-03-15 00:00:00 时出错: None
# 2025-06-30 13:21:43,519 - __main__ - ERROR - 处理日期 2025-03-16 00:00:00 时出错: None
# 2025-06-30 13:21:43,520 - __main__ - ERROR - 处理日期 2025-03-22 00:00:00 时出错: None
# 2025-06-30 13:21:43,521 - __main__ - ERROR - 处理日期 2025-03-23 00:00:00 时出错: None
# 2025-06-30 13:21:43,522 - __main__ - ERROR - 处理日期 2025-03-29 00:00:00 时出错: None
# 2025-06-30 13:21:43,523 - __main__ - ERROR - 处理日期 2025-03-30 00:00:00 时出错: None
# 2025-06-30 13:21:43,524 - __main__ - ERROR - 处理日期 2025-04-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,525 - __main__ - ERROR - 处理日期 2025-04-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,526 - __main__ - ERROR - 处理日期 2025-04-06 00:00:00 时出错: None
# 2025-06-30 13:21:43,526 - __main__ - ERROR - 处理日期 2025-04-12 00:00:00 时出错: None
# 2025-06-30 13:21:43,527 - __main__ - ERROR - 处理日期 2025-04-13 00:00:00 时出错: None
# 2025-06-30 13:21:43,530 - __main__ - ERROR - 处理日期 2025-04-19 00:00:00 时出错: None
# 2025-06-30 13:21:43,530 - __main__ - ERROR - 处理日期 2025-04-20 00:00:00 时出错: None
# 2025-06-30 13:21:43,531 - __main__ - ERROR - 处理日期 2025-04-26 00:00:00 时出错: None
# 2025-06-30 13:21:43,532 - __main__ - ERROR - 处理日期 2025-04-27 00:00:00 时出错: None
# 2025-06-30 13:21:43,533 - __main__ - ERROR - 处理日期 2025-05-01 00:00:00 时出错: None
# 2025-06-30 13:21:43,534 - __main__ - ERROR - 处理日期 2025-05-02 00:00:00 时出错: None
# 2025-06-30 13:21:43,535 - __main__ - ERROR - 处理日期 2025-05-03 00:00:00 时出错: None
# 2025-06-30 13:21:43,536 - __main__ - ERROR - 处理日期 2025-05-04 00:00:00 时出错: None
# 2025-06-30 13:21:43,537 - __main__ - ERROR - 处理日期 2025-05-05 00:00:00 时出错: None
# 2025-06-30 13:21:43,541 - __main__ - ERROR - 处理日期 2025-05-10 00:00:00 时出错: None
# 2025-06-30 13:21:43,542 - __main__ - ERROR - 处理日期 2025-05-11 00:00:00 时出错: None
# 2025-06-30 13:21:43,543 - __main__ - ERROR - 处理日期 2025-05-17 00:00:00 时出错: None
# 2025-06-30 13:21:43,544 - __main__ - ERROR - 处理日期 2025-05-18 00:00:00 时出错: None
# 2025-06-30 13:21:43,545 - __main__ - ERROR - 处理日期 2025-05-24 00:00:00 时出错: None
# 2025-06-30 13:21:43,546 - __main__ - ERROR - 处理日期 2025-05-25 00:00:00 时出错: None
# 2025-06-30 13:21:43,547 - __main__ - ERROR - 处理日期 2025-05-31 00:00:00 时出错: None
# 2025-06-30 13:21:43,548 - __main__ - INFO - 处理完成: 成功 0/790
