# %%
import connectorx as cx
import pandas as pd
import numpy as np
import os
import duckdb
from datetime import datetime
import glob
import multiprocessing as mp
from functools import partial
import time

# %%
def calculate_daily_factor(trading_date):
    date_str = pd.to_datetime(trading_date).strftime('%Y%m%d')
    order_pth = f"/data/cephfs/order/{date_str}.parquet"

    
    conn = duckdb.connect(database=':memory:')

    # 定义六个时间段的查询
    time_intervals = {
        'pre_open_915_920': "order_time >= 91500000 AND order_time < 92000000",
        'pre_open_920_925': "order_time >= 92000000 AND order_time < 92500000",
        'early_930_1000': "order_time >= 93000000 AND order_time < 100000000",
        'main_1000_1430': "order_time >= 100000000 AND order_time < 143000000",
        'late_1430_1457': "order_time >= 143000000 AND order_time < 145700000",
        'close_1457_1500': "order_time >= 145700000 AND order_time < 150000000",
        'continue_930_1457':"order_time >= 93000000 AND order_time < 145700000"
    }

    # 创建的表名列表
    created_tables = []
    
    # 分位数类型列表
    percentile_types = ['p01_p99', 'p05_p95']

    try:
        # 为每个时间段和买卖方向创建临时表
        for interval_name, time_condition in time_intervals.items():
            # 买方订单
            bid_query = f"""
            SELECT 
                security_code,
                order_side, 
                order_type,
                order_details,
                order_price,
                order_price_adj,
                order_volume,
                order_time
            FROM '{order_pth}'
            WHERE order_type = 'A'
                AND order_details = 'L'
                AND order_side = 1
                AND {time_condition}
                AND order_price > 0
            """
            
            # 卖方订单
            ask_query = f"""
            SELECT 
                security_code,
                order_side, 
                order_type,
                order_details,
                order_price,
                order_price_adj,
                order_volume,
                order_time
            FROM '{order_pth}'
            WHERE order_type = 'A'
                AND order_details = 'L'
                AND order_side = -1
                AND {time_condition}
                AND order_price > 0
            """
            
            # 检查买方订单是否有数据
            check_bid_query = f"""
            SELECT COUNT(*) AS count FROM ({bid_query}) t
            """
            bid_count = conn.execute(check_bid_query).fetchone()[0]
            
            if bid_count > 0:
                # 创建买方基础表
                conn.execute(f"CREATE TEMPORARY TABLE bid_base_{interval_name} AS {bid_query}")
                
                # 计算买方价格分位数
                bid_percentile_query = f"""
                CREATE TEMPORARY TABLE bid_percentiles_{interval_name} AS
                SELECT 
                    security_code,
                    PERCENTILE_CONT(0.01) WITHIN GROUP (ORDER BY order_price) AS p01,
                    PERCENTILE_CONT(0.99) WITHIN GROUP (ORDER BY order_price) AS p99,

                FROM bid_base_{interval_name}
                GROUP BY security_code
                """
                conn.execute(bid_percentile_query)
                
                # 创建买方P01-P99缩尾表
                bid_winsorized_query_p01_p99 = f"""
                CREATE TEMPORARY TABLE bid_{interval_name}_p01_p99 AS
                SELECT 
                    b.security_code,
                    b.order_side,
                    b.order_type,
                    b.order_details,
                    CASE 
                        WHEN b.order_price < p.p01 THEN p.p01
                        WHEN b.order_price > p.p99 THEN p.p99
                        ELSE b.order_price
                    END AS order_price,
                    b.order_price_adj,
                    b.order_volume,
                    b.order_time
                FROM bid_base_{interval_name} b
                JOIN bid_percentiles_{interval_name} p ON b.security_code = p.security_code
                """
                conn.execute(bid_winsorized_query_p01_p99)
                created_tables.append(f'bid_{interval_name}_p01_p99')
                
            
            # 检查卖方订单是否有数据
            check_ask_query = f"""
            SELECT COUNT(*) AS count FROM ({ask_query}) t
            """
            ask_count = conn.execute(check_ask_query).fetchone()[0]
            
            if ask_count > 0:
                # 创建卖方基础表
                conn.execute(f"CREATE TEMPORARY TABLE ask_base_{interval_name} AS {ask_query}")
                
                # 计算卖方价格分位数
                ask_percentile_query = f"""
                CREATE TEMPORARY TABLE ask_percentiles_{interval_name} AS
                SELECT 
                    security_code,
                    PERCENTILE_CONT(0.01) WITHIN GROUP (ORDER BY order_price) AS p01,
                    PERCENTILE_CONT(0.99) WITHIN GROUP (ORDER BY order_price) AS p99,

                FROM ask_base_{interval_name}
                GROUP BY security_code
                """
                conn.execute(ask_percentile_query)
                
                # 创建卖方P01-P99缩尾表
                ask_winsorized_query_p01_p99 = f"""
                CREATE TEMPORARY TABLE ask_{interval_name}_p01_p99 AS
                SELECT 
                    a.security_code,
                    a.order_side,
                    a.order_type,
                    a.order_details,
                    CASE 
                        WHEN a.order_price < p.p01 THEN p.p01
                        WHEN a.order_price > p.p99 THEN p.p99
                        ELSE a.order_price
                    END AS order_price,
                    a.order_price_adj,
                    a.order_volume,
                    a.order_time
                FROM ask_base_{interval_name} a
                JOIN ask_percentiles_{interval_name} p ON a.security_code = p.security_code
                """
                conn.execute(ask_winsorized_query_p01_p99)
                created_tables.append(f'ask_{interval_name}_p01_p99')
                
                # # 创建卖方P05-P95缩尾表
                # ask_winsorized_query_p05_p95 = f"""
                # CREATE TEMPORARY TABLE ask_{interval_name}_p05_p95 AS
                # SELECT 
                #     a.security_code,
                #     a.order_side,
                #     a.order_type,
                #     a.order_details,
                #     CASE 
                #         WHEN a.order_price < p.p05 THEN p.p05
                #         WHEN a.order_price > p.p95 THEN p.p95
                #         ELSE a.order_price
                #     END AS order_price,
                #     a.order_price_adj,
                #     a.order_volume,
                #     a.order_time
                # FROM ask_base_{interval_name} a
                # JOIN ask_percentiles_{interval_name} p ON a.security_code = p.security_code
                # """
                # conn.execute(ask_winsorized_query_p05_p95)
                # created_tables.append(f'ask_{interval_name}_p05_p95')

        # 计算所有因子
        result_df = None
        
        for factor_name in created_tables:
            # 提取时间段和分位数类型
            parts = factor_name.split('_')
            side = parts[0]  # bid 或 ask
            interval_name = '_'.join(parts[1:-2])  # 时间段名称
            percentile_type = parts[-2] + '_' + parts[-1]  # p03_p97 
            
            # 检查表是否有足够的数据计算因子
            check_query = f"""
            SELECT COUNT(*) AS count FROM {factor_name} 
            WHERE order_price IS NOT NULL
            """
            count = conn.execute(check_query).fetchone()[0]
            
            if count <= 1:  # 需要至少两条记录才能计算分歧度
                continue
                
            try:
                # 计算订单加权平均对数价格
                factor_query = f"""
                WITH {factor_name}_stats AS (
                    SELECT 
                        security_code,
                        SUM(order_volume) AS total_volume,
                        SUM(LN(order_price) * order_volume) / SUM(order_volume) AS weighted_log_price
                    FROM {factor_name}
                    WHERE order_price IS NOT NULL AND order_price > 0  -- 确保只使用有效价格
                    GROUP BY security_code
                    HAVING COUNT(*) > 1  -- 确保每个证券至少有两条记录
                ),

                {factor_name}_price_divergence AS (
                    SELECT 
                        o.security_code,
                        SQRT(
                            SUM(POWER(LN(o.order_price) - s.weighted_log_price, 2) * o.order_volume) / 
                            ANY_VALUE(s.total_volume)
                        ) AS {side}_{interval_name}_{percentile_type}
                    FROM {factor_name} o
                    JOIN {factor_name}_stats s ON o.security_code = s.security_code
                    WHERE o.order_price IS NOT NULL AND o.order_price > 0  -- 确保只使用有效价格
                    GROUP BY o.security_code
                )

                SELECT 
                    security_code,
                    {side}_{interval_name}_{percentile_type}
                FROM {factor_name}_price_divergence
                """
                
                current_df = conn.execute(factor_query).fetchdf()
                
                if len(current_df) > 0:
                    if result_df is None:
                        result_df = current_df
                    else:
                        result_df = result_df.merge(
                            current_df,
                            on='security_code',
                            how='outer'
                        )
            except Exception as e:
                print(f"计算因子 {factor_name} 时出错: {str(e)}")
                continue
                
    except Exception as e:
        print(f"处理日期 {date_str} 时出错: {str(e)}")
        raise
    finally:
        conn.close()
    
    # 如果没有结果，返回空DataFrame
    if result_df is None or len(result_df) == 0:
        columns = ['security_code']
        return pd.DataFrame(columns=columns)
    
    return result_df

# %%
def process_single_date(trading_date, factor_name):
    
    """处理单个交易日的函数"""
   
    date_str = trading_date.strftime('%Y%m%d')
    output_dir = f"./factors/{factor_name}"
    file_path = f"{output_dir}/{date_str}.parquet"
    
    # 如果文件已存在，跳过处理
    if os.path.exists(file_path):
        print(f"文件已存在，跳过: {date_str}")
        return date_str, True, "已存在"
    
    # 检查原始数据文件是否存在
    data_file = f"/data/cephfs/order/{date_str}.parquet"
    if not os.path.exists(data_file):
        print(f"跳过日期 {date_str}: 原始数据文件不存在")
        return date_str, False, "数据文件不存在"
    
    try:
        daily_factor_df = calculate_daily_factor(trading_date)
        
        daily_factor_df['date'] = date_str

        daily_factor_df.to_parquet(file_path, index=False)
        print(f"已生成因子文件: {file_path}")
        return date_str, True, "成功"
        
    except Exception as e:
        error_msg = str(e)
        print(f"处理日期 {date_str} 时出错: {error_msg}")
        return date_str, False, error_msg


def derive_daily_factor(start_date, end_date, factor_name, num_processes=16):
    start_time = time.time()
    
    trading_dates = pd.date_range(start=start_date, end=end_date, freq='D')
    
    # 创建输出目录
    output_dir = f"./factors/{factor_name}"
    os.makedirs(output_dir, exist_ok=True)
    
    # 创建进程池
    pool = mp.Pool(processes=num_processes)
    
    # 创建带有固定参数的处理函数
    process_date_with_args = partial(process_single_date, factor_name=factor_name)
    
    # 提交所有任务到进程池并获取结果
    print(f"开始使用 {num_processes} 个进程并行处理 {len(trading_dates)} 个交易日...")
    results = pool.map(process_date_with_args, trading_dates)
    
    # 关闭进程池
    pool.close()
    pool.join()
    
    # 分析处理结果
    processed_dates = [date_str for date_str, success, _ in results if success]
    skipped_dates = [date_str for date_str, success, _ in results if not success]
    
    # 打印处理结果摘要
    print(f"\n处理完成:")
    print(f"成功处理 {len(processed_dates)} 个日期")
    print(f"跳过 {len(skipped_dates)} 个日期")

    return output_dir

# %%
def main():
    start_date = '2016-06-20'
    end_date = '2025-06-30'
    factor_name = '1_99_percent_price_divergence'
    factor_dir = derive_daily_factor (start_date, end_date, factor_name)

main()
# Out:
# 文件已存在，跳过: 20160811文件已存在，跳过: 20160620文件已存在，跳过: 20170307跳过日期 20161002: 原始数据文件不存在文件已存在，跳过: 20170810跳过日期 20170114: 原始数据文件不存在文件已存在，跳过: 20161123文件已存在，跳过: 20170428文件已存在，跳过: 20170619跳过日期 20171001: 原始数据文件不存在
#
#
#
#
# 文件已存在，跳过: 20160812文件已存在，跳过: 20171122
#
# 跳过日期 20180113: 原始数据文件不存在文件已存在，跳过: 20160621
#
# 文件已存在，跳过: 20170308
# 文件已存在，跳过: 20180306文件已存在，跳过: 20170811
# 跳过日期 20180618: 原始数据文件不存在跳过日期 20161003: 原始数据文件不存在文件已存在，跳过: 20180809文件已存在，跳过: 20180427
#
# 文件已存在，跳过: 20161124跳过日期 20170115: 原始数据文件不存在
# 跳过日期 20170429: 原始数据文件不存在跳过日期 20171002: 原始数据文件不存在
#
# 文件已存在，跳过: 20170620
# 文件已存在，跳过: 20171123
#
#
# 文件已存在，跳过: 20160622
# 跳过日期 20180114: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20170309跳过日期 20160813: 原始数据文件不存在
# 文件已存在，跳过: 20180307跳过日期 20170812: 原始数据文件不存在跳过日期 20161004: 原始数据文件不存在
# 跳过日期 20180428: 原始数据文件不存在文件已存在，跳过: 20180619
#
# 文件已存在，跳过: 20170116
# 文件已存在，跳过: 20180810
# 跳过日期 20171003: 原始数据文件不存在文件已存在，跳过: 20170621
#
#
#
# 文件已存在，跳过: 20171124文件已存在，跳过: 20161125
#
# 跳过日期 20170430: 原始数据文件不存在文件已存在，跳过: 20160623
# 文件已存在，跳过: 20180115
# 跳过日期 20160814: 原始数据文件不存在
#
# 文件已存在，跳过: 20180308跳过日期 20170813: 原始数据文件不存在文件已存在，跳过: 20170310跳过日期 20161005: 原始数据文件不存在
#
# 跳过日期 20180429: 原始数据文件不存在文件已存在，跳过: 20180620
#
# 文件已存在，跳过: 20170117
# 跳过日期 20180811: 原始数据文件不存在
# 跳过日期 20171004: 原始数据文件不存在文件已存在，跳过: 20170622
#
#
#
# 跳过日期 20171125: 原始数据文件不存在跳过日期 20161126: 原始数据文件不存在
#
# 跳过日期 20170501: 原始数据文件不存在文件已存在，跳过: 20160624
# 文件已存在，跳过: 20180116
# 文件已存在，跳过: 20160815
#
# 文件已存在，跳过: 20180309文件已存在，跳过: 20170814跳过日期 20170311: 原始数据文件不存在跳过日期 20161006: 原始数据文件不存在
#
# 跳过日期 20180430: 原始数据文件不存在文件已存在，跳过: 20180621
#
# 文件已存在，跳过: 20170118
# 跳过日期 20180812: 原始数据文件不存在
# 跳过日期 20171005: 原始数据文件不存在文件已存在，跳过: 20170623
#
#
# 跳过日期 20171126: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20170502跳过日期 20160625: 原始数据文件不存在跳过日期 20161127: 原始数据文件不存在
# 文件已存在，跳过: 20180117文件已存在，跳过: 20160816
#
# 跳过日期 20170312: 原始数据文件不存在
# 文件已存在，跳过: 20170815文件已存在，跳过: 20180622
# 跳过日期 20180310: 原始数据文件不存在跳过日期 20161007: 原始数据文件不存在跳过日期 20180501: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20170119
# 文件已存在，跳过: 20180813跳过日期 20171006: 原始数据文件不存在
#
# 跳过日期 20170624: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20171127
#
# 文件已存在，跳过: 20161128文件已存在，跳过: 20170503跳过日期 20160626: 原始数据文件不存在
#
# 文件已存在，跳过: 20160817文件已存在，跳过: 20180118
#
# 跳过日期 20180623: 原始数据文件不存在文件已存在，跳过: 20170313文件已存在，跳过: 20170816跳过日期 20161008: 原始数据文件不存在
# 跳过日期 20180311: 原始数据文件不存在
#
# 文件已存在，跳过: 20180502
# 文件已存在，跳过: 20180814文件已存在，跳过: 20170120
# 跳过日期 20171007: 原始数据文件不存在
# 跳过日期 20170625: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: 20171128
# 文件已存在，跳过: 20161129
# 文件已存在，跳过: 20160627
#
# 文件已存在，跳过: 20160818
# 文件已存在，跳过: 20170504文件已存在，跳过: 20170817跳过日期 20180624: 原始数据文件不存在文件已存在，跳过: 20180119
# 文件已存在，跳过: 20170314跳过日期 20161009: 原始数据文件不存在
# 文件已存在，跳过: 20180312
# 文件已存在，跳过: 20180503
# 文件已存在，跳过: 20180815跳过日期 20170121: 原始数据文件不存在
#
# 跳过日期 20171008: 原始数据文件不存在
#
# 文件已存在，跳过: 20170626
#
#
# 文件已存在，跳过: 20171129
# 文件已存在，跳过: 20161130
#
# 文件已存在，跳过: 20160628
#
# 文件已存在，跳过: 20180625文件已存在，跳过: 20170315文件已存在，跳过: 20170818跳过日期 20180120: 原始数据文件不存在文件已存在，跳过: 20160819
#
# 文件已存在，跳过: 20180313文件已存在，跳过: 20161010文件已存在，跳过: 20170505文件已存在，跳过: 20180504
# 文件已存在，跳过: 20170627
#
#
#
# 文件已存在，跳过: 20171130
#
#
#
# 跳过日期 20170122: 原始数据文件不存在
# 文件已存在，跳过: 20171009文件已存在，跳过: 20180816
# 文件已存在，跳过: 20160629
# 文件已存在，跳过: 20180626文件已存在，跳过: 20170316跳过日期 20170819: 原始数据文件不存在跳过日期 20160820: 原始数据文件不存在
# 文件已存在，跳过: 20161201跳过日期 20170506: 原始数据文件不存在文件已存在，跳过: 20180314跳过日期 20180121: 原始数据文件不存在
#
#
#
# 跳过日期 20180505: 原始数据文件不存在文件已存在，跳过: 20161011文件已存在，跳过: 20170628
#
#
#
#
#
#
# 文件已存在，跳过: 20180817文件已存在，跳过: 20171201文件已存在，跳过: 20170123文件已存在，跳过: 20171010文件已存在，跳过: 20180627
#
#
# 跳过日期 20160821: 原始数据文件不存在
# 文件已存在，跳过: 20161202文件已存在，跳过: 20160630跳过日期 20170820: 原始数据文件不存在文件已存在，跳过: 20180315文件已存在，跳过: 20170317
# 跳过日期 20170507: 原始数据文件不存在
#
#
#
# 跳过日期 20180506: 原始数据文件不存在文件已存在，跳过: 20180122文件已存在，跳过: 20170629
# 文件已存在，跳过: 20161012
#
#
#
#
# 跳过日期 20180818: 原始数据文件不存在跳过日期 20171202: 原始数据文件不存在
# 文件已存在，跳过: 20170124文件已存在，跳过: 20171011文件已存在，跳过: 20180628
#
#
# 文件已存在，跳过: 20160822
# 跳过日期 20161203: 原始数据文件不存在文件已存在，跳过: 20160701文件已存在，跳过: 20170821文件已存在，跳过: 20180316跳过日期 20170318: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20170508
#
# 文件已存在，跳过: 20180507文件已存在，跳过: 20180123
# 文件已存在，跳过: 20170630文件已存在，跳过: 20161013
#
#
#
#
# 跳过日期 20180819: 原始数据文件不存在文件已存在，跳过: 20170125跳过日期 20171203: 原始数据文件不存在
# 文件已存在，跳过: 20171012文件已存在，跳过: 20180629
#
#
# 文件已存在，跳过: 20160823
# 跳过日期 20161204: 原始数据文件不存在跳过日期 20160702: 原始数据文件不存在文件已存在，跳过: 20170822跳过日期 20180317: 原始数据文件不存在跳过日期 20170319: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20170509
#
# 文件已存在，跳过: 20180508文件已存在，跳过: 20180124跳过日期 20170701: 原始数据文件不存在文件已存在，跳过: 20161014
#
#
#
#
#
# 文件已存在，跳过: 20180820
# 文件已存在，跳过: 20170126文件已存在，跳过: 20171204跳过日期 20180630: 原始数据文件不存在文件已存在，跳过: 20171013
# 文件已存在，跳过: 20160824
# 文件已存在，跳过: 20161205跳过日期 20160703: 原始数据文件不存在跳过日期 20180318: 原始数据文件不存在
# 文件已存在，跳过: 20170823
#
# 文件已存在，跳过: 20170510
# 文件已存在，跳过: 20170320
#
# 跳过日期 20161015: 原始数据文件不存在
#
#
#
#
#
# 文件已存在，跳过: 20180821文件已存在，跳过: 20180125
# 文件已存在，跳过: 20180509文件已存在，跳过: 20171205跳过日期 20170127: 原始数据文件不存在跳过日期 20180701: 原始数据文件不存在
#
# 文件已存在，跳过: 20160825跳过日期 20170702: 原始数据文件不存在文件已存在，跳过: 20161206跳过日期 20171014: 原始数据文件不存在
# 文件已存在，跳过: 20170511文件已存在，跳过: 20160704文件已存在，跳过: 20170824
# 文件已存在，跳过: 20180319
#
# 文件已存在，跳过: 20170321
#
#
#
#
#
# 跳过日期 20161016: 原始数据文件不存在文件已存在，跳过: 20180822
#
#
# 文件已存在，跳过: 20180510
# 文件已存在，跳过: 20171206跳过日期 20170128: 原始数据文件不存在
# 文件已存在，跳过: 20180126文件已存在，跳过: 20180702文件已存在，跳过: 20170703文件已存在，跳过: 20161207跳过日期 20171015: 原始数据文件不存在文件已存在，跳过: 20160826
#
# 文件已存在，跳过: 20160705文件已存在，跳过: 20170825文件已存在，跳过: 20170512
# 文件已存在，跳过: 20180320
#
# 文件已存在，跳过: 20170322
#
#
#
#
#
# 文件已存在，跳过: 20161017文件已存在，跳过: 20180823
#
#
#
# 文件已存在，跳过: 20180511文件已存在，跳过: 20171207跳过日期 20170129: 原始数据文件不存在
# 文件已存在，跳过: 20180703跳过日期 20180127: 原始数据文件不存在文件已存在，跳过: 20170704文件已存在，跳过: 20161208文件已存在，跳过: 20171016跳过日期 20160827: 原始数据文件不存在
#
# 文件已存在，跳过: 20160706跳过日期 20170826: 原始数据文件不存在文件已存在，跳过: 20180321跳过日期 20170513: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20170323
#
#
#
#
#
# 文件已存在，跳过: 20161018文件已存在，跳过: 20180824
#
#
# 文件已存在，跳过: 20171208
#
# 跳过日期 20170130: 原始数据文件不存在跳过日期 20180128: 原始数据文件不存在文件已存在，跳过: 20180704文件已存在，跳过: 20161209
# 跳过日期 20180512: 原始数据文件不存在文件已存在，跳过: 20171017文件已存在，跳过: 20170705跳过日期 20160828: 原始数据文件不存在跳过日期 20170827: 原始数据文件不存在文件已存在，跳过: 20160707文件已存在，跳过: 20180322
#
# 跳过日期 20170514: 原始数据文件不存在文件已存在，跳过: 20170324
#
#
#
# 文件已存在，跳过: 20161019
#
#
#
#
#
#
# 跳过日期 20171209: 原始数据文件不存在跳过日期 20180825: 原始数据文件不存在
#
# 文件已存在，跳过: 20180129跳过日期 20170131: 原始数据文件不存在跳过日期 20180513: 原始数据文件不存在文件已存在，跳过: 20180705文件已存在，跳过: 20171018
# 文件已存在，跳过: 20170706跳过日期 20161210: 原始数据文件不存在文件已存在，跳过: 20170828文件已存在，跳过: 20160708文件已存在，跳过: 20180323文件已存在，跳过: 20160829
#
# 跳过日期 20170325: 原始数据文件不存在文件已存在，跳过: 20170515
#
#
# 文件已存在，跳过: 20161020
#
#
#
#
#
#
# 跳过日期 20180826: 原始数据文件不存在
#
# 跳过日期 20170201: 原始数据文件不存在
# 跳过日期 20171210: 原始数据文件不存在文件已存在，跳过: 20180514文件已存在，跳过: 20180706
# 文件已存在，跳过: 20170707跳过日期 20161211: 原始数据文件不存在文件已存在，跳过: 20170829文件已存在，跳过: 20171019文件已存在，跳过: 20180130跳过日期 20180324: 原始数据文件不存在
# 文件已存在，跳过: 20160830跳过日期 20170326: 原始数据文件不存在文件已存在，跳过: 20170516
#
# 跳过日期 20160709: 原始数据文件不存在
#
# 文件已存在，跳过: 20161021
#
#
#
#
#
# 文件已存在，跳过: 20180827
# 文件已存在，跳过: 20171211
# 跳过日期 20170708: 原始数据文件不存在文件已存在，跳过: 20161212
# 文件已存在，跳过: 20170830文件已存在，跳过: 20171020
# 文件已存在，跳过: 20180131跳过日期 20180707: 原始数据文件不存在跳过日期 20170202: 原始数据文件不存在
#
# 文件已存在，跳过: 20180515文件已存在，跳过: 20160831
# 文件已存在，跳过: 20170327
# 跳过日期 20180325: 原始数据文件不存在
# 文件已存在，跳过: 20170517
# 跳过日期 20160710: 原始数据文件不存在
#
#
#
#
# 文件已存在，跳过: 20171212
#
# 文件已存在，跳过: 20180828跳过日期 20161022: 原始数据文件不存在跳过日期 20170709: 原始数据文件不存在
# 文件已存在，跳过: 20161213
# 文件已存在，跳过: 20170831文件已存在，跳过: 20170203文件已存在，跳过: 20180516跳过日期 20171021: 原始数据文件不存在
# 跳过日期 20180708: 原始数据文件不存在文件已存在，跳过: 20160901
# 文件已存在，跳过: 20170328文件已存在，跳过: 20180201
#
#
# 文件已存在，跳过: 20180326
# 文件已存在，跳过: 20170518
#
#
#
# 文件已存在，跳过: 20160711
#
#
# 文件已存在，跳过: 20171213
# 文件已存在，跳过: 20180829文件已存在，跳过: 20170710跳过日期 20161023: 原始数据文件不存在
# 文件已存在，跳过: 20161214
# 文件已存在，跳过: 20170901跳过日期 20170204: 原始数据文件不存在跳过日期 20171022: 原始数据文件不存在文件已存在，跳过: 20180517
# 文件已存在，跳过: 20180709文件已存在，跳过: 20160902文件已存在，跳过: 20170329
#
# 文件已存在，跳过: 20180202
# 文件已存在，跳过: 20180327
# 文件已存在，跳过: 20170519
#
#
#
#
#
# 文件已存在，跳过: 20160712
#
# 文件已存在，跳过: 20171214文件已存在，跳过: 20180830
# 文件已存在，跳过: 20161024
#
# 文件已存在，跳过: 20170711文件已存在，跳过: 20161215跳过日期 20170205: 原始数据文件不存在跳过日期 20170902: 原始数据文件不存在文件已存在，跳过: 20171023文件已存在，跳过: 20180518
# 文件已存在，跳过: 20180710文件已存在，跳过: 20170330跳过日期 20160903: 原始数据文件不存在
#
# 跳过日期 20180203: 原始数据文件不存在
#
# 跳过日期 20170520: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: 20160713
#
#
# 文件已存在，跳过: 20171215文件已存在，跳过: 20180328
# 文件已存在，跳过: 20180831
# 文件已存在，跳过: 20161025
# 文件已存在，跳过: 20161216文件已存在，跳过: 20170712文件已存在，跳过: 20170206文件已存在，跳过: 20171024文件已存在，跳过: 20180711跳过日期 20160904: 原始数据文件不存在跳过日期 20180519: 原始数据文件不存在跳过日期 20170903: 原始数据文件不存在文件已存在，跳过: 20170331
#
#
#
# 跳过日期 20180204: 原始数据文件不存在
# 跳过日期 20170521: 原始数据文件不存在
#
#
#
#
#
#
#
#
# 文件已存在，跳过: 20160714跳过日期 20180901: 原始数据文件不存在跳过日期 20171216: 原始数据文件不存在
# 文件已存在，跳过: 20180329文件已存在，跳过: 20161026
# 文件已存在，跳过: 20170713跳过日期 20161217: 原始数据文件不存在文件已存在，跳过: 20171025文件已存在，跳过: 20170207文件已存在，跳过: 20160905跳过日期 20180520: 原始数据文件不存在文件已存在，跳过: 20180712文件已存在，跳过: 20170904跳过日期 20170401: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20180205
#
# 文件已存在，跳过: 20170522
#
#
#
#
#
#
#
#
# 文件已存在，跳过: 20160715跳过日期 20180902: 原始数据文件不存在
# 跳过日期 20171217: 原始数据文件不存在文件已存在，跳过: 20161027
# 文件已存在，跳过: 20180330跳过日期 20161218: 原始数据文件不存在文件已存在，跳过: 20170714文件已存在，跳过: 20171026文件已存在，跳过: 20170208文件已存在，跳过: 20180521文件已存在，跳过: 20160906
# 文件已存在，跳过: 20180206文件已存在，跳过: 20180713文件已存在，跳过: 20170905
# 跳过日期 20170402: 原始数据文件不存在
#
#
#
#
# 文件已存在，跳过: 20170523
#
#
# 跳过日期 20160716: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20180903
#
# 跳过日期 20180331: 原始数据文件不存在文件已存在，跳过: 20171218文件已存在，跳过: 20161219文件已存在，跳过: 20161028文件已存在，跳过: 20171027
# 文件已存在，跳过: 20180522
# 文件已存在，跳过: 20170209文件已存在，跳过: 20180207文件已存在，跳过: 20160907跳过日期 20180714: 原始数据文件不存在跳过日期 20170715: 原始数据文件不存在
# 文件已存在，跳过: 20170906跳过日期 20170403: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20170524
#
#
#
# 跳过日期 20160717: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20180904
#
#
# 文件已存在，跳过: 20171219跳过日期 20171028: 原始数据文件不存在跳过日期 20180401: 原始数据文件不存在文件已存在，跳过: 20180523
# 跳过日期 20161029: 原始数据文件不存在文件已存在，跳过: 20161220文件已存在，跳过: 20170210
# 文件已存在，跳过: 20160908跳过日期 20180715: 原始数据文件不存在文件已存在，跳过: 20180208
# 跳过日期 20170716: 原始数据文件不存在文件已存在，跳过: 20170907跳过日期 20170404: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: 20170525
#
#
# 文件已存在，跳过: 20160718
#
#
# 文件已存在，跳过: 20180905
#
#
# 文件已存在，跳过: 20171220文件已存在，跳过: 20180524跳过日期 20171029: 原始数据文件不存在文件已存在，跳过: 20180402
# 跳过日期 20161030: 原始数据文件不存在跳过日期 20170211: 原始数据文件不存在文件已存在，跳过: 20161221文件已存在，跳过: 20180716文件已存在，跳过: 20160909文件已存在，跳过: 20180209
#
# 文件已存在，跳过: 20170717文件已存在，跳过: 20170908文件已存在，跳过: 20170405
#
#
#
#
#
# 文件已存在，跳过: 20170526
#
#
# 文件已存在，跳过: 20160719
# 文件已存在，跳过: 20180906
#
# 文件已存在，跳过: 20171221
# 文件已存在，跳过: 20180403文件已存在，跳过: 20171030文件已存在，跳过: 20180525
# 文件已存在，跳过: 20161031跳过日期 20160910: 原始数据文件不存在
# 跳过日期 20170909: 原始数据文件不存在文件已存在，跳过: 20161222文件已存在，跳过: 20180717
# 文件已存在，跳过: 20170406文件已存在，跳过: 20170718
# 跳过日期 20170212: 原始数据文件不存在
#
# 跳过日期 20180210: 原始数据文件不存在跳过日期 20170527: 原始数据文件不存在
#
# 文件已存在，跳过: 20180907
#
#
#
# 文件已存在，跳过: 20171222文件已存在，跳过: 20180404
#
#
# 跳过日期 20180526: 原始数据文件不存在
#
# 文件已存在，跳过: 20171031文件已存在，跳过: 20160720文件已存在，跳过: 20161101
# 文件已存在，跳过: 20180718跳过日期 20160911: 原始数据文件不存在跳过日期 20170910: 原始数据文件不存在文件已存在，跳过: 20170407
#
# 文件已存在，跳过: 20170719文件已存在，跳过: 20161223文件已存在，跳过: 20170213
# 跳过日期 20180211: 原始数据文件不存在
# 跳过日期 20170528: 原始数据文件不存在
#
# 跳过日期 20180908: 原始数据文件不存在
#
#
#
# 跳过日期 20171223: 原始数据文件不存在跳过日期 20180405: 原始数据文件不存在
#
#
# 跳过日期 20180527: 原始数据文件不存在
# 文件已存在，跳过: 20171101
# 文件已存在，跳过: 20160721
# 文件已存在，跳过: 20161102文件已存在，跳过: 20180719文件已存在，跳过: 20160912跳过日期 20170408: 原始数据文件不存在文件已存在，跳过: 20170911
#
# 文件已存在，跳过: 20170720文件已存在，跳过: 20170214跳过日期 20161224: 原始数据文件不存在
# 文件已存在，跳过: 20180212
#
# 跳过日期 20170529: 原始数据文件不存在
# 跳过日期 20180909: 原始数据文件不存在
#
#
#
# 跳过日期 20171224: 原始数据文件不存在跳过日期 20180406: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20171102文件已存在，跳过: 20160722文件已存在，跳过: 20180528
#
#
# 文件已存在，跳过: 20180720文件已存在，跳过: 20161103跳过日期 20170409: 原始数据文件不存在文件已存在，跳过: 20170912文件已存在，跳过: 20160913
#
# 文件已存在，跳过: 20170721跳过日期 20161225: 原始数据文件不存在文件已存在，跳过: 20170215
#
#
# 文件已存在，跳过: 20180910
# 文件已存在，跳过: 20180213
#
# 跳过日期 20170530: 原始数据文件不存在
#
# 文件已存在，跳过: 20171103
# 文件已存在，跳过: 20171225跳过日期 20180407: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20180529
# 文件已存在，跳过: 20161104跳过日期 20180721: 原始数据文件不存在跳过日期 20160723: 原始数据文件不存在
# 文件已存在，跳过: 20170913文件已存在，跳过: 20170410文件已存在，跳过: 20160914
#
#
# 文件已存在，跳过: 20170216文件已存在，跳过: 20161226文件已存在，跳过: 20180214
#
# 文件已存在，跳过: 20180911
#
# 跳过日期 20170722: 原始数据文件不存在
# 文件已存在，跳过: 20170531
#
# 跳过日期 20180408: 原始数据文件不存在文件已存在，跳过: 20171226跳过日期 20171104: 原始数据文件不存在
#
#
# 跳过日期 20161105: 原始数据文件不存在
# 跳过日期 20180722: 原始数据文件不存在文件已存在，跳过: 20180530跳过日期 20160724: 原始数据文件不存在
#
# 文件已存在，跳过: 20170914文件已存在，跳过: 20170411
# 跳过日期 20160915: 原始数据文件不存在
#
# 文件已存在，跳过: 20170217文件已存在，跳过: 20161227跳过日期 20180215: 原始数据文件不存在
# 文件已存在，跳过: 20180912
#
#
# 跳过日期 20170723: 原始数据文件不存在文件已存在，跳过: 20170601
#
# 文件已存在，跳过: 20180409
# 文件已存在，跳过: 20171227跳过日期 20171105: 原始数据文件不存在
#
#
# 跳过日期 20161106: 原始数据文件不存在
# 文件已存在，跳过: 20180531文件已存在，跳过: 20160725
# 文件已存在，跳过: 20180723
# 文件已存在，跳过: 20170915文件已存在，跳过: 20170412
# 跳过日期 20160916: 原始数据文件不存在
#
# 文件已存在，跳过: 20161228跳过日期 20170218: 原始数据文件不存在
# 文件已存在，跳过: 20180913跳过日期 20180216: 原始数据文件不存在
#
# 文件已存在，跳过: 20170724
#
# 文件已存在，跳过: 20180410文件已存在，跳过: 20170602
#
# 文件已存在，跳过: 20171228文件已存在，跳过: 20171106
# 文件已存在，跳过: 20160726文件已存在，跳过: 20180724文件已存在，跳过: 20170413
#
# 文件已存在，跳过: 20161107
# 跳过日期 20170916: 原始数据文件不存在文件已存在，跳过: 20180601跳过日期 20160917: 原始数据文件不存在
#
#
#
#
#
# 文件已存在，跳过: 20161229文件已存在，跳过: 20180914
#
# 跳过日期 20180217: 原始数据文件不存在
# 文件已存在，跳过: 20180411
# 文件已存在，跳过: 20171107
# 跳过日期 20170219: 原始数据文件不存在
# 文件已存在，跳过: 20171229跳过日期 20170603: 原始数据文件不存在文件已存在，跳过: 20160727
#
#
# 文件已存在，跳过: 20170725文件已存在，跳过: 20161108
# 文件已存在，跳过: 20170414跳过日期 20180602: 原始数据文件不存在跳过日期 20160918: 原始数据文件不存在文件已存在，跳过: 20180725
# 跳过日期 20170917: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: 20161230跳过日期 20180915: 原始数据文件不存在
#
# 跳过日期 20180218: 原始数据文件不存在
# 文件已存在，跳过: 20180412
#
#
# 文件已存在，跳过: 20170220
# 文件已存在，跳过: 20171108跳过日期 20171230: 原始数据文件不存在文件已存在，跳过: 20160728跳过日期 20170604: 原始数据文件不存在
#
# 文件已存在，跳过: 20170726
# 跳过日期 20170415: 原始数据文件不存在文件已存在，跳过: 20161109
# 跳过日期 20180603: 原始数据文件不存在文件已存在，跳过: 20160919文件已存在，跳过: 20180726
# 文件已存在，跳过: 20170918
#
#
#
# 跳过日期 20161231: 原始数据文件不存在跳过日期 20180916: 原始数据文件不存在
# 跳过日期 20180219: 原始数据文件不存在
#
# 文件已存在，跳过: 20180413
#
#
# 文件已存在，跳过: 20170221
# 文件已存在，跳过: 20171109跳过日期 20171231: 原始数据文件不存在文件已存在，跳过: 20160729文件已存在，跳过: 20170605
#
# 文件已存在，跳过: 20170727
# 跳过日期 20170416: 原始数据文件不存在文件已存在，跳过: 20161110
# 文件已存在，跳过: 20180604文件已存在，跳过: 20180727
# 文件已存在，跳过: 20160920文件已存在，跳过: 20170919
#
#
# 跳过日期 20170101: 原始数据文件不存在文件已存在，跳过: 20180917
#
#
#
# 跳过日期 20180414: 原始数据文件不存在
# 跳过日期 20180220: 原始数据文件不存在
# 文件已存在，跳过: 20170222
#
#
#
# 文件已存在，跳过: 20171110跳过日期 20160730: 原始数据文件不存在文件已存在，跳过: 20170728文件已存在，跳过: 20170606跳过日期 20180101: 原始数据文件不存在文件已存在，跳过: 20170417文件已存在，跳过: 20161111
# 文件已存在，跳过: 20180605
# 跳过日期 20180728: 原始数据文件不存在
# 文件已存在，跳过: 20180918文件已存在，跳过: 20160921
#
# 文件已存在，跳过: 20170920
#
# 跳过日期 20170102: 原始数据文件不存在
#
# 跳过日期 20180415: 原始数据文件不存在跳过日期 20180221: 原始数据文件不存在
#
#
# 跳过日期 20171111: 原始数据文件不存在
# 文件已存在，跳过: 20170223跳过日期 20170729: 原始数据文件不存在
# 跳过日期 20160731: 原始数据文件不存在
#
# 文件已存在，跳过: 20170607文件已存在，跳过: 20180102
#
# 文件已存在，跳过: 20170418
# 跳过日期 20161112: 原始数据文件不存在文件已存在，跳过: 20180606文件已存在，跳过: 20160922文件已存在，跳过: 20170921
#
#
# 跳过日期 20180729: 原始数据文件不存在文件已存在，跳过: 20180919文件已存在，跳过: 20170103
#
# 文件已存在，跳过: 20180416文件已存在，跳过: 20180222
#
# 跳过日期 20171112: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20170224跳过日期 20170730: 原始数据文件不存在
# 文件已存在，跳过: 20160801
#
# 文件已存在，跳过: 20180103文件已存在，跳过: 20170608
#
# 文件已存在，跳过: 20170419跳过日期 20161113: 原始数据文件不存在
# 文件已存在，跳过: 20180607文件已存在，跳过: 20160923文件已存在，跳过: 20170922
#
# 文件已存在，跳过: 20180730
# 文件已存在，跳过: 20180920文件已存在，跳过: 20170104
#
# 文件已存在，跳过: 20180417文件已存在，跳过: 20180223
#
# 文件已存在，跳过: 20171113
#
#
# 文件已存在，跳过: 20170731跳过日期 20170225: 原始数据文件不存在
# 文件已存在，跳过: 20160802
#
# 文件已存在，跳过: 20180104文件已存在，跳过: 20170609
#
# 文件已存在，跳过: 20170420
# 文件已存在，跳过: 20180608跳过日期 20170923: 原始数据文件不存在跳过日期 20160924: 原始数据文件不存在文件已存在，跳过: 20161114
#
#
# 文件已存在，跳过: 20180731文件已存在，跳过: 20180921文件已存在，跳过: 20170105
#
# 文件已存在，跳过: 20171114
# 文件已存在，跳过: 20180418
# 跳过日期 20180224: 原始数据文件不存在
# 文件已存在，跳过: 20170801
#
#
#
# 跳过日期 20170226: 原始数据文件不存在文件已存在，跳过: 20160803文件已存在，跳过: 20170421
#
# 文件已存在，跳过: 20180105
# 跳过日期 20170610: 原始数据文件不存在跳过日期 20180609: 原始数据文件不存在跳过日期 20170924: 原始数据文件不存在
#
# 跳过日期 20180922: 原始数据文件不存在
#
# 文件已存在，跳过: 20161115跳过日期 20160925: 原始数据文件不存在文件已存在，跳过: 20171115文件已存在，跳过: 20170106文件已存在，跳过: 20180419
#
#
#
#
# 文件已存在，跳过: 20180801文件已存在，跳过: 20170227跳过日期 20180225: 原始数据文件不存在
# 文件已存在，跳过: 20160804文件已存在，跳过: 20170802
#
#
#
#
# 跳过日期 20180610: 原始数据文件不存在跳过日期 20170422: 原始数据文件不存在文件已存在，跳过: 20170925跳过日期 20170611: 原始数据文件不存在跳过日期 20180106: 原始数据文件不存在
#
#
# 跳过日期 20180923: 原始数据文件不存在
#
# 文件已存在，跳过: 20160926文件已存在，跳过: 20171116文件已存在，跳过: 20161116跳过日期 20170107: 原始数据文件不存在文件已存在，跳过: 20180420
#
#
#
#
# 文件已存在，跳过: 20180802文件已存在，跳过: 20170228文件已存在，跳过: 20180226文件已存在，跳过: 20160805
#
# 文件已存在，跳过: 20170803
#
#
#
# 文件已存在，跳过: 20180611文件已存在，跳过: 20170926文件已存在，跳过: 20170612跳过日期 20180107: 原始数据文件不存在跳过日期 20170423: 原始数据文件不存在
#
#
# 跳过日期 20180924: 原始数据文件不存在
# 文件已存在，跳过: 20160927
# 文件已存在，跳过: 20171117文件已存在，跳过: 20161117跳过日期 20170108: 原始数据文件不存在跳过日期 20180421: 原始数据文件不存在
#
#
#
#
# 文件已存在，跳过: 20180803文件已存在，跳过: 20170301文件已存在，跳过: 20180227跳过日期 20160806: 原始数据文件不存在
# 文件已存在，跳过: 20170804
#
#
#
#
# 文件已存在，跳过: 20180612文件已存在，跳过: 20170927文件已存在，跳过: 20170613文件已存在，跳过: 20170424文件已存在，跳过: 20180108
# 文件已存在，跳过: 20180925
#
#
# 文件已存在，跳过: 20161118文件已存在，跳过: 20170109
# 跳过日期 20180422: 原始数据文件不存在
#
# 文件已存在，跳过: 20160928跳过日期 20171118: 原始数据文件不存在跳过日期 20180804: 原始数据文件不存在
#
#
# 跳过日期 20160807: 原始数据文件不存在文件已存在，跳过: 20180613
# 跳过日期 20170805: 原始数据文件不存在文件已存在，跳过: 20170614
# 跳过日期 20161119: 原始数据文件不存在
# 文件已存在，跳过: 20180228
# 文件已存在，跳过: 20160929
# 文件已存在，跳过: 20170928文件已存在，跳过: 20180109
# 开始使用 16 个进程并行处理 3298 个交易日...
# 文件已存在，跳过: 20180614
# 文件已存在，跳过: 20170302
#
#
#
# 文件已存在，跳过: 20160808
#
#
# 文件已存在，跳过: 20180926
# 跳过日期 20171119: 原始数据文件不存在跳过日期 20170806: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20180423文件已存在，跳过: 20180301文件已存在，跳过: 20170425文件已存在，跳过: 20170110
# 跳过日期 20180805: 原始数据文件不存在跳过日期 20161120: 原始数据文件不存在文件已存在，跳过: 20160930文件已存在，跳过: 20170615
# 文件已存在，跳过: 20170929
# 文件已存在，跳过: 20170303文件已存在，跳过: 20180615文件已存在，跳过: 20180110
#
#
#
#
# 文件已存在，跳过: 20160809
#
#
#
# 文件已存在，跳过: 20180927
#
#
# 文件已存在，跳过: 20171120
# 文件已存在，跳过: 20180302文件已存在，跳过: 20180424文件已存在，跳过: 20170807文件已存在，跳过: 20170426
# 文件已存在，跳过: 20170111文件已存在，跳过: 20161121文件已存在，跳过: 20180806
# 跳过日期 20161001: 原始数据文件不存在跳过日期 20170930: 原始数据文件不存在文件已存在，跳过: 20170616跳过日期 20170304: 原始数据文件不存在跳过日期 20180616: 原始数据文件不存在
# 文件已存在，跳过: 20180111
#
#
#
#
# 文件已存在，跳过: 20160810
#
#
# 文件已存在，跳过: 20180928
#
# 文件已存在，跳过: 20170427
#
# 文件已存在，跳过: 20171121
# 跳过日期 20180303: 原始数据文件不存在文件已存在，跳过: 20180425文件已存在，跳过: 20170112
# 文件已存在，跳过: 20170808文件已存在，跳过: 20180807文件已存在，跳过: 20161122
# 跳过日期 20170617: 原始数据文件不存在跳过日期 20170305: 原始数据文件不存在跳过日期 20180930: 原始数据文件不存在跳过日期 20180617: 原始数据文件不存在
# 文件已存在，跳过: 20180112文件已存在，跳过: 20181121
#
#
# 跳过日期 20190112: 原始数据文件不存在
#
#
#
# 跳过日期 20180929: 原始数据文件不存在文件已存在，跳过: 20190305
#
#
#
# 文件已存在，跳过: 20180426
# 文件已存在，跳过: 20170113
#
# 跳过日期 20180304: 原始数据文件不存在
# 跳过日期 20170618: 原始数据文件不存在文件已存在，跳过: 20170809文件已存在，跳过: 20170306文件已存在，跳过: 20190426文件已存在，跳过: 20180808文件已存在，跳过: 20190617
# 文件已存在，跳过: 20190808跳过日期 20181001: 原始数据文件不存在
# 跳过日期 20190113: 原始数据文件不存在
# 文件已存在，跳过: 20181122
#
#
#
#
# 文件已存在，跳过: 20191120
#
# 跳过日期 20190929: 原始数据文件不存在
# 跳过日期 20200111: 原始数据文件不存在
#
# 文件已存在，跳过: 20180305
# 跳过日期 20190427: 原始数据文件不存在文件已存在，跳过: 20200303文件已存在，跳过: 20190618文件已存在，跳过: 20190809文件已存在，跳过: 20190306跳过日期 20181002: 原始数据文件不存在
#
# 文件已存在，跳过: 20200424文件已存在，跳过: 20200615
# 文件已存在，跳过: 20190114
# 文件已存在，跳过: 20181123
#
#
# 跳过日期 20200927: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20190930
# 文件已存在，跳过: 20191121
#
# 跳过日期 20200112: 原始数据文件不存在
# 文件已存在，跳过: 20201118文件已存在，跳过: 20200304
# 文件已存在，跳过: 20190619文件已存在，跳过: 20190307跳过日期 20181003: 原始数据文件不存在跳过日期 20190428: 原始数据文件不存在跳过日期 20190810: 原始数据文件不存在
# 文件已存在，跳过: 20200616
# 跳过日期 20200425: 原始数据文件不存在文件已存在，跳过: 20190115
# 跳过日期 20181124: 原始数据文件不存在
#
# 文件已存在，跳过: 20200928
#
#
#
#
# 跳过日期 20191001: 原始数据文件不存在
# 文件已存在，跳过: 20191122
#
# 文件已存在，跳过: 20200113
# 文件已存在，跳过: 20200305文件已存在，跳过: 20201119
# 文件已存在，跳过: 20190308文件已存在，跳过: 20190620跳过日期 20181004: 原始数据文件不存在文件已存在，跳过: 20200617跳过日期 20190811: 原始数据文件不存在
# 跳过日期 20200426: 原始数据文件不存在
# 文件已存在，跳过: 20190116跳过日期 20181125: 原始数据文件不存在
#
# 文件已存在，跳过: 20190429
#
# 文件已存在，跳过: 20200929
#
#
#
#
# 跳过日期 20191002: 原始数据文件不存在
# 跳过日期 20191123: 原始数据文件不存在
# 文件已存在，跳过: 20200114文件已存在，跳过: 20200306
# 文件已存在，跳过: 20201120
# 文件已存在，跳过: 20190621跳过日期 20190309: 原始数据文件不存在文件已存在，跳过: 20200427文件已存在，跳过: 20200618文件已存在，跳过: 20190812跳过日期 20181005: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20181126文件已存在，跳过: 20190117
# 文件已存在，跳过: 20190430
# 文件已存在，跳过: 20200930
#
#
#
#
#
# 跳过日期 20191003: 原始数据文件不存在跳过日期 20200307: 原始数据文件不存在跳过日期 20191124: 原始数据文件不存在文件已存在，跳过: 20200115跳过日期 20190310: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20200428跳过日期 20201121: 原始数据文件不存在跳过日期 20181006: 原始数据文件不存在
#
# 文件已存在，跳过: 20190118
#
# 文件已存在，跳过: 20190813
#
# 文件已存在，跳过: 20200619跳过日期 20190622: 原始数据文件不存在跳过日期 20191004: 原始数据文件不存在
# 文件已存在，跳过: 20181127
#
#
# 文件已存在，跳过: 20200116
# 跳过日期 20200308: 原始数据文件不存在文件已存在，跳过: 20190311跳过日期 20201001: 原始数据文件不存在文件已存在，跳过: 20200429
#
#
# 跳过日期 20190501: 原始数据文件不存在跳过日期 20190119: 原始数据文件不存在跳过日期 20201122: 原始数据文件不存在
# 文件已存在，跳过: 20191125文件已存在，跳过: 20190814跳过日期 20181007: 原始数据文件不存在
#
#
#
#
# 跳过日期 20190623: 原始数据文件不存在跳过日期 20200620: 原始数据文件不存在
# 跳过日期 20191005: 原始数据文件不存在
#
# 文件已存在，跳过: 20200117
#
#
# 文件已存在，跳过: 20200309文件已存在，跳过: 20181128跳过日期 20201002: 原始数据文件不存在文件已存在，跳过: 20200430文件已存在，跳过: 20190312
#
#
# 文件已存在，跳过: 20201123跳过日期 20190502: 原始数据文件不存在
# 跳过日期 20190120: 原始数据文件不存在文件已存在，跳过: 20191126文件已存在，跳过: 20190815文件已存在，跳过: 20181008
#
#
#
#
# 文件已存在，跳过: 20190624
# 跳过日期 20200621: 原始数据文件不存在跳过日期 20191006: 原始数据文件不存在
#
# 跳过日期 20200118: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20200310文件已存在，跳过: 20181129跳过日期 20201003: 原始数据文件不存在文件已存在，跳过: 20190313
# 跳过日期 20200501: 原始数据文件不存在文件已存在，跳过: 20201124
#
# 跳过日期 20190503: 原始数据文件不存在文件已存在，跳过: 20190121
# 文件已存在，跳过: 20191127文件已存在，跳过: 20190816
# 文件已存在，跳过: 20181009
#
#
# 文件已存在，跳过: 20190625
#
# 文件已存在，跳过: 20200622
# 跳过日期 20191007: 原始数据文件不存在
#
#
# 跳过日期 20200119: 原始数据文件不存在文件已存在，跳过: 20181130
# 文件已存在，跳过: 20190314跳过日期 20201004: 原始数据文件不存在
# 文件已存在，跳过: 20201125跳过日期 20200502: 原始数据文件不存在
# 文件已存在，跳过: 20190122文件已存在，跳过: 20191128
# 跳过日期 20190817: 原始数据文件不存在文件已存在，跳过: 20181010
# 跳过日期 20190504: 原始数据文件不存在
# 文件已存在，跳过: 20190626
#
#
# 文件已存在，跳过: 20191008
#
# 文件已存在，跳过: 20200623
#
#
# 文件已存在，跳过: 20190315
# 跳过日期 20201005: 原始数据文件不存在
# 跳过日期 20181201: 原始数据文件不存在文件已存在，跳过: 20200120
# 文件已存在，跳过: 20190123文件已存在，跳过: 20181011
#
#
# 文件已存在，跳过: 20191129跳过日期 20190818: 原始数据文件不存在跳过日期 20200503: 原始数据文件不存在
# 文件已存在，跳过: 20201126
# 文件已存在，跳过: 20200624
# 跳过日期 20190316: 原始数据文件不存在跳过日期 20201006: 原始数据文件不存在
# 文件已存在，跳过: 20190627
# 文件已存在，跳过: 20191009
# 文件已存在，跳过: 20200121跳过日期 20190505: 原始数据文件不存在
# 文件已存在，跳过: 20190124
#
#
#
#
# 跳过日期 20181202: 原始数据文件不存在文件已存在，跳过: 20181012
#
# 跳过日期 20191130: 原始数据文件不存在跳过日期 20200504: 原始数据文件不存在文件已存在，跳过: 20190819
# 跳过日期 20201007: 原始数据文件不存在跳过日期 20190317: 原始数据文件不存在文件已存在，跳过: 20201127
# 跳过日期 20200625: 原始数据文件不存在
# 文件已存在，跳过: 20190628
# 文件已存在，跳过: 20191010文件已存在，跳过: 20200122
#
#
# 文件已存在，跳过: 20190506
#
#
#
#
# 文件已存在，跳过: 20190125跳过日期 20181013: 原始数据文件不存在
# 跳过日期 20191201: 原始数据文件不存在文件已存在，跳过: 20190820
# 跳过日期 20200505: 原始数据文件不存在
# 文件已存在，跳过: 20181203跳过日期 20201008: 原始数据文件不存在文件已存在，跳过: 20190318
# 跳过日期 20201128: 原始数据文件不存在
# 跳过日期 20200626: 原始数据文件不存在跳过日期 20190629: 原始数据文件不存在文件已存在，跳过: 20200123
#
# 文件已存在，跳过: 20190507
# 文件已存在，跳过: 20191011
#
#
# 跳过日期 20190126: 原始数据文件不存在
# 跳过日期 20181014: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20191202文件已存在，跳过: 20190821
# 文件已存在，跳过: 20200506
# 文件已存在，跳过: 20181204文件已存在，跳过: 20201009文件已存在，跳过: 20190319
# 跳过日期 20201129: 原始数据文件不存在
# 跳过日期 20200627: 原始数据文件不存在跳过日期 20200124: 原始数据文件不存在
# 跳过日期 20190630: 原始数据文件不存在
#
# 跳过日期 20191012: 原始数据文件不存在
#
#
#
#
# 文件已存在，跳过: 20181015文件已存在，跳过: 20190822跳过日期 20190127: 原始数据文件不存在文件已存在，跳过: 20190508跳过日期 20201010: 原始数据文件不存在文件已存在，跳过: 20181205跳过日期 20200628: 原始数据文件不存在
#
# 文件已存在，跳过: 20200507文件已存在，跳过: 20191203
#
# 文件已存在，跳过: 20190823文件已存在，跳过: 20190128
#
#
#
#
# 文件已存在，跳过: 20190320
#
# 跳过日期 20200125: 原始数据文件不存在
# 文件已存在，跳过: 20190701
# 文件已存在，跳过: 20200629文件已存在，跳过: 20181206
# 文件已存在，跳过: 20200508跳过日期 20201011: 原始数据文件不存在
#
# 文件已存在，跳过: 20181016文件已存在，跳过: 20190509文件已存在，跳过: 20190321
# 跳过日期 20191013: 原始数据文件不存在
#
#
# 跳过日期 20190824: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20201012文件已存在，跳过: 20200630文件已存在，跳过: 20191204文件已存在，跳过: 20190129
# 文件已存在，跳过: 20190702
# 跳过日期 20200509: 原始数据文件不存在跳过日期 20200126: 原始数据文件不存在
# 文件已存在，跳过: 20190322文件已存在，跳过: 20181017文件已存在，跳过: 20190510
#
#
#
# 文件已存在，跳过: 20181207文件已存在，跳过: 20191014
#
#
# 跳过日期 20190825: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20201013文件已存在，跳过: 20200701文件已存在，跳过: 20190130文件已存在，跳过: 20191205
#
# 文件已存在，跳过: 20190703跳过日期 20200510: 原始数据文件不存在
# 跳过日期 20200127: 原始数据文件不存在文件已存在，跳过: 20181018跳过日期 20190323: 原始数据文件不存在
#
# 跳过日期 20190511: 原始数据文件不存在
# 文件已存在，跳过: 20191015
#
#
# 文件已存在，跳过: 20190826
# 跳过日期 20181208: 原始数据文件不存在
#
# 文件已存在，跳过: 20201014文件已存在，跳过: 20200702
# 文件已存在，跳过: 20190131
# 文件已存在，跳过: 20190704文件已存在，跳过: 20200511文件已存在，跳过: 20191206
#
# 跳过日期 20200128: 原始数据文件不存在跳过日期 20190324: 原始数据文件不存在文件已存在，跳过: 20181019
#
#
# 文件已存在，跳过: 20191016跳过日期 20190512: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20190827跳过日期 20181209: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20200703文件已存在，跳过: 20190201
#
# 文件已存在，跳过: 20201015文件已存在，跳过: 20190705文件已存在，跳过: 20200512
#
# 跳过日期 20191207: 原始数据文件不存在跳过日期 20181020: 原始数据文件不存在
# 跳过日期 20200129: 原始数据文件不存在文件已存在，跳过: 20191017文件已存在，跳过: 20190513
#
# 文件已存在，跳过: 20190828文件已存在，跳过: 20190325
#
# 文件已存在，跳过: 20181210
#
#
# 跳过日期 20190202: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20200513文件已存在，跳过: 20201016
# 文件已存在，跳过: 20191018跳过日期 20190706: 原始数据文件不存在跳过日期 20191208: 原始数据文件不存在文件已存在，跳过: 20190514跳过日期 20200130: 原始数据文件不存在文件已存在，跳过: 20190829
#
#
#
# 文件已存在，跳过: 20181211跳过日期 20200704: 原始数据文件不存在跳过日期 20181021: 原始数据文件不存在
#
#
#
#
#
# 文件已存在，跳过: 20200514文件已存在，跳过: 20190326跳过日期 20190203: 原始数据文件不存在跳过日期 20200131: 原始数据文件不存在跳过日期 20190707: 原始数据文件不存在跳过日期 20201017: 原始数据文件不存在文件已存在，跳过: 20190515文件已存在，跳过: 20190830
# 跳过日期 20191019: 原始数据文件不存在
# 文件已存在，跳过: 20191209
#
# 跳过日期 20200705: 原始数据文件不存在文件已存在，跳过: 20190327文件已存在，跳过: 20200515文件已存在，跳过: 20181022跳过日期 20190204: 原始数据文件不存在文件已存在，跳过: 20190708文件已存在，跳过: 20190516跳过日期 20200201: 原始数据文件不存在
# 跳过日期 20190831: 原始数据文件不存在
# 文件已存在，跳过: 20181212
# 跳过日期 20201018: 原始数据文件不存在
#
#
#
#
#
#
#
# 跳过日期 20191020: 原始数据文件不存在
# 文件已存在，跳过: 20191210
# 文件已存在，跳过: 20200706文件已存在，跳过: 20181023跳过日期 20200516: 原始数据文件不存在文件已存在，跳过: 20190328跳过日期 20190205: 原始数据文件不存在文件已存在，跳过: 20190709文件已存在，跳过: 20190517跳过日期 20200202: 原始数据文件不存在
# 跳过日期 20190901: 原始数据文件不存在文件已存在，跳过: 20181213文件已存在，跳过: 20201019
#
#
#
#
#
#
#
#
# 文件已存在，跳过: 20191021
#
#
# 文件已存在，跳过: 20191211文件已存在，跳过: 20200707文件已存在，跳过: 20181024文件已存在，跳过: 20190329跳过日期 20200517: 原始数据文件不存在文件已存在，跳过: 20190710跳过日期 20190206: 原始数据文件不存在跳过日期 20190518: 原始数据文件不存在文件已存在，跳过: 20200203
# 文件已存在，跳过: 20190902文件已存在，跳过: 20181214文件已存在，跳过: 20201020
#
#
#
#
#
#
#
#
# 文件已存在，跳过: 20191022
#
#
# 文件已存在，跳过: 20200708文件已存在，跳过: 20181025文件已存在，跳过: 20191212文件已存在，跳过: 20200518跳过日期 20190330: 原始数据文件不存在跳过日期 20190519: 原始数据文件不存在文件已存在，跳过: 20190711
# 文件已存在，跳过: 20190903文件已存在，跳过: 20200204跳过日期 20181215: 原始数据文件不存在
# 文件已存在，跳过: 20201021
#
#
#
#
# 文件已存在，跳过: 20191023
# 跳过日期 20190207: 原始数据文件不存在
# 文件已存在，跳过: 20200709
#
# 文件已存在，跳过: 20200519文件已存在，跳过: 20190712
# 文件已存在，跳过: 20190520
# 文件已存在，跳过: 20190904跳过日期 20190331: 原始数据文件不存在文件已存在，跳过: 20191213跳过日期 20181216: 原始数据文件不存在
#
# 文件已存在，跳过: 20201022文件已存在，跳过: 20181026文件已存在，跳过: 20200205
#
#
#
# 文件已存在，跳过: 20191024
#
# 文件已存在，跳过: 20200710跳过日期 20190208: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20200520
# 文件已存在，跳过: 20190521文件已存在，跳过: 20190905跳过日期 20190713: 原始数据文件不存在
# 文件已存在，跳过: 20190401文件已存在，跳过: 20181217文件已存在，跳过: 20201023跳过日期 20191214: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20191025跳过日期 20181027: 原始数据文件不存在
#
# 文件已存在，跳过: 20190906跳过日期 20190209: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20200206
#
# 跳过日期 20200711: 原始数据文件不存在
#
# 跳过日期 20190714: 原始数据文件不存在文件已存在，跳过: 20200521
#
# 文件已存在，跳过: 20190522
# 文件已存在，跳过: 20181218跳过日期 20191026: 原始数据文件不存在跳过日期 20201024: 原始数据文件不存在跳过日期 20191215: 原始数据文件不存在
# 跳过日期 20181028: 原始数据文件不存在
#
# 文件已存在，跳过: 20200207
# 跳过日期 20190210: 原始数据文件不存在跳过日期 20190907: 原始数据文件不存在
#
#
#
#
# 文件已存在，跳过: 20190715跳过日期 20200712: 原始数据文件不存在
# 文件已存在，跳过: 20200522文件已存在，跳过: 20190523
# 文件已存在，跳过: 20181219
# 文件已存在，跳过: 20191216跳过日期 20191027: 原始数据文件不存在跳过日期 20201025: 原始数据文件不存在文件已存在，跳过: 20181029
#
# 跳过日期 20200208: 原始数据文件不存在
#
# 文件已存在，跳过: 20190211
#
# 跳过日期 20190908: 原始数据文件不存在
#
# 文件已存在，跳过: 20190716
#
# 文件已存在，跳过: 20200713文件已存在，跳过: 20191217文件已存在，跳过: 20190524
# 文件已存在，跳过: 20201026文件已存在，跳过: 20191028文件已存在，跳过: 20181220
# 跳过日期 20200523: 原始数据文件不存在
#
# 文件已存在，跳过: 20181030跳过日期 20200209: 原始数据文件不存在
# 文件已存在，跳过: 20190212
#
#
#
# 文件已存在，跳过: 20190717
# 文件已存在，跳过: 20200714
# 文件已存在，跳过: 20190909
#
# 文件已存在，跳过: 20201027文件已存在，跳过: 20191029文件已存在，跳过: 20191218跳过日期 20190525: 原始数据文件不存在
# 文件已存在，跳过: 20181031跳过日期 20200524: 原始数据文件不存在
# 文件已存在，跳过: 20190213文件已存在，跳过: 20200715
# 文件已存在，跳过: 20181221
# 文件已存在，跳过: 20200210
#
#
#
#
# 文件已存在，跳过: 20191219文件已存在，跳过: 20190718
# 文件已存在，跳过: 20191030
# 文件已存在，跳过: 20190910
# 文件已存在，跳过: 20200525跳过日期 20190526: 原始数据文件不存在
# 文件已存在，跳过: 20201028文件已存在，跳过: 20181101
#
# 文件已存在，跳过: 20200211
#
# 文件已存在，跳过: 20190214跳过日期 20181222: 原始数据文件不存在
#
# 文件已存在，跳过: 20200716
# 文件已存在，跳过: 20191220
#
# 文件已存在，跳过: 20190719文件已存在，跳过: 20191031
# 文件已存在，跳过: 20200526文件已存在，跳过: 20190911
# 文件已存在，跳过: 20190527
#
# 文件已存在，跳过: 20200212文件已存在，跳过: 20181102
#
# 文件已存在，跳过: 20190215
# 文件已存在，跳过: 20201029
#
# 跳过日期 20181223: 原始数据文件不存在
# 跳过日期 20191221: 原始数据文件不存在
# 文件已存在，跳过: 20191101文件已存在，跳过: 20190912跳过日期 20190720: 原始数据文件不存在
# 文件已存在，跳过: 20200527
#
#
# 跳过日期 20181103: 原始数据文件不存在文件已存在，跳过: 20200213
#
# 跳过日期 20190216: 原始数据文件不存在
# 文件已存在，跳过: 20190528
# 跳过日期 20191222: 原始数据文件不存在文件已存在，跳过: 20181224
#
# 跳过日期 20190721: 原始数据文件不存在
# 文件已存在，跳过: 20200528跳过日期 20190913: 原始数据文件不存在跳过日期 20191102: 原始数据文件不存在文件已存在，跳过: 20201030
#
# 跳过日期 20181104: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: 20190529
# 文件已存在，跳过: 20191223
# 文件已存在，跳过: 20181225跳过日期 20190217: 原始数据文件不存在文件已存在，跳过: 20200214跳过日期 20191103: 原始数据文件不存在跳过日期 20201031: 原始数据文件不存在
#
# 文件已存在，跳过: 20200529
# 文件已存在，跳过: 20190722
#
#
#
# 跳过日期 20190914: 原始数据文件不存在
# 文件已存在，跳过: 20181226文件已存在，跳过: 20190530
# 文件已存在，跳过: 20181105文件已存在，跳过: 20190218文件已存在，跳过: 20191224
#
# 文件已存在，跳过: 20191104
#
# 跳过日期 20200215: 原始数据文件不存在跳过日期 20201101: 原始数据文件不存在跳过日期 20200530: 原始数据文件不存在
#
# 文件已存在，跳过: 20181227
#
#
# 文件已存在，跳过: 20201102文件已存在，跳过: 20181106文件已存在，跳过: 20191225
#
# 跳过日期 20190915: 原始数据文件不存在文件已存在，跳过: 20190723文件已存在，跳过: 20190219
# 跳过日期 20200216: 原始数据文件不存在文件已存在，跳过: 20181228
# 文件已存在，跳过: 20191105
#
# 文件已存在，跳过: 20201103
#
# 文件已存在，跳过: 20190916
# 跳过日期 20200531: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: 20190531
# 文件已存在，跳过: 20200217文件已存在，跳过: 20191226文件已存在，跳过: 20190917跳过日期 20181229: 原始数据文件不存在文件已存在，跳过: 20190724文件已存在，跳过: 20191106文件已存在，跳过: 20201104
#
#
#
# 文件已存在，跳过: 20181107文件已存在，跳过: 20190220
#
#
# 文件已存在，跳过: 20190918文件已存在，跳过: 20200218
#
# 文件已存在，跳过: 20200601
#
#
# 文件已存在，跳过: 20191227文件已存在，跳过: 20191107跳过日期 20181230: 原始数据文件不存在文件已存在，跳过: 20190725文件已存在，跳过: 20200219文件已存在，跳过: 20181108
#
# 文件已存在，跳过: 20190919跳过日期 20190601: 原始数据文件不存在文件已存在，跳过: 20201105
#
# 文件已存在，跳过: 20190221文件已存在，跳过: 20200602
#
#
#
#
#
# 跳过日期 20181231: 原始数据文件不存在跳过日期 20191228: 原始数据文件不存在
# 文件已存在，跳过: 20191108文件已存在，跳过: 20190726
# 文件已存在，跳过: 20201106
# 跳过日期 20190602: 原始数据文件不存在
# 文件已存在，跳过: 20181109
#
# 文件已存在，跳过: 20200603文件已存在，跳过: 20200220
#
# 跳过日期 20190101: 原始数据文件不存在
# 文件已存在，跳过: 20190920文件已存在，跳过: 20190222
#
# 跳过日期 20191229: 原始数据文件不存在跳过日期 20181110: 原始数据文件不存在
# 跳过日期 20201107: 原始数据文件不存在
# 跳过日期 20191109: 原始数据文件不存在跳过日期 20190921: 原始数据文件不存在文件已存在，跳过: 20190603
# 文件已存在，跳过: 20200604跳过日期 20190727: 原始数据文件不存在
# 文件已存在，跳过: 20200221
#
#
#
# 跳过日期 20191110: 原始数据文件不存在
#
#
# 跳过日期 20181111: 原始数据文件不存在
# 跳过日期 20190922: 原始数据文件不存在
# 文件已存在，跳过: 20191230跳过日期 20201108: 原始数据文件不存在文件已存在，跳过: 20190604
# 文件已存在，跳过: 20200605跳过日期 20190223: 原始数据文件不存在跳过日期 20190728: 原始数据文件不存在
# 文件已存在，跳过: 20190102
# 文件已存在，跳过: 20201109
#
#
#
#
#
# 跳过日期 20200222: 原始数据文件不存在文件已存在，跳过: 20181112
# 文件已存在，跳过: 20190605文件已存在，跳过: 20191231文件已存在，跳过: 20190923
# 文件已存在，跳过: 20191111
# 跳过日期 20200606: 原始数据文件不存在文件已存在，跳过: 20190729
#
#
# 跳过日期 20200223: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20190924文件已存在，跳过: 20201110
# 文件已存在，跳过: 20181113文件已存在，跳过: 20190103文件已存在，跳过: 20190730跳过日期 20200607: 原始数据文件不存在
# 跳过日期 20190224: 原始数据文件不存在跳过日期 20200101: 原始数据文件不存在
# 文件已存在，跳过: 20190606
#
#
# 文件已存在，跳过: 20190925文件已存在，跳过: 20181114
# 文件已存在，跳过: 20200608
# 文件已存在，跳过: 20190731文件已存在，跳过: 20200102
# 文件已存在，跳过: 20190225
#
#
# 跳过日期 20190607: 原始数据文件不存在
#
# 文件已存在，跳过: 20191112
#
# 文件已存在，跳过: 20200224
# 文件已存在，跳过: 20201111文件已存在，跳过: 20200609文件已存在，跳过: 20200103
# 文件已存在，跳过: 20181115文件已存在，跳过: 20190926
# 文件已存在，跳过: 20190104
#
#
# 跳过日期 20190608: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20190226文件已存在，跳过: 20200225文件已存在，跳过: 20200610文件已存在，跳过: 20181116文件已存在，跳过: 20190801
#
# 文件已存在，跳过: 20191113
# 文件已存在，跳过: 20190927
# 文件已存在，跳过: 20201112跳过日期 20190609: 原始数据文件不存在
# 跳过日期 20200104: 原始数据文件不存在
#
#
#
#
# 跳过日期 20181117: 原始数据文件不存在文件已存在，跳过: 20200226
# 文件已存在，跳过: 20190227文件已存在，跳过: 20200611文件已存在，跳过: 20190610
#
# 文件已存在，跳过: 20191114文件已存在，跳过: 20190802
#
#
# 跳过日期 20200105: 原始数据文件不存在
# 文件已存在，跳过: 20190228文件已存在，跳过: 20190611文件已存在，跳过: 20200227跳过日期 20181118: 原始数据文件不存在文件已存在，跳过: 20201113文件已存在，跳过: 20200612
#
#
#
#
#
# 文件已存在，跳过: 20191115文件已存在，跳过: 20200228文件已存在，跳过: 20190301文件已存在，跳过: 20181119
#
# 跳过日期 20190803: 原始数据文件不存在
# 跳过日期 20201114: 原始数据文件不存在跳过日期 20190105: 原始数据文件不存在跳过日期 20190928: 原始数据文件不存在
# 文件已存在，跳过: 20200106
#
#
# 文件已存在，跳过: 20181120跳过日期 20200229: 原始数据文件不存在
#
#
# 跳过日期 20190302: 原始数据文件不存在跳过日期 20200613: 原始数据文件不存在跳过日期 20190106: 原始数据文件不存在
# 跳过日期 20201115: 原始数据文件不存在
#
# 文件已存在，跳过: 20200107
# 文件已存在，跳过: 20190612
# 跳过日期 20210109: 原始数据文件不存在跳过日期 20190303: 原始数据文件不存在
# 跳过日期 20200614: 原始数据文件不存在
# 跳过日期 20191116: 原始数据文件不存在
#
#
#
#
#
# 文件已存在，跳过: 20190613跳过日期 20200301: 原始数据文件不存在文件已存在，跳过: 20190304跳过日期 20190804: 原始数据文件不存在文件已存在，跳过: 20190107
#
# 文件已存在，跳过: 20200302文件已存在，跳过: 20201116
#
#
# 文件已存在，跳过: 20190614文件已存在，跳过: 20201117跳过日期 20210614: 原始数据文件不存在
#
#
#
# 跳过日期 20191117: 原始数据文件不存在
# 文件已存在，跳过: 20200108跳过日期 20210110: 原始数据文件不存在跳过日期 20190615: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: 20200109
#
# 文件已存在，跳过: 20190108文件已存在，跳过: 20210111
# 文件已存在，跳过: 20190805文件已存在，跳过: 20191118跳过日期 20210926: 原始数据文件不存在
# 跳过日期 20190616: 原始数据文件不存在
# 文件已存在，跳过: 20200110
# 文件已存在，跳过: 20190109文件已存在，跳过: 20190806
#
# 文件已存在，跳过: 20210112
# 跳过日期 20220108: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20210113文件已存在，跳过: 20191119
#
# 文件已存在，跳过: 20190110
# 跳过日期 20220109: 原始数据文件不存在
# 文件已存在，跳过: 20220301
# 文件已存在，跳过: 20190807文件已存在，跳过: 20220110
# 文件已存在，跳过: 20220302
# 文件已存在，跳过: 20190111
# 文件已存在，跳过: 20220422
# 文件已存在，跳过: 20220111
# 文件已存在，跳过: 20220303
# 文件已存在，跳过: 20220112
# 跳过日期 20220423: 原始数据文件不存在文件已存在，跳过: 20220613
#
#
# 跳过日期 20220424: 原始数据文件不存在
# 文件已存在，跳过: 20220425
# 文件已存在，跳过: 20220426
#
# 文件已存在，跳过: 20220304文件已存在，跳过: 20220427
# 跳过日期 20220305: 原始数据文件不存在
# 文件已存在，跳过: 20220113
#
# 跳过日期 20220306: 原始数据文件不存在文件已存在，跳过: 20220428
# 文件已存在，跳过: 20220114文件已存在，跳过: 20220614
#
# 文件已存在，跳过: 20220307
# 跳过日期 20220115: 原始数据文件不存在
#
# 文件已存在，跳过: 20220429跳过日期 20220116: 原始数据文件不存在文件已存在，跳过: 20220615
# 文件已存在，跳过: 20220616
# 文件已存在，跳过: 20220308
#
# 文件已存在，跳过: 20220117
# 文件已存在，跳过: 20220118
# 文件已存在，跳过: 20220119
# 文件已存在，跳过: 20220617跳过日期 20220430: 原始数据文件不存在
# 文件已存在，跳过: 20220309
#
# 跳过日期 20220501: 原始数据文件不存在
# 文件已存在，跳过: 20220120跳过日期 20220618: 原始数据文件不存在
# 文件已存在，跳过: 20220310
# 文件已存在，跳过: 20220121
# 跳过日期 20220122: 原始数据文件不存在
# 跳过日期 20220502: 原始数据文件不存在
# 跳过日期 20220123: 原始数据文件不存在
#
# 文件已存在，跳过: 20220311跳过日期 20220619: 原始数据文件不存在
# 文件已存在，跳过: 20220124文件已存在，跳过: 20220620
#
#
#
# 跳过日期 20220312: 原始数据文件不存在文件已存在，跳过: 20220621
# 文件已存在，跳过: 20220622
# 文件已存在，跳过: 20220125
# 文件已存在，跳过: 20220623跳过日期 20220503: 原始数据文件不存在
# 跳过日期 20220313: 原始数据文件不存在文件已存在，跳过: 20220624
#
# 跳过日期 20220504: 原始数据文件不存在
#
# 跳过日期 20220625: 原始数据文件不存在
#
# 文件已存在，跳过: 20220126文件已存在，跳过: 20220314文件已存在，跳过: 20220505跳过日期 20220626: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: 20220627文件已存在，跳过: 20220506文件已存在，跳过: 20220315
#
# 文件已存在，跳过: 20220127文件已存在，跳过: 20220316
# 跳过日期 20220507: 原始数据文件不存在
#
# 文件已存在，跳过: 20220628
#
# 文件已存在，跳过: 20220128文件已存在，跳过: 20220317
#
# 跳过日期 20220508: 原始数据文件不存在文件已存在，跳过: 20220629跳过日期 20220129: 原始数据文件不存在
# 文件已存在，跳过: 20220318
# 文件已存在，跳过: 20220509
#
# 文件已存在，跳过: 20220510跳过日期 20220319: 原始数据文件不存在
# 跳过日期 20220130: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20220511文件已存在，跳过: 20220630跳过日期 20220320: 原始数据文件不存在
#
# 跳过日期 20220131: 原始数据文件不存在
# 文件已存在，跳过: 20220512
# 文件已存在，跳过: 20220701
#
# 文件已存在，跳过: 20220322文件已存在，跳过: 20220321文件已存在，跳过: 20220513
# 跳过日期 20220702: 原始数据文件不存在跳过日期 20220201: 原始数据文件不存在
#
#
# 文件已存在，跳过: 20220323
# 跳过日期 20220514: 原始数据文件不存在跳过日期 20220202: 原始数据文件不存在跳过日期 20220703: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: 20220704文件已存在，跳过: 20220324跳过日期 20220515: 原始数据文件不存在
# 文件已存在，跳过: 20220705
# 跳过日期 20220203: 原始数据文件不存在
#
# 文件已存在，跳过: 20220516
# 文件已存在，跳过: 20220325文件已存在，跳过: 20220706跳过日期 20220204: 原始数据文件不存在
#
# 跳过日期 20220326: 原始数据文件不存在
#
# 跳过日期 20220205: 原始数据文件不存在
# 文件已存在，跳过: 20220517
# 文件已存在，跳过: 20220707跳过日期 20220206: 原始数据文件不存在跳过日期 20220327: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: 20220708
# 文件已存在，跳过: 20220518文件已存在，跳过: 20220207
#
# 跳过日期 20220709: 原始数据文件不存在
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20220328
# 文件已存在，跳过: 20220208文件已存在，跳过: 20220519
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20220329
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20220520
#
# 跳过日期 20220710: 原始数据文件不存在
#
# 文件已存在，跳过: 20220209
# 文件已存在，跳过: 20220330文件已存在，跳过: 20220210文件已存在，跳过: 20220711跳过日期 20220521: 原始数据文件不存在
# 文件已存在，跳过: 20220211
#
#
# 文件已存在，跳过: 20220331
# 文件已存在，跳过: 20220712
# 跳过日期 20220212: 原始数据文件不存在
# 文件已存在，跳过: 20220401跳过日期 20220522: 原始数据文件不存在
#
# 文件已存在，跳过: 20220713文件已存在，跳过: 20220523
# 跳过日期 20220213: 原始数据文件不存在跳过日期 20220402: 原始数据文件不存在
#
#
# 跳过日期 20220403: 原始数据文件不存在
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 跳过日期 20220404: 原始数据文件不存在
#
# 文件已存在，跳过: 20220524
# 文件已存在，跳过: 20220525
# 文件已存在，跳过: 20220526
# 文件已存在，跳过: 20220527
# 文件已存在，跳过: 20220214跳过日期 20220528: 原始数据文件不存在文件已存在，跳过: 20220714
#
# 文件已存在，跳过: 20220715
# 跳过日期 20220405: 原始数据文件不存在
#
# 跳过日期 20220529: 原始数据文件不存在跳过日期 20220716: 原始数据文件不存在文件已存在，跳过: 20220406
# 文件已存在，跳过: 20220407
# 文件已存在，跳过: 20220408
#
# 跳过日期 20220409: 原始数据文件不存在文件已存在，跳过: 20220215文件已存在，跳过: 20220530
#
#
# 文件已存在，跳过: 20220216文件已存在，跳过: 20220531跳过日期 20220410: 原始数据文件不存在
#
# 文件已存在，跳过: 20220601
#
# 文件已存在，跳过: 20220217文件已存在，跳过: 20220411
# 文件已存在，跳过: 20220602
# 跳过日期 20220603: 原始数据文件不存在
# 文件已存在，跳过: 20220412文件已存在，跳过: 20220218
#
#
# 文件已存在，跳过: 20220413跳过日期 20220604: 原始数据文件不存在跳过日期 20220219: 原始数据文件不存在
#
# 跳过日期 20220605: 原始数据文件不存在
# 文件已存在，跳过: 20220606
# 文件已存在，跳过: 20220607
# 文件已存在，跳过: 20220608
#
# 文件已存在，跳过: 20220414跳过日期 20220717: 原始数据文件不存在
# 跳过日期 20220220: 原始数据文件不存在
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20220718文件已存在，跳过: 20220221文件已存在，跳过: 20220415
#
# 文件已存在，跳过: 20220609
# 文件已存在，跳过: 20220719
# 文件已存在，跳过: 20220222跳过日期 20220416: 原始数据文件不存在
#
# 文件已存在，跳过: 20220720文件已存在，跳过: 20220610跳过日期 20220417: 原始数据文件不存在
#
#
#
# 文件已存在，跳过: 20220418文件已存在，跳过: 20220223
#
# 文件已存在，跳过: 20220224
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20220721跳过日期 20220611: 原始数据文件不存在文件已存在，跳过: 20220419
#
#
#
# 文件已存在，跳过: 20220722跳过日期 20220612: 原始数据文件不存在文件已存在，跳过: 20220225
# 文件已存在，跳过: 20220804
#
#
# 跳过日期 20220226: 原始数据文件不存在跳过日期 20220723: 原始数据文件不存在文件已存在，跳过: 20220805
#
#
# 跳过日期 20220724: 原始数据文件不存在跳过日期 20220806: 原始数据文件不存在
# 跳过日期 20220227: 原始数据文件不存在
# 文件已存在，跳过: 20220725跳过日期 20220807: 原始数据文件不存在
# 文件已存在，跳过: 20220420
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20220228
#
# 文件已存在，跳过: 20220421
#
# 跳过日期 20220925: 原始数据文件不存在
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20221116
#
# 文件已存在，跳过: 20220726
# 文件已存在，跳过: 20221117
#
# 文件已存在，跳过: 20221118
# 跳过日期 20221119: 原始数据文件不存在
# 文件已存在，跳过: 20220808文件已存在，跳过: 20220926文件已存在，跳过: 20220727
# 文件已存在，跳过: 20220728
# 跳过日期 20221120: 原始数据文件不存在
# 文件已存在，跳过: 20220927
#
# 文件已存在，跳过: 20220928
# 文件已存在，跳过: 20221121文件已存在，跳过: 20220929
# 文件已存在，跳过: 20221122
# 文件已存在，跳过: 20221123
# 文件已存在，跳过: 20221124
#
# 文件已存在，跳过: 20220930文件已存在，跳过: 20220809
#
#
# 跳过日期 20221001: 原始数据文件不存在
# 文件已存在，跳过: 20220729文件已存在，跳过: 20220810跳过日期 20221002: 原始数据文件不存在
#
# 跳过日期 20220730: 原始数据文件不存在
# 跳过日期 20221003: 原始数据文件不存在跳过日期 20220731: 原始数据文件不存在
#
#
# 跳过日期 20221004: 原始数据文件不存在文件已存在，跳过: 20220811文件已存在，跳过: 20220801
#
# 跳过日期 20221005: 原始数据文件不存在
#
# 文件已存在，跳过: 20220802跳过日期 20221006: 原始数据文件不存在
# 文件已存在，跳过: 20220812
#
# 跳过日期 20220813: 原始数据文件不存在跳过日期 20221007: 原始数据文件不存在文件已存在，跳过: 20220803
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 跳过日期 20230107: 原始数据文件不存在
# 跳过日期 20221008: 原始数据文件不存在跳过日期 20220814: 原始数据文件不存在
#
# 文件已存在，跳过: 20220815跳过日期 20221009: 原始数据文件不存在
# 文件已存在，跳过: 20221010
# 文件已存在，跳过: 20221011
# 文件已存在，跳过: 20221012
#
# 文件已存在，跳过: 20220816
#
# 跳过日期 20230108: 原始数据文件不存在文件已存在，跳过: 20220817
# 文件已存在，跳过: 20220818
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20220819
#
# 文件已存在，跳过: 20230109跳过日期 20220820: 原始数据文件不存在
# 文件已存在，跳过: 20230110
# 文件已存在，跳过: 20230111
# 文件已存在，跳过: 20230112
# 文件已存在，跳过: 20230113
# 跳过日期 20230114: 原始数据文件不存在
# 跳过日期 20230115: 原始数据文件不存在
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 跳过日期 20220821: 原始数据文件不存在文件已存在，跳过: 20230116
# 文件已存在，跳过: 20230117
#
# 文件已存在，跳过: 20230118文件已存在，跳过: 20220822
#
# 文件已存在，跳过: 20230119
# 文件已存在，跳过: 20220823
# 文件已存在，跳过: 20220824文件已存在，跳过: 20230120
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 跳过日期 20230121: 原始数据文件不存在文件已存在，跳过: 20220825
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20220826
# 跳过日期 20230122: 原始数据文件不存在
# 跳过日期 20220827: 原始数据文件不存在
# 跳过日期 20230123: 原始数据文件不存在
# 跳过日期 20220828: 原始数据文件不存在
# 文件已存在，跳过: 20220829跳过日期 20230124: 原始数据文件不存在
#
# 跳过日期 20230125: 原始数据文件不存在文件已存在，跳过: 20220830
#
# 跳过日期 20230126: 原始数据文件不存在
# 跳过日期 20230127: 原始数据文件不存在文件已存在，跳过: 20220831
#
# 文件已存在，跳过: 20220901跳过日期 20230128: 原始数据文件不存在
# 跳过日期 20230129: 原始数据文件不存在
# 文件已存在，跳过: 20230130
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20230131文件已存在，跳过: 20220902
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20230201
#
# 跳过日期 20220903: 原始数据文件不存在
# 跳过日期 20220904: 原始数据文件不存在
# 文件已存在，跳过: 20220905文件已存在，跳过: 20230202
#
# 文件已存在，跳过: 20220906
# 文件已存在，跳过: 20230203文件已存在，跳过: 20220907
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20220908
#
# 文件已存在，跳过: 20220909跳过日期 20230204: 原始数据文件不存在
#
# 跳过日期 20230205: 原始数据文件不存在跳过日期 20220910: 原始数据文件不存在
# 文件已存在，跳过: 20230206
# 跳过日期 20220911: 原始数据文件不存在
#
# 文件已存在，跳过: 20230207跳过日期 20220912: 原始数据文件不存在
#
# 文件已存在，跳过: 20230208
# 文件已存在，跳过: 20220913文件已存在，跳过: 20230209
# 文件已存在，跳过: 20220914
# 文件已存在，跳过: 20230210
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 跳过日期 20230211: 原始数据文件不存在
# 文件已存在，跳过: 20220915
# 跳过日期 20230212: 原始数据文件不存在
# 文件已存在，跳过: 20230213
# 文件已存在，跳过: 20220916
# 跳过日期 20220917: 原始数据文件不存在
#
# 跳过日期 20220918: 原始数据文件不存在文件已存在，跳过: 20230214
#
# 文件已存在，跳过: 20230215
# 文件已存在，跳过: 20220919
# 文件已存在，跳过: 20230216文件已存在，跳过: 20220920
#
# 文件已存在，跳过: 20230217
# 文件已存在，跳过: 20220921跳过日期 20230218: 原始数据文件不存在
# 文件已存在，跳过: 20220922
#
# 跳过日期 20230219: 原始数据文件不存在
# 文件已存在，跳过: 20230220
# 文件已存在，跳过: 20230221文件已存在，跳过: 20220923
#
# 文件已存在，跳过: 20230222跳过日期 20220924: 原始数据文件不存在
#
# 文件已存在，跳过: 20230223文件已存在，跳过: 20230228
#
# 文件已存在，跳过: 20230224文件已存在，跳过: 20230301
#
# 跳过日期 20230225: 原始数据文件不存在文件已存在，跳过: 20230302
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20230303
# 跳过日期 20230304: 原始数据文件不存在
# 跳过日期 20230226: 原始数据文件不存在跳过日期 20230305: 原始数据文件不存在
# 文件已存在，跳过: 20230227
# 文件已存在，跳过: 20230306
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20230307
# 文件已存在，跳过: 20230308文件已存在，跳过: 20230421
#
# 文件已存在，跳过: 20230309跳过日期 20230422: 原始数据文件不存在
# 文件已存在，跳过: 20230310
#
# 跳过日期 20230311: 原始数据文件不存在跳过日期 20230423: 原始数据文件不存在
#
# 跳过日期 20230312: 原始数据文件不存在文件已存在，跳过: 20230424
#
# 文件已存在，跳过: 20230313文件已存在，跳过: 20230425
# 文件已存在，跳过: 20230426
#
#
# 文件已存在，跳过: 20230314文件已存在，跳过: 20230427文件已存在，跳过: 20230315
# 文件已存在，跳过: 20230316
# 文件已存在，跳过: 20230428
# 跳过日期 20230429: 原始数据文件不存在
# 文件已存在，跳过: 20230317
#
# 跳过日期 20230430: 原始数据文件不存在跳过日期 20230318: 原始数据文件不存在
#
# 跳过日期 20230501: 原始数据文件不存在
# 跳过日期 20230319: 原始数据文件不存在跳过日期 20230502: 原始数据文件不存在
#
#
# 跳过日期 20230503: 原始数据文件不存在文件已存在，跳过: 20230320
#
# 文件已存在，跳过: 20230504文件已存在，跳过: 20230321
# 文件已存在，跳过: 20230505
# 文件已存在，跳过: 20230322
# 跳过日期 20230506: 原始数据文件不存在
# 文件已存在，跳过: 20230323跳过日期 20230507: 原始数据文件不存在
#
# 文件已存在，跳过: 20230508文件已存在，跳过: 20230324
# 文件已存在，跳过: 20230509
# 跳过日期 20230325: 原始数据文件不存在
#
# 文件已存在，跳过: 20230510
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20230511
# 文件已存在，跳过: 20230512
# 跳过日期 20230326: 原始数据文件不存在跳过日期 20230513: 原始数据文件不存在
# 文件已存在，跳过: 20230327
#
# 跳过日期 20230514: 原始数据文件不存在文件已存在，跳过: 20230328
#
# 文件已存在，跳过: 20230515文件已存在，跳过: 20230329
#
#
# 文件已存在，跳过: 20230330文件已存在，跳过: 20230516
# 文件已存在，跳过: 20230331
# 跳过日期 20230401: 原始数据文件不存在
# 跳过日期 20230402: 原始数据文件不存在
# 文件已存在，跳过: 20230403
# 文件已存在，跳过: 20230404
# 跳过日期 20230405: 原始数据文件不存在
# 文件已存在，跳过: 20230406
# 文件已存在，跳过: 20230407
# 跳过日期 20230408: 原始数据文件不存在
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 跳过日期 20230409: 原始数据文件不存在文件已存在，跳过: 20230517
#
# 文件已存在，跳过: 20230410文件已存在，跳过: 20230518
#
# 文件已存在，跳过: 20230519文件已存在，跳过: 20230411
#
# 文件已存在，跳过: 20230412
# 跳过日期 20230520: 原始数据文件不存在
# 跳过日期 20230521: 原始数据文件不存在文件已存在，跳过: 20230413
#
# 文件已存在，跳过: 20230522
# 文件已存在，跳过: 20230523
# 文件已存在，跳过: 20230524文件已存在，跳过: 20230414
#
# 文件已存在，跳过: 20230525跳过日期 20230415: 原始数据文件不存在
#
# 跳过日期 20230416: 原始数据文件不存在文件已存在，跳过: 20230526
#
# 文件已存在，跳过: 20230417跳过日期 20230527: 原始数据文件不存在
#
# 文件已存在，跳过: 20230418跳过日期 20230528: 原始数据文件不存在
#
# 文件已存在，跳过: 20230529
# 文件已存在，跳过: 20230530文件已存在，跳过: 20230419
# 文件已存在，跳过: 20230420
# 文件已存在，跳过: 20230612
#
# 文件已存在，跳过: 20230613
# 文件已存在，跳过: 20230614
# 文件已存在，跳过: 20230615
# 文件已存在，跳过: 20230616
# 文件已存在，跳过: 20230531跳过日期 20230617: 原始数据文件不存在
#
# 跳过日期 20230618: 原始数据文件不存在
# 文件已存在，跳过: 20230619
# 文件已存在，跳过: 20230601文件已存在，跳过: 20230620
# 文件已存在，跳过: 20230621
#
# 文件已存在，跳过: 20230602
# 跳过日期 20230622: 原始数据文件不存在
# 跳过日期 20230623: 原始数据文件不存在
# 跳过日期 20230624: 原始数据文件不存在
# 跳过日期 20230625: 原始数据文件不存在
# 文件已存在，跳过: 20230626
# 文件已存在，跳过: 20230627
# 文件已存在，跳过: 20230628
# 文件已存在，跳过: 20230629
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20230630跳过日期 20230603: 原始数据文件不存在
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 跳过日期 20230604: 原始数据文件不存在跳过日期 20230701: 原始数据文件不存在
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20230605跳过日期 20230702: 原始数据文件不存在
#
# 文件已存在，跳过: 20230703文件已存在，跳过: 20230606
# 文件已存在，跳过: 20230607
#
# 文件已存在，跳过: 20230608
# 文件已存在，跳过: 20230609
# 文件已存在，跳过: 20230704跳过日期 20230610: 原始数据文件不存在
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 跳过日期 20230611: 原始数据文件不存在
# 文件已存在，跳过: 20230803
# 文件已存在，跳过: 20230804
# 文件已存在，跳过: 20230705
# 文件已存在，跳过: 20230706跳过日期 20230805: 原始数据文件不存在
#
# 文件已存在，跳过: 20230707跳过日期 20230806: 原始数据文件不存在
#
# 文件已存在，跳过: 20230807跳过日期 20230708: 原始数据文件不存在
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 跳过日期 20230709: 原始数据文件不存在
#
# 文件已存在，跳过: 20230808
# 文件已存在，跳过: 20230710
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20230809
# 文件已存在，跳过: 20230711文件已存在，跳过: 20230810
#
# 文件已存在，跳过: 20230811文件已存在，跳过: 20230712
# 文件已存在，跳过: 20230713
# 跳过日期 20230812: 原始数据文件不存在
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20230714跳过日期 20230813: 原始数据文件不存在
#
# 跳过日期 20230715: 原始数据文件不存在文件已存在，跳过: 20230814
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 跳过日期 20230716: 原始数据文件不存在
# 文件已存在，跳过: 20230717文件已存在，跳过: 20230815
#
# 文件已存在，跳过: 20230718文件已存在，跳过: 20230816
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20230817
# 文件已存在，跳过: 20230818
# 跳过日期 20230819: 原始数据文件不存在
# 文件已存在，跳过: 20230719
# 跳过日期 20230820: 原始数据文件不存在文件已存在，跳过: 20230720
# 文件已存在，跳过: 20230821
#
# 文件已存在，跳过: 20230721文件已存在，跳过: 20230822
#
# 文件已存在，跳过: 20230823跳过日期 20230722: 原始数据文件不存在
#
# 跳过日期 20230723: 原始数据文件不存在文件已存在，跳过: 20230824
#
# 文件已存在，跳过: 20230825文件已存在，跳过: 20230724
#
# 跳过日期 20230826: 原始数据文件不存在文件已存在，跳过: 20230725
#
# 文件已存在，跳过: 20230726
# 跳过日期 20230827: 原始数据文件不存在
# 文件已存在，跳过: 20230727
# 文件已存在，跳过: 20230828
# 文件已存在，跳过: 20230728
# 文件已存在，跳过: 20230829
# 跳过日期 20230729: 原始数据文件不存在
# 文件已存在，跳过: 20230830跳过日期 20230730: 原始数据文件不存在
# 文件已存在，跳过: 20230831
#
# 文件已存在，跳过: 20230901文件已存在，跳过: 20230731
#
# 跳过日期 20230902: 原始数据文件不存在
# 文件已存在，跳过: 20230801跳过日期 20230903: 原始数据文件不存在
# 文件已存在，跳过: 20230802
# 文件已存在，跳过: 20230904
# 文件已存在，跳过: 20230905
#
# 跳过日期 20230924: 原始数据文件不存在
# 文件已存在，跳过: 20230906
# 文件已存在，跳过: 20230907
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20230908
# 跳过日期 20230909: 原始数据文件不存在
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 跳过日期 20230910: 原始数据文件不存在
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20230911
# 文件已存在，跳过: 20230912
# 文件已存在，跳过: 20230913
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 文件已存在，跳过: 20230914
# 文件已存在，跳过: 20230915
# 跳过日期 20230916: 原始数据文件不存在
# 跳过日期 20230917: 原始数据文件不存在
# 文件已存在，跳过: 20230918
# 文件已存在，跳过: 20230919
# 文件已存在，跳过: 20230920
# 文件已存在，跳过: 20230921
# 文件已存在，跳过: 20230922
# 跳过日期 20230923: 原始数据文件不存在
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ...
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 已生成因子文件: ./factors/1_99_percent_price_divergence/20241101.parquet
# 跳过日期 20241102: 原始数据文件不存在
# 跳过日期 20241103: 原始数据文件不存在
# 文件已存在，跳过: 20241104
# 已生成因子文件: ./factors/1_99_percent_price_divergence/20250409.parquet
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 已生成因子文件: ./factors/1_99_percent_price_divergence/20241218.parquet
# 文件已存在，跳过: 20241219
# 文件已存在，跳过: 20241220
# 跳过日期 20241221: 原始数据文件不存在
# 跳过日期 20241222: 原始数据文件不存在
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 已生成因子文件: ./factors/1_99_percent_price_divergence/20240416.parquet
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 已生成因子文件: ./factors/1_99_percent_price_divergence/20240417.parquet
# 已生成因子文件: ./factors/1_99_percent_price_divergence/20250410.parquet
# 文件已存在，跳过: 20250411
# 跳过日期 20250412: 原始数据文件不存在
# 跳过日期 20250413: 原始数据文件不存在
# 文件已存在，跳过: 20250414
# 文件已存在，跳过: 20250415
# 文件已存在，跳过: 20250416
# 文件已存在，跳过: 20250417
# 已生成因子文件: ./factors/1_99_percent_price_divergence/20241223.parquet
# 已生成因子文件: ./factors/1_99_percent_price_divergence/20241105.parquet
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 已生成因子文件: ./factors/1_99_percent_price_divergence/20240418.parquet
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 已生成因子文件: ./factors/1_99_percent_price_divergence/20241224.parquet
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 已生成因子文件: ./factors/1_99_percent_price_divergence/20241106.parquet
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 已生成因子文件: ./factors/1_99_percent_price_divergence/20241225.parquet
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 已生成因子文件: ./factors/1_99_percent_price_divergence/20241107.parquet
# 已生成因子文件: ./factors/1_99_percent_price_divergence/20241226.parquet
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 已生成因子文件: ./factors/1_99_percent_price_divergence/20241227.parquet
# 跳过日期 20241228: 原始数据文件不存在
# 跳过日期 20241229: 原始数据文件不存在
# 已生成因子文件: ./factors/1_99_percent_price_divergence/20241108.parquet
# 跳过日期 20241109: 原始数据文件不存在
# 跳过日期 20241110: 原始数据文件不存在
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 已生成因子文件: ./factors/1_99_percent_price_divergence/20241230.parquet
# 文件已存在，跳过: 20241231
# 跳过日期 20250101: 原始数据文件不存在
# 文件已存在，跳过: 20250102
# 文件已存在，跳过: 20250103
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 已生成因子文件: ./factors/1_99_percent_price_divergence/20241111.parquet
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 已生成因子文件: ./factors/1_99_percent_price_divergence/20241112.parquet
#
# 处理完成:
# 成功处理 2192 个日期
# 跳过 1106 个日期

# %%
import os
import glob
import pandas as pd
import numpy as np
import duckdb

def standardize_parquet_files(factor_dir):
    """
    读取目录中的所有Parquet文件，确保它们具有相同的列结构，然后重新保存。
    
    参数:
    factor_dir (str): 包含Parquet文件的目录路径
    
    返回:
    int: 处理的文件数量
    """
    # 获取目录中的所有parquet文件
    parquet_files = glob.glob(os.path.join(factor_dir, "*.parquet"))
    if not parquet_files:
        print(f"在目录 {factor_dir} 中未找到Parquet文件")
        return 0
    
    print(f"在目录 {factor_dir} 中找到 {len(parquet_files)} 个Parquet文件")

    all_columns = set(['date','security_code', 'bid_pre_open_915_920_p01_p99',
       'bid_pre_open_915_920_p05_p95', 'ask_pre_open_915_920_p01_p99',
       'ask_pre_open_915_920_p05_p95', 'bid_pre_open_920_925_p01_p99',
       'bid_pre_open_920_925_p05_p95', 'ask_pre_open_920_925_p01_p99',
       'ask_pre_open_920_925_p05_p95', 'bid_early_930_1000_p01_p99',
       'bid_early_930_1000_p05_p95', 'ask_early_930_1000_p01_p99',
       'ask_early_930_1000_p05_p95', 'bid_main_1000_1430_p01_p99',
       'bid_main_1000_1430_p05_p95', 'ask_main_1000_1430_p01_p99',
       'ask_main_1000_1430_p05_p95', 'bid_late_1430_1457_p01_p99',
       'bid_late_1430_1457_p05_p95', 'ask_late_1430_1457_p01_p99',
       'ask_late_1430_1457_p05_p95', 'bid_close_1457_1500_p01_p99',
       'bid_close_1457_1500_p05_p95', 'ask_close_1457_1500_p01_p99',
       'ask_close_1457_1500_p05_p95', 'bid_continue_930_1457_p01_p99',
       'bid_continue_930_1457_p05_p95', 'ask_continue_930_1457_p01_p99',
       'ask_continue_930_1457_p05_p95'])
    
    # # 收集所有文件中的所有列名
    # all_columns = set(['security_code', 'date', 
    #     'pre_open_915_920', 
    #     'pre_open_920_925', 
    #     'early_930_1000', 
    #     'main_1000_1430', 
    #     'late_1430_1457', 
    #     'close_1457_1500',
    #     'continue_930_1457'])  # 这些列必须存在
    
    # # 定义所有可能的因子列名
    # time_intervals = [
    #     'pre_open_915_920', 
    #     'pre_open_920_925', 
    #     'early_930_1000', 
    #     'main_1000_1430', 
    #     'late_1430_1457', 
    #     'close_1457_1500',
    #     'continue_930_1457'
    # ]
    
    # for interval in time_intervals:
    #     all_columns.add(f"bid_{interval}")
    
    # 处理每个文件
    for i, file_path in enumerate(parquet_files):
        try:
            # 读取Parquet文件
            df = pd.read_parquet(file_path)
            
            # 添加缺失的列
            missing_columns = all_columns - set(df.columns)
            for col in missing_columns:
                df[col] = np.nan
            
            # 如果缺少factor_name列，添加它
            if 'factor_name' not in df.columns:
                df['factor_name'] = "3_97_percent_price_divergence"
            
            # 重新保存文件
            df.to_parquet(file_path, index=False)
            
            if (i+1) % 10 == 0 or i+1 == len(parquet_files):
                print(f"已处理 {i+1}/{len(parquet_files)} 个文件")
                
        except Exception as e:
            print(f"处理文件 {file_path} 时出错: {str(e)}")
    
    print("所有文件处理完成")
    return len(parquet_files)

# %%
def filter_and_pivot_factor(all_factor_data, factor_name):
    """
    筛选特定因子列且该列不为NaN的数据，并进行透视
    
    参数:
    all_factor_data: 原始数据DataFrame
    factor_name: 要筛选的因子列名称，例如'bid_pre_open_915_920_p01_p99'
    
    返回:
    透视后的DataFrame，索引为date，列为security_code
    """
    # 步骤1: 筛选必要的列
    filtered_data = all_factor_data[['date', 'security_code', factor_name]]
    
    # 步骤2: 去除因子列为NaN的行
    filtered_data = filtered_data.dropna(subset=[factor_name])
    
    # 步骤3: 检查是否存在重复的(date, security_code)组合
    duplicates = filtered_data.duplicated(subset=['date', 'security_code'], keep=False)
    if duplicates.any():
        print(f"警告: 发现{duplicates.sum()}条重复记录，将保留第一条")
        # 如果有重复，保留第一条
        filtered_data = filtered_data.drop_duplicates(subset=['date', 'security_code'], keep='first')

    output_path = f"/data/home/lexuanchen/Factors/Order/Signal/1_100_Percent_Raw_Price_Divergence_2"
    os.makedirs(output_path, exist_ok=True)
    output_file_path = f"{output_path}/Raw_{factor_name}.csv"
    filtered_data.to_csv(output_file_path)
    print(f"已成功保存因子原文件：{factor_name}")
    
    # 步骤4: 透视表，将security_code作为列，date作为索引
    pivot_data = filtered_data.pivot(index='date', columns='security_code', values=factor_name)
    
    return pivot_data

# %%
def calculate_rolling_20d_avg(factor_names, factor_dir, start_date=None, end_date=None, min_window=5):
    
    print(factor_names)
    
    if not isinstance(factor_names, list):
        factor_names = [factor_names]
    
    parquet_pattern = os.path.join(factor_dir, "*.parquet")
    parquet_files = glob.glob(parquet_pattern)
    print(f"在目录 {factor_dir} 中找到 {len(parquet_files)} 个Parquet文件")
    

    conn = duckdb.connect(database=':memory:')
    all_factor_data = conn.execute(f"""
        SELECT * FROM read_parquet('{parquet_pattern}')
    """).fetchdf()
    conn.close()
    
    

    missing_factors = [f for f in factor_names if f not in all_factor_data.columns]
    if missing_factors:
        raise ValueError(f"在Parquet文件中未找到以下因子列: {', '.join(missing_factors)}")
    
    all_factor_data['date'] = pd.to_datetime(all_factor_data['date'])

    all_factor_data = all_factor_data.sort_values(['date', 'security_code'])
    
    # 筛选日期范围
    if start_date:
        start_date = pd.to_datetime(start_date)
        all_factor_data = all_factor_data[all_factor_data['date'] >= start_date]
    if end_date:
        end_date = pd.to_datetime(end_date)
        all_factor_data = all_factor_data[all_factor_data['date'] <= end_date]

    # 获取所有个股代码
    all_securities = all_factor_data['security_code'].unique()

    result_df = all_factor_data[['date', 'security_code']].copy()

    # 为每个因子计算滚动平均
    for factor_name in factor_names:
        print(f"\n处理因子: {factor_name}")
        
        #转置成宽表
        pivot_data = filter_and_pivot_factor(all_factor_data,factor_name)

        # 对宽表直接应用rolling
        rolling_avg = pivot_data.rolling(window=20, min_periods=min_window).mean()

        # 将结果转换回长格式
        factor_df = rolling_avg.stack().reset_index()
        factor_df.columns = ['date', 'security_code', factor_name]
        factor_df[factor_name] = - factor_df[factor_name]

        # 计算每日因子覆盖率
        # 计算每个日期非NaN的因子值数量
        non_nan_counts = factor_df.dropna(subset=[factor_name]).groupby('date').size()

        # 计算覆盖率
        coverage = non_nan_counts / len(all_securities)
        print(f"\n{factor_name}因子覆盖率统计: 平均={coverage.mean():.2f}, 最小={coverage.min():.2f}")

        result_df = pd.merge(
            result_df, 
            factor_df,
            on=['date', 'security_code'],
            how='left'
        )
    
    return result_df

# %%
def main():
    start_date = '2016-06-20'
    end_date = '2025-06-30'
    
    # 定义时间段列表
    time_intervals = [
        'pre_open_915_920',
        'pre_open_920_925',
        'early_930_1000',
        'main_1000_1430',
        'late_1430_1457',
        'close_1457_1500',
        'continue_930_1457'
    ]
    
    # # 定义因子类型
    # factor_types = [
    #     'bid_p01_p99',
    #     'bid_p05_p95',
    #     'ask_p01_p99',
    #     'ask_p05_p95'
    # ]

        # 定义因子类型
    factor_types = [
        'bid_p03_p97',
        'ask_p03_p97',
    ]
    
    # 生成所有因子名称列表
    all_factors = []
    for factor_type in factor_types:
        side = factor_type.split('_')[0]  # bid 或 ask
        percentile = '_'.join(factor_type.split('_')[1:])  # p01_p99 或 p05_p95
        for interval in time_intervals:
            all_factors.append(f"{side}_{interval}_{percentile}")
    
    # 为每种因子类型创建单独的目录
    factor_dirs = {}
    for factor_type in factor_types:
        factor_name = f"3_97_percent_{factor_type}_price_divergence"
        factor_dir = f"./factors/3_97_percent_price_divergence"
        factor_dirs[factor_type] = factor_dir
        # print(f"{factor_type} 因子文件已生成在目录: {factor_dir}")
        
        # 统一化列名
    # standardize_parquet_files(factor_dir)
    
    # 为每种因子类型计算滚动平均值
    for factor_type, factor_dir in factor_dirs.items():
        # 获取该类型的因子列表
        type_factors = [f for f in all_factors if f.startswith(factor_type.split('_')[0]) and f.endswith('_'.join(factor_type.split('_')[1:]))]
        
        # 计算滚动平均
        result_df = calculate_rolling_20d_avg(type_factors, factor_dir, start_date, end_date, min_window=5)
        
        # 保存结果为CSV
        output_path = f"/data/home/lexuanchen/Factors/Order/Signal/3_97_Percent_{factor_type.upper()}_Price_Divergence_2"
        os.makedirs(output_path, exist_ok=True)
        
        print(f"{factor_type} 因子共计 {len(result_df)} 条记录")
        print("\n数据预览:")
        print(result_df.head())
        
        # 保存每个因子的CSV文件
        for factor in type_factors:
            output_file_path = f"{output_path}/20d_{factor}.csv"
            factor_df = result_df[['date', 'security_code', factor]].dropna(subset=[factor])
            factor_df.to_csv(output_file_path, index=False)

# 执行主函数
if __name__ == "__main__":
    main()
# Out:
# ['bid_pre_open_915_920_p03_p97', 'bid_pre_open_920_925_p03_p97', 'bid_early_930_1000_p03_p97', 'bid_main_1000_1430_p03_p97', 'bid_late_1430_1457_p03_p97', 'bid_close_1457_1500_p03_p97', 'bid_continue_930_1457_p03_p97']
# 在目录 ./factors/3_97_percent_price_divergence 中找到 2164 个Parquet文件
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 处理因子: bid_pre_open_915_920_p03_p97
# 已成功保存因子原文件：bid_pre_open_915_920_p03_p97
#
# bid_pre_open_915_920_p03_p97因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: bid_pre_open_920_925_p03_p97
# 已成功保存因子原文件：bid_pre_open_920_925_p03_p97
#
# bid_pre_open_920_925_p03_p97因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: bid_early_930_1000_p03_p97
# 已成功保存因子原文件：bid_early_930_1000_p03_p97
#
# bid_early_930_1000_p03_p97因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: bid_main_1000_1430_p03_p97
# 已成功保存因子原文件：bid_main_1000_1430_p03_p97
#
# bid_main_1000_1430_p03_p97因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: bid_late_1430_1457_p03_p97
# 已成功保存因子原文件：bid_late_1430_1457_p03_p97
#
# bid_late_1430_1457_p03_p97因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: bid_close_1457_1500_p03_p97
# 已成功保存因子原文件：bid_close_1457_1500_p03_p97
#
# bid_close_1457_1500_p03_p97因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: bid_continue_930_1457_p03_p97
# 已成功保存因子原文件：bid_continue_930_1457_p03_p97
#
# bid_continue_930_1457_p03_p97因子覆盖率统计: 平均=0.77, 最小=0.47
# bid_p03_p97 因子共计 8852399 条记录
#
# 数据预览:
#         date security_code  bid_pre_open_915_920_p03_p97  \
# 0 2016-06-20        000001                           NaN
# 1 2016-06-20        000005                           NaN
# 2 2016-06-20        000006                           NaN
# 3 2016-06-20        000008                           NaN
# 4 2016-06-20        000009                           NaN
#
#    bid_pre_open_920_925_p03_p97  bid_early_930_1000_p03_p97  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#    bid_main_1000_1430_p03_p97  bid_late_1430_1457_p03_p97  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    bid_close_1457_1500_p03_p97  bid_continue_930_1457_p03_p97
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
# ['ask_pre_open_915_920_p03_p97', 'ask_pre_open_920_925_p03_p97', 'ask_early_930_1000_p03_p97', 'ask_main_1000_1430_p03_p97', 'ask_late_1430_1457_p03_p97', 'ask_close_1457_1500_p03_p97', 'ask_continue_930_1457_p03_p97']
# 在目录 ./factors/3_97_percent_price_divergence 中找到 2164 个Parquet文件
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 处理因子: ask_pre_open_915_920_p03_p97
# 已成功保存因子原文件：ask_pre_open_915_920_p03_p97
#
# ask_pre_open_915_920_p03_p97因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: ask_pre_open_920_925_p03_p97
# 已成功保存因子原文件：ask_pre_open_920_925_p03_p97
#
# ask_pre_open_920_925_p03_p97因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: ask_early_930_1000_p03_p97
# 已成功保存因子原文件：ask_early_930_1000_p03_p97
#
# ask_early_930_1000_p03_p97因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: ask_main_1000_1430_p03_p97
# 已成功保存因子原文件：ask_main_1000_1430_p03_p97
#
# ask_main_1000_1430_p03_p97因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: ask_late_1430_1457_p03_p97
# 已成功保存因子原文件：ask_late_1430_1457_p03_p97
#
# ask_late_1430_1457_p03_p97因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: ask_close_1457_1500_p03_p97
# 已成功保存因子原文件：ask_close_1457_1500_p03_p97
#
# ask_close_1457_1500_p03_p97因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: ask_continue_930_1457_p03_p97
# 已成功保存因子原文件：ask_continue_930_1457_p03_p97
#
# ask_continue_930_1457_p03_p97因子覆盖率统计: 平均=0.77, 最小=0.47
# ask_p03_p97 因子共计 8852399 条记录
#
# 数据预览:
#         date security_code  ask_pre_open_915_920_p03_p97  \
# 0 2016-06-20        000001                           NaN
# 1 2016-06-20        000005                           NaN
# 2 2016-06-20        000006                           NaN
# 3 2016-06-20        000008                           NaN
# 4 2016-06-20        000009                           NaN
#
#    ask_pre_open_920_925_p03_p97  ask_early_930_1000_p03_p97  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#    ask_main_1000_1430_p03_p97  ask_late_1430_1457_p03_p97  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    ask_close_1457_1500_p03_p97  ask_continue_930_1457_p03_p97
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN

# %%
import pandas as pd
path = "/data/home/lexuanchen/Factors/Order/Signal/1_100_Percent_BID_P01_P99_Price_Divergence/bid_main_1000_1430_p01_p99.csv"
df = pd.read_csv(path)

df.head()

# %%
def filter_data(all_factor_data, factor_name, factor_type):
    """
    筛选特定因子列且该列不为NaN的数据，并进行透视
    
    参数:
    all_factor_data: 原始数据DataFrame
    factor_name: 要筛选的因子列名称，例如'bid_pre_open_915_920_p01_p99'
    
    返回:
    透视后的DataFrame，索引为date，列为security_code
    """
    # 步骤1: 筛选必要的列
    mask = all_factor_data['factor_type'] == factor_type
    filtered_data = all_factor_data[mask][['date', 'security_code', factor_name]]
    
    # 步骤2: 去除因子列为NaN的行
    filtered_data = filtered_data.dropna(subset=[factor_name])
    
    # 步骤3: 检查是否存在重复的(date, security_code)组合
    duplicates = filtered_data.duplicated(subset=['date', 'security_code'], keep=False)
    if duplicates.any():
        print(f"警告: 发现{duplicates.sum()}条重复记录，将保留第一条")
        # 如果有重复，保留第一条
        filtered_data = filtered_data.drop_duplicates(subset=['date', 'security_code'], keep='first')
    
    
    return filtered_data

# %%
def main():
    start_date = '2016-06-20'
    end_date = '2025-06-30'
    
    # 定义时间段列表
    time_intervals = [
        'pre_open_915_920',
        'pre_open_920_925',
        'early_930_1000',
        'main_1000_1430',
        'late_1430_1457',
        'close_1457_1500',
        'continue_930_1457'
    ]
    
    # 定义因子类型
    factor_types = [
        'bid_p01_p99',
        # 'bid_p05_p95',
        'ask_p01_p99'
        #, 'ask_p05_p95'
    ]
    
    # 生成所有因子名称列表
    all_factors = []
    for factor_type in factor_types:
        side = factor_type.split('_')[0]  # bid 或 ask
        percentile = '_'.join(factor_type.split('_')[1:])  # p01_p99 或 p05_p95
        for interval in time_intervals:
            all_factors.append(f"{side}_{interval}_{percentile}")
    
    # 为每种因子类型创建单独的目录
    factor_dirs = {}
    for factor_type in factor_types:
        # factor_name = f"1_100_percent_{factor_type}_price_divergence"
        factor_dir = f"./factors/1_99_percent_price_divergence"
        factor_dirs[factor_type] = factor_dir
        # print(f"{factor_type} 因子文件已生成在目录: {factor_dir}")
        
        # 统一化列名
        # standardize_parquet_files(factor_dir)
    
    # 为每种因子类型计算滚动平均值
    for factor_type, factor_dir in factor_dirs.items():
        # 获取该类型的因子列表
        type_factors = [f for f in all_factors if f.startswith(factor_type.split('_')[0]) and f.endswith('_'.join(factor_type.split('_')[1:]))]

        parquet_pattern = os.path.join(factor_dir, "*.parquet")
        parquet_files = glob.glob(parquet_pattern)
        print(f"在目录 {factor_dir} 中找到 {len(parquet_files)} 个Parquet文件")
        

        conn = duckdb.connect(database=':memory:')
        all_factor_data = conn.execute(f"""
            SELECT * FROM read_parquet('{parquet_pattern}')
        """).fetchdf()
        conn.close()
        

        all_factor_data['date'] = pd.to_datetime(all_factor_data['date'])

        all_factor_data = all_factor_data.sort_values(['date', 'security_code'])

        
        # 保存结果为CSV
        output_path = f"/data/home/lexuanchen/Factors/Order/Signal/1_99_Percent_{factor_type.upper()}_Price_Divergence_2"
        os.makedirs(output_path, exist_ok=True)
        
        print(f"{factor_type} 因子共计 {len(all_factor_data)} 条记录")
        print("\n数据预览:")
        print(all_factor_data.head())
        
        # 保存每个因子的CSV文件
        for factor in type_factors:
            result_df = filter_data(all_factor_data, factor, factor_type)
            output_file_path = f"{output_path}/raw_{factor}.csv"
            factor_df = result_df[['date', 'security_code', factor]].dropna(subset=[factor])
            factor_df.to_csv(output_file_path, index=False)

# 执行主函数
if __name__ == "__main__":
    main()
# Out:
# 在目录 ./factors/1_99_percent_price_divergence 中找到 2192 个Parquet文件
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# bid_p01_p99 因子共计 8992552 条记录
#
# 数据预览:
#   security_code  bid_pre_open_915_920_p01_p99  ask_pre_open_915_920_p01_p99  \
# 0        000001                      0.025253                      0.033544
# 1        000005                      0.034132                      0.029355
# 2        000006                      0.034470                      0.030007
# 3        000008                      0.024734                      0.031154
# 4        000009                      0.032511                      0.029375
#
#    bid_pre_open_920_925_p01_p99  ask_pre_open_920_925_p01_p99  \
# 0                      0.024399                      0.026576
# 1                      0.025580                      0.039455
# 2                      0.007618                      0.023609
# 3                      0.015137                      0.038711
# 4                      0.027177                      0.028236
#
#    bid_early_930_1000_p01_p99  ask_early_930_1000_p01_p99  \
# 0                    0.012684                    0.024194
# 1                    0.018472                    0.029513
# 2                    0.009761                    0.018221
# 3                    0.018601                    0.021838
# 4                    0.009430                    0.019707
#
#    bid_main_1000_1430_p01_p99  ask_main_1000_1430_p01_p99  \
# 0                    0.008248                    0.023670
# 1                    0.016620                    0.021335
# 2                    0.007042                    0.017227
# 3                    0.016355                    0.022872
# 4                    0.008507                    0.016086
#
#    bid_late_1430_1457_p01_p99  ask_late_1430_1457_p01_p99  \
# 0                    0.002896                    0.005828
# 1                    0.003546                    0.005848
# 2                    0.003422                    0.005778
# 3                    0.002655                    0.007415
# 4                    0.002776                    0.004377
#
#    bid_close_1457_1500_p01_p99  ask_close_1457_1500_p01_p99  \
# 0                     0.004962                     0.011613
# 1                     0.021567                     0.015177
# 2                     0.000747                     0.001749
# 3                     0.002041                     0.005278
# 4                     0.001207                     0.002843
#
#    bid_continue_930_1457_p01_p99  ask_continue_930_1457_p01_p99       date
# 0                       0.009249                       0.022642 2016-06-20
# 1                       0.016140                       0.021898 2016-06-20
# 2                       0.007819                       0.016033 2016-06-20
# 3                       0.016419                       0.023356 2016-06-20
# 4                       0.010079                       0.017955 2016-06-20
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/test1/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'factor_type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 82
#      80 # 执行主函数
#      81 if __name__ == "__main__":
# ---> 82     main()
#
# Cell In[13], line 75, in main()
#      73 # 保存每个因子的CSV文件
#      74 for factor in type_factors:
# ---> 75     result_df = filter_data(all_factor_data, factor, factor_type)
#      76     output_file_path = f"{output_path}/raw_{factor}.csv"
#      77     factor_df = result_df[['date', 'security_code', factor]].dropna(subset=[factor])
#
# Cell In[6], line 13, in filter_data(all_factor_data, factor_name, factor_type)
#       2 """
#       3 筛选特定因子列且该列不为NaN的数据，并进行透视
#       4
#    (...)     10 透视后的DataFrame，索引为date，列为security_code
#      11 """
#      12 # 步骤1: 筛选必要的列
# ---> 13 mask = all_factor_data['factor_type'] == factor_type
#      14 filtered_data = all_factor_data[mask][['date', 'security_code', factor_name]]
#      16 # 步骤2: 去除因子列为NaN的行
#
# File ~/.conda/envs/test1/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.conda/envs/test1/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'factor_type'

# %%
def main():
    start_date = '2016-06-20'
    end_date = '2025-06-30'
    
    # 定义时间段列表
    time_intervals = [
        'pre_open_915_920',
        'pre_open_920_925',
        'early_930_1000',
        'main_1000_1430',
        'late_1430_1457',
        'close_1457_1500',
        'continue_930_1457'
    ]
    
    # # 定义因子类型
    # factor_types = [
    #     'bid_p01_p99',
    #     'bid_p05_p95',
    #     'ask_p01_p99',
    #     'ask_p05_p95'
    # ]

        # 定义因子类型
    factor_types = [
        'bid_p01_p99',
        'ask_p01_p99',
    ]
    
    # 生成所有因子名称列表
    all_factors = []
    for factor_type in factor_types:
        side = factor_type.split('_')[0]  # bid 或 ask
        percentile = '_'.join(factor_type.split('_')[1:])  # p01_p99 或 p05_p95
        for interval in time_intervals:
            all_factors.append(f"{side}_{interval}_{percentile}")
    
    # 为每种因子类型创建单独的目录
    factor_dirs = {}
    for factor_type in factor_types:
        factor_name = f"1_99_percent_{factor_type}_price_divergence"
        factor_dir = f"./factors/1_99_percent_price_divergence"
        factor_dirs[factor_type] = factor_dir
        # print(f"{factor_type} 因子文件已生成在目录: {factor_dir}")
        
        # 统一化列名
    # standardize_parquet_files(factor_dir)
    
    # 为每种因子类型计算滚动平均值
    for factor_type, factor_dir in factor_dirs.items():
        # 获取该类型的因子列表
        type_factors = [f for f in all_factors if f.startswith(factor_type.split('_')[0]) and f.endswith('_'.join(factor_type.split('_')[1:]))]
        
        # 计算滚动平均
        result_df = calculate_rolling_20d_avg(type_factors, factor_dir, start_date, end_date, min_window=5)
        
        # 保存结果为CSV
        output_path = f"/data/home/lexuanchen/Factors/Order/Signal/1_99_Percent_{factor_type.upper()}_Price_Divergence_2"
        os.makedirs(output_path, exist_ok=True)
        
        print(f"{factor_type} 因子共计 {len(result_df)} 条记录")
        print("\n数据预览:")
        print(result_df.head())
        
        # 保存每个因子的CSV文件
        for factor in type_factors:
            output_file_path = f"{output_path}/20d_{factor}.csv"
            factor_df = result_df[['date', 'security_code', factor]].dropna(subset=[factor])
            factor_df.to_csv(output_file_path, index=False)

# 执行主函数
if __name__ == "__main__":
    main()
# Out:
# ['bid_pre_open_915_920_p01_p99', 'bid_pre_open_920_925_p01_p99', 'bid_early_930_1000_p01_p99', 'bid_main_1000_1430_p01_p99', 'bid_late_1430_1457_p01_p99', 'bid_close_1457_1500_p01_p99', 'bid_continue_930_1457_p01_p99']
# 在目录 ./factors/1_99_percent_price_divergence 中找到 2192 个Parquet文件
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 处理因子: bid_pre_open_915_920_p01_p99
# 已成功保存因子原文件：bid_pre_open_915_920_p01_p99
#
# bid_pre_open_915_920_p01_p99因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: bid_pre_open_920_925_p01_p99
# 已成功保存因子原文件：bid_pre_open_920_925_p01_p99
#
# bid_pre_open_920_925_p01_p99因子覆盖率统计: 平均=0.77, 最小=0.46
#
# 处理因子: bid_early_930_1000_p01_p99
# 已成功保存因子原文件：bid_early_930_1000_p01_p99
#
# bid_early_930_1000_p01_p99因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: bid_main_1000_1430_p01_p99
# 已成功保存因子原文件：bid_main_1000_1430_p01_p99
#
# bid_main_1000_1430_p01_p99因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: bid_late_1430_1457_p01_p99
# 已成功保存因子原文件：bid_late_1430_1457_p01_p99
#
# bid_late_1430_1457_p01_p99因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: bid_close_1457_1500_p01_p99
# 已成功保存因子原文件：bid_close_1457_1500_p01_p99
#
# bid_close_1457_1500_p01_p99因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: bid_continue_930_1457_p01_p99
# 已成功保存因子原文件：bid_continue_930_1457_p01_p99
#
# bid_continue_930_1457_p01_p99因子覆盖率统计: 平均=0.77, 最小=0.47
# bid_p01_p99 因子共计 8992552 条记录
#
# 数据预览:
#         date security_code  bid_pre_open_915_920_p01_p99  \
# 0 2016-06-20        000001                           NaN
# 1 2016-06-20        000005                           NaN
# 2 2016-06-20        000006                           NaN
# 3 2016-06-20        000008                           NaN
# 4 2016-06-20        000009                           NaN
#
#    bid_pre_open_920_925_p01_p99  bid_early_930_1000_p01_p99  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#    bid_main_1000_1430_p01_p99  bid_late_1430_1457_p01_p99  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    bid_close_1457_1500_p01_p99  bid_continue_930_1457_p01_p99
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
# ['ask_pre_open_915_920_p01_p99', 'ask_pre_open_920_925_p01_p99', 'ask_early_930_1000_p01_p99', 'ask_main_1000_1430_p01_p99', 'ask_late_1430_1457_p01_p99', 'ask_close_1457_1500_p01_p99', 'ask_continue_930_1457_p01_p99']
# 在目录 ./factors/1_99_percent_price_divergence 中找到 2192 个Parquet文件
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 处理因子: ask_pre_open_915_920_p01_p99
# 已成功保存因子原文件：ask_pre_open_915_920_p01_p99
#
# ask_pre_open_915_920_p01_p99因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: ask_pre_open_920_925_p01_p99
# 已成功保存因子原文件：ask_pre_open_920_925_p01_p99
#
# ask_pre_open_920_925_p01_p99因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: ask_early_930_1000_p01_p99
# 已成功保存因子原文件：ask_early_930_1000_p01_p99
#
# ask_early_930_1000_p01_p99因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: ask_main_1000_1430_p01_p99
# 已成功保存因子原文件：ask_main_1000_1430_p01_p99
#
# ask_main_1000_1430_p01_p99因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: ask_late_1430_1457_p01_p99
# 已成功保存因子原文件：ask_late_1430_1457_p01_p99
#
# ask_late_1430_1457_p01_p99因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: ask_close_1457_1500_p01_p99
# 已成功保存因子原文件：ask_close_1457_1500_p01_p99
#
# ask_close_1457_1500_p01_p99因子覆盖率统计: 平均=0.77, 最小=0.47
#
# 处理因子: ask_continue_930_1457_p01_p99
# 已成功保存因子原文件：ask_continue_930_1457_p01_p99
#
# ask_continue_930_1457_p01_p99因子覆盖率统计: 平均=0.77, 最小=0.47
# ask_p01_p99 因子共计 8992552 条记录
#
# 数据预览:
#         date security_code  ask_pre_open_915_920_p01_p99  \
# 0 2016-06-20        000001                           NaN
# 1 2016-06-20        000005                           NaN
# 2 2016-06-20        000006                           NaN
# 3 2016-06-20        000008                           NaN
# 4 2016-06-20        000009                           NaN
#
#    ask_pre_open_920_925_p01_p99  ask_early_930_1000_p01_p99  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#    ask_main_1000_1430_p01_p99  ask_late_1430_1457_p01_p99  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    ask_close_1457_1500_p01_p99  ask_continue_930_1457_p01_p99
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
